# %% [markdown]
# ### checking

# %% [markdown]
# 사용 python 버전 확인

# %%
import sys
print(sys.version)
# Out:
# 3.10.19 (main, Oct 21 2025, 16:43:05) [GCC 11.2.0]

# %% [markdown]
# CPU/GPU 사용 확인

# %%
import torch

# CPU/GPU 사용 여부 확인
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("현재 실행 장치: GPU (CUDA)")
    print("GPU 이름:", torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print("현재 실행 장치: CPU")
# Out:
# 현재 실행 장치: GPU (CUDA)
# GPU 이름: NVIDIA RTX 6000 Ada Generation

# %% [markdown]
# ### LIBRARY

# %%
import os
import pandas as pd
import ee
import re
from datetime import timedelta
# Out:
# /home/khs/anaconda3/envs/hoso/lib/python3.10/site-packages/google/api_core/_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ### CSV

# %% [markdown]
# 호소 chla 자료

# %%
# 최상위 폴더 경로
folder = r"/home/khs/data/csv/hoso chla/"

# 결과 저장
df_list = []

# 모든 하위 폴더 포함하여 .csv 찾기
for root, dirs, files in os.walk(folder):
    for file in files:
        if file.lower().endswith('.csv'):
            file_path = os.path.join(root, file)
            try:
                df = pd.read_csv(file_path, encoding='cp949')  # 또는 utf-8-sig
                df_list.append(df)
            except Exception as e:
                print(f"[오류] {file_path} 읽기 실패: {e}")

# 결측값 제거 후 전체 병합
if df_list:
    total_df = pd.concat(df_list, ignore_index=True).dropna()
    print(f"\n 총 병합된 파일 수: {len(df_list)}개")
    print(f" 총 병합된 행 수: {len(total_df)} rows")
    display(total_df.head())
else:
    print(" 병합할 수 있는 CSV 파일이 없습니다.")
# Out:
#  총 병합된 파일 수: 8개
#  총 병합된 행 수: 47776 rows
#       분류번호       측정소명       년/월/일       회차            경도           위도   채수시각  \
# 0  3008B60       대청댐2  2020/01/02  1회차 상층부   127°29'5.4"    36°28'37"  15:05
# 1  3008B50       대청댐3  2020/01/02  1회차 상층부  127°30'23.8"  36°30'43.2"  15:20
# 2  3008B10       대청댐4  2020/01/02  1회차 상층부   127°38'8.4"  36°22'18.5"  14:00
# 3  3008B30  대청댐5(대청호)  2020/01/02  1회차 상층부   127°33'9.3"  36°25'59.2"  14:40
# 4  3008B20       대청댐6  2020/01/02  1회차 상층부  127°33'25.1"  36°23'18.6"  14:20
#
#    클로로필 a(㎎/㎥)
# 0          1.2
# 1          1.4
# 2          1.8
# 3          1.2
# 4          2.0

# %% [markdown]
# 댐 목록 추출

# %%
# 측정소명에서 숫자 + 괄호 제거 → 댐 이름만 추출
total_df['댐명'] = (
    total_df['측정소명']
    .str.replace(r'\d+', '', regex=True)        # 숫자 제거
    .str.replace(r'\(.*?\)', '', regex=True)    # 괄호 내용 제거
    .str.strip()                                # 공백 제거
)

# 중복 없는 댐 목록 추출
dam_list = total_df['댐명'].unique()

print(dam_list)
# Out:
# ['대청댐' '섬진강댐' '임하댐' '충주조정지댐' '보령댐' '부안댐' '영산호' '용담댐' '장성댐' '주암조정지댐' '충주댐'
#  '간월호' '부남호' '팔당댐' '낙동강하구' '보현산댐' '성덕댐' '수어댐' '안계댐' '안동댐' '영천댐' '운문댐'
#  '의암댐' '광포호' '봉포호' '송지호' '천진호' '화진포호' '소양강댐' '주암댐' '감포댐' '군위댐' '밀양댐' '평림댐'
#  '횡성댐' '광동댐' '김천부항댐' '달방댐' '예당지' '나주댐' '영암호' '가창댐' '회야호' '광주댐' '구천댐' '남강댐'
#  '연초댐' '영주댐' '청평댐' '경포호' '금호호' '대곡댐' '대암댐' '사연댐' '선암댐' '장흥댐' '합천댐' '고삼지'
#  '괴산댐' '이동지' '주남저수지' '담양댐' '보성강댐' '남양호' '보문호' '서호' '아산호' '춘천댐' '매호' '영랑호'
#  '청초호' '향호' '경천지' '대아지' '동화호' '화천댐' '금강하구' '탑정지' '대호' '삽교호' '신갈지' '광교지'
#  '원천지' '평화의댐' '동복댐' '한탄강댐' '도암댐' '군남댐']

# %% [markdown]
# 수역 리스트 정의

# %%
# ---------------------
# 대형 댐호 (dam)
# ---------------------
dam_list = [
    '대청댐1','대청댐2','대청댐3','대청댐4','대청댐5(대청호)','대청댐6',
    '섬진강댐1(옥정호)','섬진강댐2(옥정호)','섬진강댐3(옥정호)',
    '임하댐1','임하댐2','임하댐3',

    '보령댐1','보령댐2','보령댐3',
    '부안댐1','부안댐2','부안댐3',
    '용담댐1','용담댐2','용담댐3','용담댐4',
    '장성댐1','장성댐2',

    '충주댐1','충주댐2','충주댐3','충주댐4',
    '수어댐1','수어댐2',
    '안계댐',

    '안동댐1','안동댐2','안동댐3',

    '영천댐1(영천호)','영천댐2(영천호)',
    '운문댐1','운문댐2',

    '의암댐1','의암댐2','의암댐3',

    '팔당댐1','팔당댐2','팔당댐3','팔당댐4','팔당댐5',

    '소양강댐1','소양강댐2','소양강댐3','소양강댐4','소양강댐5',

    '주암댐1','주암댐2','주암댐3',

    '군위댐1','군위댐2',
    '밀양댐1','밀양댐2',

    '횡성댐1','횡성댐2','횡성댐3',

    '광동댐','김천부항댐','달방댐',

    '나주댐1','나주댐2',
    '가창댐1','가창댐2',
    '구천댐',

    '남강댐1(진양호)','남강댐2(진양호)','남강댐3(진양호)',

    '연초댐1','연초댐2',

    '영주댐1','영주댐2','영주댐3','영주댐4',

    '청평댐1','청평댐2','청평댐3',

    '대곡댐1','대곡댐2',
    '대암댐1','대암댐2',
    '사연댐1','사연댐2',

    '선암댐',

    '장흥댐1','장흥댐2','장흥댐3','장흥댐4',

    '합천댐1','합천댐2','합천댐3',

    '괴산댐1','괴산댐2','괴산댐3',

    '담양댐1','담양댐2',

    '보성강댐1','보성강댐2',

    '화천댐1(파로호)','화천댐2(파로호)','화천댐3(파로호)',

    '춘천댐1','춘천댐2','춘천댐3',

    '한탄강댐','도암댐','군남댐','보현산댐','감포댐',

    '광주댐1','광주댐2',
    '회야호1','회야호2'
]


# ---------------------
# 조정지댐 (regulating)
# ---------------------
regulating_list = [
    '충주조정지댐1','충주조정지댐2',
    '주암조정지댐1(상사호)','주암조정지댐3(상사호)'
]


# ---------------------
# 자연호 (natural)
# ---------------------
natural_list = [
    '광포호','봉포호','송지호','천진호','화진포호',
    '영랑호','경포호1','경포호2','청초호',
    '서호1','서호2','서호3'
]


# ---------------------
# 인공저수지 (artificial)
# ---------------------
artificial_list = [
    '예당지1','예당지2','예당지3',
    '고삼지1','고삼지2','고삼지3',

    '경천지1','경천지2',
    '대아지1','대아지2','대아지3',

    '이동지1','이동지2',

    '향호','매호',

    '평림댐',

    '금호호1','금호호2','금호호3',

    '주남저수지',

    '보문호1','보문호2',

    '원천지1','원천지2','원천지3',
    '광교지1','광교지2',

    '아산호1(평택호)','아산호2(평택호)','아산호3(평택호)',

    '탑정지1(논산지)','탑정지2(논산지)',

    '동화호'
]


# ---------------------
# 간척호 (lagoon)
# ---------------------
lagoon_list = [
    '영암호1','영암호2','영암호3',
    '부남호1','부남호2','부남호3',
    '간월호1','간월호2','간월호3',
    '남양호1','남양호2','남양호3',
    '대호1','대호2','대호3',
    '삽교호1','삽교호2','삽교호3'
]


# ---------------------
# 하구호 (estuary)
# ---------------------
estuary_list = [
    '금강하구1','금강하구2','금강하구3',
    '낙동강하구1','낙동강하구2','낙동강하구3',
    '영산호1','영산호2','영산호3'
]

# %% [markdown]
# 측정소 선택

# %%
# 호소 유형 분류 함수
def classify_lake(name):
    if name in dam_list:
        return 'dam'
    elif name in natural_list:
        return 'natural'
    elif name in regulating_list:
        return 'regulating'
    elif name in artificial_list:
        return 'artificial'
    elif name in lagoon_list:
        return 'lagoon'
    elif name in estuary_list:
        return 'estuary'
    else:
        return 'unknown'

# total_df에 새로운 컬럼 추가
total_df["호소유형"] = total_df["측정소명"].apply(classify_lake)

# 결과 확인
print(total_df["호소유형"].value_counts())
# Out:
# 호소유형
# dam           35307
# artificial     5118
# lagoon         2604
# estuary        1792
# natural        1062
# unknown         965
# regulating      928
# Name: count, dtype: int64

# %%
selected_types = ["dam", "regulating"]
total_df = total_df[ total_df["호소유형"].isin(selected_types) ].copy()

# %%
print("최종 선택된 호소유형 분포:")
print(total_df["호소유형"].value_counts())
print("최종 선택된 측정소 개수:", total_df["측정소명"].nunique())
# Out:
# 최종 선택된 호소유형 분포:
# 호소유형
# dam           35307
# regulating      928
# Name: count, dtype: int64
# 최종 선택된 측정소 개수: 121

# %%
# 측정소명에서 숫자 + 괄호 제거 → 댐 이름만 추출
total_df['댐명'] = (
    total_df['측정소명']
    .str.replace(r'\d+', '', regex=True)        # 숫자 제거
    .str.replace(r'\(.*?\)', '', regex=True)    # 괄호 내용 제거
    .str.strip()                                # 공백 제거
)

# 중복 없는 댐 목록 추출
dam_list = total_df['댐명'].unique()

print(dam_list)
# Out:
# ['대청댐' '섬진강댐' '임하댐' '충주조정지댐' '보령댐' '부안댐' '용담댐' '장성댐' '주암조정지댐' '충주댐' '팔당댐'
#  '보현산댐' '수어댐' '안계댐' '안동댐' '영천댐' '운문댐' '의암댐' '소양강댐' '주암댐' '감포댐' '군위댐' '밀양댐'
#  '횡성댐' '광동댐' '김천부항댐' '달방댐' '나주댐' '가창댐' '회야호' '광주댐' '구천댐' '남강댐' '연초댐' '영주댐'
#  '청평댐' '대곡댐' '대암댐' '사연댐' '선암댐' '장흥댐' '합천댐' '괴산댐' '담양댐' '보성강댐' '춘천댐' '화천댐'
#  '한탄강댐' '도암댐' '군남댐']

# %% [markdown]
# ### GEE

# %%
# 서버 사용 시 직접 터미널로 인증 진행

# 기존 인증 파일 삭제(꼬였을 수 있으니 정리)
# rm ~/.config/earthengine/credentials

# 터미널에서 인증 실행
# earthengine authenticate --auth_mode=notebook

# %%
# 최초 1회만 필요 (브라우저 인증)
ee.Authenticate()

ee.Initialize()

# %% [markdown]
# ### matching

# %%
 # DMS->DD (이미 DD면 통과)
def dms_to_dd(v):
    try:
        if isinstance(v, (int, float)):
            return float(v)
        s = str(v).strip()
        if re.match(r'^\d+(\.\d+)?$', s):
            return float(s)
        parts = re.split('[°\'"]+', s)
        parts = [p for p in parts if p]
        deg, minute, sec = map(float, parts[:3])
        return deg + minute/60 + sec/3600
    except Exception:
        return None

# %% [markdown]
# ImageCollection 정의

# %%
# sentinel-2
S2 = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")

# landsat
L8 = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")
L9 = ee.ImageCollection("LANDSAT/LC09/C02/T1_L2")
Landsat = L8.merge(L9)

# 결과 저장용 리스트
results = []

# %% [markdown]
# 불러오기 (날짜별)

# %%
for date, group in total_df.groupby("년/월/일"):

    obs_date = pd.to_datetime(date)
    start = obs_date.strftime("%Y-%m-%d")
    end   = (obs_date + timedelta(days=1)).strftime("%Y-%m-%d")

    # -----------------------------------
    # 관측 지점 → FeatureCollection
    # -----------------------------------
    features = []
    for idx, row in group.iterrows():
        lon = dms_to_dd(row["경도"])
        lat = dms_to_dd(row["위도"])

        pt = ee.Geometry.Point([lon, lat])
        feat = ee.Feature(pt, {"idx": idx})
        features.append(feat)

    fc = ee.FeatureCollection(features)

    # -----------------------------------
    # Sentinel-2
    # -----------------------------------
    s2_img = (S2
              .filterBounds(fc)
              .filterDate(start, end)
              .sort("system:time_start", False)
              .first())

    if s2_img.getInfo() is None:
        print(date, "→ Sentinel-2 없음")
        continue

    s2_selected = s2_img.select([
        "SCL",
        "B1","B2","B3","B4","B5","B6","B7",
        "B8","B8A","B9","B11","B12"
    ])

    s2_reduced = s2_selected.reduceRegions(
        collection = fc,
        reducer = ee.Reducer.first(),
        scale = 10
    )

    s2_rows = s2_reduced.getInfo()["features"]

    # -----------------------------------
    # Landsat
    # -----------------------------------
    lst_img = (Landsat
               .filterBounds(fc)
               .filterDate(start, end)
               .sort("system:time_start", False)
               .first())

    # Landsat 없으면 해당 날짜 전체 제거
    if lst_img.getInfo() is None:
        print(date, "→ Landsat 없음")
        continue

    # ST_B10 → 섭씨 변환
    lst_selected = (
        lst_img.select("ST_B10")
        .multiply(0.00341802)
        .add(149.0)
        .subtract(273.15)
        .rename("LST")
    )

    lst_reduced = lst_selected.reduceRegions(
        collection = fc,
        reducer = ee.Reducer.first(),
        scale = 30
    )

    # LST가 있는 지점만 저장
    lst_rows = {
        f["properties"]["idx"]: f["properties"]["LST"]
        for f in lst_reduced.getInfo()["features"]
        if "LST" in f["properties"]
    }
    # lst_rows = {
    #     f["properties"]["idx"]: f["properties"]["LST"]
    #     for f in lst_reduced.getInfo()["features"]
    # }

    # -----------------------------------
    # Sentinel + Landsat 병합
    # -----------------------------------
    for item in s2_rows:
        props = item["properties"]
        idx = props["idx"]

        # SCL 기반 수질 픽셀 필터
        scl = props.get("SCL", None)
        if scl not in [2, 6, 7]:
            continue

        # Landsat LST 없는 지점 제거
        if idx not in lst_rows:
            continue

        out = total_df.loc[idx].to_dict()

        # Sentinel-2 밴드 추가
        out.update(props)

        # Landsat LST 추가
        out["LST"] = lst_rows.get(idx, None)

        # 메타정보
        out["image_id_S2"] = s2_img.get("system:index").getInfo()
        out["image_id_Landsat"] = lst_img.get("system:index").getInfo()

        results.append(out)

df_out = pd.DataFrame(results)
# Out:
# 2018/01/02 → Sentinel-2 없음
# 2018/01/03 → Sentinel-2 없음
# 2018/01/04 → Sentinel-2 없음
# 2018/01/05 → Sentinel-2 없음
# 2018/01/08 → Sentinel-2 없음
# 2018/01/09 → Sentinel-2 없음
# 2018/01/10 → Sentinel-2 없음
# 2018/01/12 → Sentinel-2 없음
# 2018/01/15 → Sentinel-2 없음
# 2018/01/19 → Sentinel-2 없음
# 2018/01/22 → Sentinel-2 없음
# 2018/01/23 → Sentinel-2 없음
# 2018/01/29 → Sentinel-2 없음
# 2018/02/01 → Sentinel-2 없음
# 2018/02/02 → Sentinel-2 없음
# 2018/02/05 → Sentinel-2 없음
# 2018/02/06 → Sentinel-2 없음
# 2018/02/08 → Sentinel-2 없음
# 2018/02/09 → Sentinel-2 없음
# 2018/02/12 → Sentinel-2 없음
# 2018/02/14 → Sentinel-2 없음
# 2018/02/19 → Sentinel-2 없음
# 2018/02/20 → Sentinel-2 없음
# 2018/02/22 → Landsat 없음
# 2018/02/26 → Sentinel-2 없음
# 2018/02/27 → Sentinel-2 없음
# 2018/02/28 → Sentinel-2 없음
# 2018/03/02 → Sentinel-2 없음
# 2018/03/05 → Sentinel-2 없음
# 2018/03/06 → Sentinel-2 없음
# 2018/03/07 → Sentinel-2 없음
# 2018/03/08 → Sentinel-2 없음
# 2018/03/09 → Landsat 없음
# 2018/03/12 → Sentinel-2 없음
# 2018/03/13 → Sentinel-2 없음
# 2018/03/14 → Sentinel-2 없음
# 2018/03/15 → Sentinel-2 없음
# 2018/03/19 → Landsat 없음
# 2018/03/20 → Sentinel-2 없음
# 2018/03/23 → Sentinel-2 없음
# 2018/03/26 → Sentinel-2 없음
# 2018/03/27 → Sentinel-2 없음
# 2018/04/02 → Sentinel-2 없음
# 2018/04/03 → Sentinel-2 없음
# 2018/04/04 → Sentinel-2 없음
# 2018/04/05 → Sentinel-2 없음
# 2018/04/06 → Sentinel-2 없음
# 2018/04/09 → Sentinel-2 없음
# 2018/04/10 → Sentinel-2 없음
# 2018/04/11 → Sentinel-2 없음
# 2018/04/12 → Sentinel-2 없음
# 2018/04/16 → Sentinel-2 없음
# 2018/04/17 → Sentinel-2 없음
# 2018/04/19 → Sentinel-2 없음
# 2018/04/23 → Sentinel-2 없음
# 2018/04/25 → Sentinel-2 없음
# 2018/04/30 → Sentinel-2 없음
# 2018/05/01 → Sentinel-2 없음
# 2018/05/02 → Sentinel-2 없음
# 2018/05/03 → Sentinel-2 없음
# 2018/05/04 → Sentinel-2 없음
# 2018/05/07 → Sentinel-2 없음
# 2018/05/08 → Sentinel-2 없음
# 2018/05/10 → Sentinel-2 없음
# 2018/05/11 → Sentinel-2 없음
# 2018/05/14 → Sentinel-2 없음
# 2018/05/15 → Sentinel-2 없음
# 2018/05/16 → Sentinel-2 없음
# 2018/05/21 → Sentinel-2 없음
# 2018/05/23 → Sentinel-2 없음
# 2018/05/28 → Sentinel-2 없음
# 2018/05/29 → Sentinel-2 없음
# 2018/06/01 → Sentinel-2 없음
# 2018/06/04 → Sentinel-2 없음
# 2018/06/05 → Sentinel-2 없음
# 2018/06/07 → Sentinel-2 없음
# 2018/06/08 → Sentinel-2 없음
# 2018/06/11 → Sentinel-2 없음
# 2018/06/12 → Sentinel-2 없음
# 2018/06/14 → Sentinel-2 없음
# 2018/06/15 → Sentinel-2 없음
# 2018/06/18 → Sentinel-2 없음
# 2018/06/21 → Sentinel-2 없음
# 2018/06/25 → Sentinel-2 없음
# 2018/06/26 → Sentinel-2 없음
# 2018/07/02 → Sentinel-2 없음
# 2018/07/03 → Sentinel-2 없음
# 2018/07/04 → Sentinel-2 없음
# 2018/07/05 → Sentinel-2 없음
# 2018/07/09 → Sentinel-2 없음
# 2018/07/10 → Sentinel-2 없음
# 2018/07/11 → Sentinel-2 없음
# 2018/07/12 → Sentinel-2 없음
# 2018/07/13 → Sentinel-2 없음
# 2018/07/16 → Sentinel-2 없음
# 2018/07/17 → Sentinel-2 없음
# 2018/07/19 → Sentinel-2 없음
# 2018/07/23 → Sentinel-2 없음
# 2018/07/24 → Sentinel-2 없음
# 2018/07/30 → Sentinel-2 없음
# 2018/07/31 → Sentinel-2 없음
# 2018/08/01 → Sentinel-2 없음
# 2018/08/02 → Sentinel-2 없음
# 2018/08/03 → Sentinel-2 없음
# 2018/08/06 → Sentinel-2 없음
# 2018/08/07 → Sentinel-2 없음
# 2018/08/08 → Sentinel-2 없음
# 2018/08/09 → Sentinel-2 없음
# 2018/08/13 → Sentinel-2 없음
# 2018/08/14 → Sentinel-2 없음
# 2018/08/16 → Sentinel-2 없음
# 2018/08/20 → Sentinel-2 없음
# 2018/08/21 → Sentinel-2 없음
# 2018/08/27 → Sentinel-2 없음
# 2018/08/28 → Sentinel-2 없음
# 2018/09/03 → Sentinel-2 없음
# 2018/09/04 → Sentinel-2 없음
# 2018/09/05 → Sentinel-2 없음
# 2018/09/06 → Sentinel-2 없음
# 2018/09/10 → Sentinel-2 없음
# 2018/09/11 → Sentinel-2 없음
# 2018/09/12 → Sentinel-2 없음
# 2018/09/13 → Sentinel-2 없음
# 2018/09/14 → Sentinel-2 없음
# 2018/09/17 → Sentinel-2 없음
# 2018/09/18 → Sentinel-2 없음
# 2018/09/27 → Sentinel-2 없음
# 2018/10/01 → Sentinel-2 없음
# 2018/10/02 → Sentinel-2 없음
# 2018/10/04 → Sentinel-2 없음
# 2018/10/08 → Sentinel-2 없음
# 2018/10/10 → Sentinel-2 없음
# 2018/10/11 → Sentinel-2 없음
# 2018/10/12 → Sentinel-2 없음
# 2018/10/15 → Landsat 없음
# 2018/10/16 → Sentinel-2 없음
# 2018/10/17 → Sentinel-2 없음
# 2018/10/22 → Sentinel-2 없음
# 2018/10/23 → Sentinel-2 없음
# 2018/10/24 → Sentinel-2 없음
# 2018/10/29 → Sentinel-2 없음
# 2018/10/30 → Sentinel-2 없음
# 2018/11/01 → Sentinel-2 없음
# 2018/11/02 → Sentinel-2 없음
# 2018/11/05 → Sentinel-2 없음
# 2018/11/06 → Sentinel-2 없음
# 2018/11/07 → Sentinel-2 없음
# 2018/11/08 → Sentinel-2 없음
# 2018/11/09 → Sentinel-2 없음
# 2018/11/12 → Sentinel-2 없음
# 2018/11/13 → Sentinel-2 없음
# 2018/11/14 → Sentinel-2 없음
# 2018/11/19 → Sentinel-2 없음
# 2018/11/20 → Sentinel-2 없음
# 2018/11/22 → Sentinel-2 없음
# 2018/11/26 → Sentinel-2 없음
# 2018/11/27 → Sentinel-2 없음
# 2018/12/03 → Sentinel-2 없음
# 2018/12/04 → Sentinel-2 없음
# 2018/12/05 → Sentinel-2 없음
# 2018/12/06 → Sentinel-2 없음
# 2018/12/07 → Sentinel-2 없음
# 2018/12/10 → Sentinel-2 없음
# 2018/12/11 → Sentinel-2 없음
# 2018/12/12 → Sentinel-2 없음
# 2018/12/13 → Sentinel-2 없음
# 2018/12/17 → Sentinel-2 없음
# 2018/12/18 → Sentinel-2 없음
# 2018/12/24 → Landsat 없음
# 2018/12/26 → Sentinel-2 없음
# 2019/01/02 → Sentinel-2 없음
# 2019/01/03 → Landsat 없음
# 2019/01/04 → Sentinel-2 없음
# 2019/01/07 → Sentinel-2 없음
# 2019/01/08 → Landsat 없음
# 2019/01/09 → Sentinel-2 없음
# 2019/01/10 → Landsat 없음
# 2019/01/14 → Sentinel-2 없음
# 2019/01/15 → Landsat 없음
# 2019/01/21 → Sentinel-2 없음
# 2019/01/22 → Sentinel-2 없음
# 2019/01/28 → Landsat 없음
# 2019/01/29 → Sentinel-2 없음
# 2019/02/01 → Sentinel-2 없음
# 2019/02/08 → Sentinel-2 없음
# 2019/02/11 → Sentinel-2 없음
# 2019/02/12 → Landsat 없음
# 2019/02/13 → Sentinel-2 없음
# 2019/02/15 → Sentinel-2 없음
# 2019/02/18 → Sentinel-2 없음
# 2019/02/19 → Sentinel-2 없음
# 2019/02/20 → Sentinel-2 없음
# 2019/02/21 → Sentinel-2 없음
# 2019/02/25 → Sentinel-2 없음
# 2019/02/26 → Sentinel-2 없음
# 2019/03/04 → Landsat 없음
# 2019/03/05 → Sentinel-2 없음
# 2019/03/06 → Landsat 없음
# 2019/03/07 → Sentinel-2 없음
# 2019/03/12 → Sentinel-2 없음
# 2019/03/13 → Sentinel-2 없음
# 2019/03/14 → Landsat 없음
# 2019/03/18 → Sentinel-2 없음
# 2019/03/19 → Landsat 없음
# 2019/03/21 → Sentinel-2 없음
# 2019/03/25 → Sentinel-2 없음
# 2019/03/26 → Sentinel-2 없음
# 2019/04/01 → Sentinel-2 없음
# 2019/04/02 → Sentinel-2 없음
# 2019/04/04 → Sentinel-2 없음
# 2019/04/05 → Sentinel-2 없음
# 2019/04/08 → Landsat 없음
# 2019/04/09 → Sentinel-2 없음
# 2019/04/10 → Landsat 없음
# 2019/04/11 → Sentinel-2 없음
# 2019/04/15 → Landsat 없음
# 2019/04/16 → Sentinel-2 없음
# 2019/04/22 → Sentinel-2 없음
# 2019/04/23 → Landsat 없음
# 2019/04/24 → Sentinel-2 없음
# 2019/04/29 → Sentinel-2 없음
# 2019/04/30 → Sentinel-2 없음
# 2019/05/02 → Sentinel-2 없음
# 2019/05/03 → Landsat 없음
# 2019/05/07 → Sentinel-2 없음
# 2019/05/08 → Landsat 없음
# 2019/05/09 → Sentinel-2 없음
# 2019/05/13 → Landsat 없음
# 2019/05/14 → Sentinel-2 없음
# 2019/05/15 → Landsat 없음
# 2019/05/17 → Sentinel-2 없음
# 2019/05/20 → Sentinel-2 없음
# 2019/05/21 → Sentinel-2 없음
# 2019/05/22 → Sentinel-2 없음
# 2019/05/27 → Sentinel-2 없음
# 2019/05/29 → Sentinel-2 없음
# 2019/06/03 → Sentinel-2 없음
# 2019/06/04 → Landsat 없음
# 2019/06/05 → Sentinel-2 없음
# 2019/06/10 → Sentinel-2 없음
# 2019/06/11 → Sentinel-2 없음
# 2019/06/12 → Sentinel-2 없음
# 2019/06/13 → Sentinel-2 없음
# 2019/06/17 → Landsat 없음
# 2019/06/18 → Sentinel-2 없음
# 2019/06/20 → Sentinel-2 없음
# 2019/06/24 → Landsat 없음
# 2019/06/25 → Sentinel-2 없음
# 2019/06/27 → Landsat 없음
# 2019/07/01 → Sentinel-2 없음
# 2019/07/02 → Landsat 없음
# 2019/07/03 → Sentinel-2 없음
# 2019/07/04 → Sentinel-2 없음
# 2019/07/08 → Sentinel-2 없음
# 2019/07/09 → Landsat 없음
# 2019/07/11 → Sentinel-2 없음
# 2019/07/12 → Landsat 없음
# 2019/07/15 → Sentinel-2 없음
# 2019/07/16 → Sentinel-2 없음
# 2019/07/18 → Sentinel-2 없음
# 2019/07/22 → Landsat 없음
# 2019/07/23 → Sentinel-2 없음
# 2019/07/24 → Sentinel-2 없음
# 2019/07/29 → Landsat 없음
# 2019/08/01 → Landsat 없음
# 2019/08/02 → Sentinel-2 없음
# 2019/08/05 → Sentinel-2 없음
# 2019/08/06 → Landsat 없음
# 2019/08/07 → Sentinel-2 없음
# 2019/08/08 → Landsat 없음
# 2019/08/12 → Sentinel-2 없음
# 2019/08/13 → Landsat 없음
# 2019/08/19 → Sentinel-2 없음
# 2019/08/20 → Sentinel-2 없음
# 2019/08/22 → Sentinel-2 없음
# 2019/08/26 → Landsat 없음
# 2019/08/27 → Sentinel-2 없음
# 2019/09/02 → Landsat 없음
# 2019/09/03 → Sentinel-2 없음
# 2019/09/04 → Sentinel-2 없음
# 2019/09/05 → Landsat 없음
# 2019/09/09 → Sentinel-2 없음
# 2019/09/11 → Sentinel-2 없음
# 2019/09/16 → Sentinel-2 없음
# 2019/09/18 → Sentinel-2 없음
# 2019/09/19 → Sentinel-2 없음
# 2019/09/20 → Landsat 없음
# 2019/09/23 → Sentinel-2 없음
# 2019/09/24 → Sentinel-2 없음
# 2019/09/30 → Landsat 없음
# 2019/10/01 → Sentinel-2 없음
# 2019/10/02 → Sentinel-2 없음
# 2019/10/04 → Sentinel-2 없음
# 2019/10/07 → Landsat 없음
# 2019/10/08 → Sentinel-2 없음
# 2019/10/10 → Landsat 없음
# 2019/10/14 → Sentinel-2 없음
# 2019/10/15 → Landsat 없음
# 2019/10/16 → Sentinel-2 없음
# 2019/10/21 → Sentinel-2 없음
# 2019/10/22 → Sentinel-2 없음
# 2019/10/28 → Sentinel-2 없음
# 2019/10/29 → Sentinel-2 없음
# 2019/11/01 → Landsat 없음
# 2019/11/05 → Sentinel-2 없음
# 2019/11/06 → Landsat 없음
# 2019/11/07 → Sentinel-2 없음
# 2019/11/08 → Sentinel-2 없음
# 2019/11/11 → Landsat 없음
# 2019/11/12 → Sentinel-2 없음
# 2019/11/13 → Sentinel-2 없음
# 2019/11/14 → Landsat 없음
# 2019/11/15 → Sentinel-2 없음
# 2019/11/18 → Sentinel-2 없음
# 2019/11/19 → Landsat 없음
# 2019/11/21 → Sentinel-2 없음
# 2019/11/25 → Sentinel-2 없음
# 2019/11/26 → Sentinel-2 없음
# 2019/12/02 → Sentinel-2 없음
# 2019/12/03 → Sentinel-2 없음
# 2019/12/04 → Landsat 없음
# 2019/12/05 → Sentinel-2 없음
# 2019/12/06 → Sentinel-2 없음
# 2019/12/09 → Landsat 없음
# 2019/12/10 → Sentinel-2 없음
# 2019/12/11 → Sentinel-2 없음
# 2019/12/16 → Landsat 없음
# 2019/12/17 → Sentinel-2 없음
# 2019/12/23 → Sentinel-2 없음
# 2019/12/30 → Sentinel-2 없음
# 2020/01/02 → Sentinel-2 없음
# 2020/01/03 → Landsat 없음
# 2020/01/06 → Sentinel-2 없음
# 2020/01/07 → Sentinel-2 없음
# 2020/01/08 → Landsat 없음
# 2020/01/09 → Sentinel-2 없음
# 2020/01/10 → Sentinel-2 없음
# 2020/01/13 → Landsat 없음
# 2020/01/14 → Sentinel-2 없음
# 2020/01/15 → Sentinel-2 없음
# 2020/01/16 → Sentinel-2 없음
# 2020/01/20 → Landsat 없음
# 2020/01/21 → Sentinel-2 없음
# 2020/01/22 → Sentinel-2 없음
# 2020/01/28 → Landsat 없음
# 2020/02/03 → Sentinel-2 없음
# 2020/02/04 → Landsat 없음
# 2020/02/05 → Sentinel-2 없음
# 2020/02/06 → Sentinel-2 없음
# 2020/02/10 → Sentinel-2 없음
# 2020/02/11 → Sentinel-2 없음
# 2020/02/12 → Landsat 없음
# 2020/02/13 → Sentinel-2 없음
# 2020/02/14 → Sentinel-2 없음
# 2020/02/18 → Sentinel-2 없음
# 2020/02/19 → Sentinel-2 없음
# 2020/02/25 → Sentinel-2 없음
# 2020/03/02 → Sentinel-2 없음
# 2020/03/03 → Landsat 없음
# 2020/03/04 → Sentinel-2 없음
# 2020/03/05 → Landsat 없음
# 2020/03/06 → Sentinel-2 없음
# 2020/03/09 → Sentinel-2 없음
# 2020/03/10 → Landsat 없음
# 2020/03/11 → Sentinel-2 없음
# 2020/03/13 → Landsat 없음
# 2020/03/16 → Sentinel-2 없음
# 2020/03/17 → Sentinel-2 없음
# 2020/03/23 → Landsat 없음
# 2020/03/24 → Sentinel-2 없음
# 2020/03/25 → Sentinel-2 없음
# 2020/03/30 → Sentinel-2 없음
# 2020/03/31 → Sentinel-2 없음
# 2020/04/01 → Sentinel-2 없음
# 2020/04/02 → Landsat 없음
# 2020/04/03 → Sentinel-2 없음
# 2020/04/06 → Sentinel-2 없음
# 2020/04/07 → Landsat 없음
# 2020/04/08 → Sentinel-2 없음
# 2020/04/09 → Sentinel-2 없음
# 2020/04/13 → Sentinel-2 없음
# 2020/04/16 → Sentinel-2 없음
# 2020/04/20 → Sentinel-2 없음
# 2020/04/21 → Sentinel-2 없음
# 2020/04/23 → Sentinel-2 없음
# 2020/04/24 → Sentinel-2 없음
# 2020/04/27 → Landsat 없음
# 2020/04/28 → Sentinel-2 없음
# 2020/05/04 → Landsat 없음
# 2020/05/06 → Sentinel-2 없음
# 2020/05/08 → Sentinel-2 없음
# 2020/05/11 → Sentinel-2 없음
# 2020/05/12 → Landsat 없음
# 2020/05/13 → Sentinel-2 없음
# 2020/05/14 → Sentinel-2 없음
# 2020/05/18 → Sentinel-2 없음
# 2020/05/19 → Sentinel-2 없음
# 2020/05/20 → Sentinel-2 없음
# 2020/05/25 → Sentinel-2 없음
# 2020/05/26 → Sentinel-2 없음
# 2020/06/02 → Sentinel-2 없음
# 2020/06/03 → Landsat 없음
# 2020/06/04 → Sentinel-2 없음
# 2020/06/09 → Sentinel-2 없음
# 2020/06/10 → Sentinel-2 없음
# 2020/06/11 → Landsat 없음
# 2020/06/12 → Sentinel-2 없음
# 2020/06/15 → Sentinel-2 없음
# 2020/06/16 → Landsat 없음
# 2020/06/22 → Sentinel-2 없음
# 2020/06/23 → Sentinel-2 없음
# 2020/06/24 → Sentinel-2 없음
# 2020/06/29 → Sentinel-2 없음
# 2020/07/01 → Landsat 없음
# 2020/07/02 → Sentinel-2 없음
# 2020/07/06 → Landsat 없음
# 2020/07/07 → Sentinel-2 없음
# 2020/07/08 → Landsat 없음
# 2020/07/09 → Sentinel-2 없음
# 2020/07/13 → Landsat 없음
# 2020/07/14 → Sentinel-2 없음
# 2020/07/15 → Sentinel-2 없음
# 2020/07/16 → Landsat 없음
# 2020/07/17 → Sentinel-2 없음
# 2020/07/20 → Sentinel-2 없음
# 2020/07/21 → Landsat 없음
# 2020/07/22 → Sentinel-2 없음
# 2020/07/27 → Sentinel-2 없음
# 2020/07/28 → Sentinel-2 없음
# 2020/08/03 → Sentinel-2 없음
# 2020/08/04 → Sentinel-2 없음
# 2020/08/05 → Landsat 없음
# 2020/08/06 → Sentinel-2 없음
# 2020/08/10 → Landsat 없음
# 2020/08/11 → Sentinel-2 없음
# 2020/08/12 → Landsat 없음
# 2020/08/14 → Sentinel-2 없음
# 2020/08/18 → Sentinel-2 없음
# 2020/08/19 → Sentinel-2 없음
# 2020/08/21 → Sentinel-2 없음
# 2020/08/24 → Sentinel-2 없음
# 2020/08/25 → Landsat 없음
# 2020/08/27 → Sentinel-2 없음
# 2020/08/31 → Sentinel-2 없음
# 2020/09/01 → Landsat 없음
# 2020/09/02 → Sentinel-2 없음
# 2020/09/04 → Landsat 없음
# 2020/09/07 → Sentinel-2 없음
# 2020/09/08 → Sentinel-2 없음
# 2020/09/09 → Landsat 없음
# 2020/09/10 → Sentinel-2 없음
# 2020/09/14 → Landsat 없음
# 2020/09/15 → Sentinel-2 없음
# 2020/09/16 → Landsat 없음
# 2020/09/17 → Sentinel-2 없음
# 2020/09/22 → Sentinel-2 없음
# 2020/09/28 → Sentinel-2 없음
# 2020/10/05 → Sentinel-2 없음
# 2020/10/06 → Landsat 없음
# 2020/10/07 → Sentinel-2 없음
# 2020/10/08 → Sentinel-2 없음
# 2020/10/12 → Sentinel-2 없음
# 2020/10/13 → Sentinel-2 없음
# 2020/10/15 → Sentinel-2 없음
# 2020/10/19 → Landsat 없음
# 2020/10/20 → Sentinel-2 없음
# 2020/10/26 → Landsat 없음
# 2020/10/27 → Sentinel-2 없음
# 2020/11/02 → Sentinel-2 없음
# 2020/11/03 → Landsat 없음
# 2020/11/04 → Sentinel-2 없음
# 2020/11/05 → Landsat 없음
# 2020/11/06 → Sentinel-2 없음
# 2020/11/09 → Sentinel-2 없음
# 2020/11/10 → Landsat 없음
# 2020/11/11 → Sentinel-2 없음
# 2020/11/16 → Sentinel-2 없음
# 2020/11/17 → Sentinel-2 없음
# 2020/11/18 → Landsat 없음
# 2020/11/23 → Landsat 없음
# 2020/11/24 → Sentinel-2 없음
# 2020/11/30 → Landsat 없음
# 2020/12/01 → Sentinel-2 없음
# 2020/12/02 → Sentinel-2 없음
# 2020/12/03 → Landsat 없음
# 2020/12/04 → Sentinel-2 없음
# 2020/12/07 → Sentinel-2 없음
# 2020/12/09 → Sentinel-2 없음
# 2020/12/10 → Sentinel-2 없음
# 2020/12/14 → Sentinel-2 없음
# 2020/12/15 → Landsat 없음
# 2020/12/16 → Sentinel-2 없음
# 2020/12/21 → Sentinel-2 없음
# 2020/12/22 → Sentinel-2 없음
# 2020/12/28 → Landsat 없음
# 2021/01/04 → Landsat 없음
# 2021/01/05 → Sentinel-2 없음
# 2021/01/06 → Sentinel-2 없음
# 2021/01/07 → Landsat 없음
# 2021/01/11 → Sentinel-2 없음
# 2021/01/12 → Sentinel-2 없음
# 2021/01/13 → Sentinel-2 없음
# 2021/01/14 → Landsat 없음
# 2021/01/18 → Sentinel-2 없음
# 2021/01/19 → Landsat 없음
# 2021/01/20 → Sentinel-2 없음
# 2021/01/25 → Sentinel-2 없음
# 2021/01/26 → Sentinel-2 없음
# 2021/02/01 → Landsat 없음
# 2021/02/02 → Sentinel-2 없음
# 2021/02/04 → Sentinel-2 없음
# 2021/02/05 → Sentinel-2 없음
# 2021/02/08 → Landsat 없음
# 2021/02/09 → Sentinel-2 없음
# 2021/02/15 → Sentinel-2 없음
# 2021/02/16 → Landsat 없음
# 2021/02/19 → Sentinel-2 없음
# 2021/02/22 → Sentinel-2 없음
# 2021/02/23 → Sentinel-2 없음
# 2021/02/24 → Sentinel-2 없음
# 2021/03/02 → Sentinel-2 없음
# 2021/03/03 → Landsat 없음
# 2021/03/04 → Sentinel-2 없음
# 2021/03/08 → Landsat 없음
# 2021/03/09 → Sentinel-2 없음
# 2021/03/10 → Landsat 없음
# 2021/03/11 → Sentinel-2 없음
# 2021/03/15 → Landsat 없음
# 2021/03/16 → Sentinel-2 없음
# 2021/03/18 → Landsat 없음
# 2021/03/22 → Sentinel-2 없음
# 2021/03/29 → Sentinel-2 없음
# 2021/03/30 → Sentinel-2 없음
# 2021/04/01 → Sentinel-2 없음
# 2021/04/02 → Landsat 없음
# 2021/04/05 → Sentinel-2 없음
# 2021/04/06 → Sentinel-2 없음
# 2021/04/07 → Landsat 없음
# 2021/04/09 → Sentinel-2 없음
# 2021/04/12 → Landsat 없음
# 2021/04/13 → Sentinel-2 없음
# 2021/04/14 → Landsat 없음
# 2021/04/15 → Sentinel-2 없음
# 2021/04/16 → Sentinel-2 없음
# 2021/04/19 → Landsat 없음
# 2021/04/20 → Sentinel-2 없음
# 2021/04/22 → Landsat 없음
# 2021/04/26 → Sentinel-2 없음
# 2021/04/27 → Landsat 없음
# 2021/05/03 → Sentinel-2 없음
# 2021/05/04 → Landsat 없음
# 2021/05/06 → Sentinel-2 없음
# 2021/05/10 → Sentinel-2 없음
# 2021/05/11 → Sentinel-2 없음
# 2021/05/12 → Landsat 없음
# 2021/05/13 → Sentinel-2 없음
# 2021/05/18 → Sentinel-2 없음
# 2021/05/20 → Sentinel-2 없음
# 2021/05/24 → Landsat 없음
# 2021/05/25 → Sentinel-2 없음
# 2021/05/31 → Sentinel-2 없음
# 2021/06/01 → Landsat 없음
# 2021/06/02 → Sentinel-2 없음
# 2021/06/03 → Sentinel-2 없음
# 2021/06/04 → Sentinel-2 없음
# 2021/06/07 → Sentinel-2 없음
# 2021/06/08 → Landsat 없음
# 2021/06/10 → Sentinel-2 없음
# 2021/06/14 → Sentinel-2 없음
# 2021/06/15 → Sentinel-2 없음
# 2021/06/21 → Landsat 없음
# 2021/06/22 → Sentinel-2 없음
# 2021/06/28 → Landsat 없음
# 2021/06/29 → Sentinel-2 없음
# 2021/07/01 → Landsat 없음
# 2021/07/02 → Sentinel-2 없음
# 2021/07/05 → Sentinel-2 없음
# 2021/07/07 → Sentinel-2 없음
# 2021/07/08 → Sentinel-2 없음
# 2021/07/12 → Sentinel-2 없음
# 2021/07/14 → Sentinel-2 없음
# 2021/07/15 → Sentinel-2 없음
# 2021/07/19 → Sentinel-2 없음
# 2021/07/20 → Sentinel-2 없음
# 2021/07/26 → Landsat 없음
# 2021/07/27 → Sentinel-2 없음
# 2021/08/02 → Landsat 없음
# 2021/08/03 → Sentinel-2 없음
# 2021/08/04 → Sentinel-2 없음
# 2021/08/09 → Sentinel-2 없음
# 2021/08/10 → Landsat 없음
# 2021/08/11 → Sentinel-2 없음
# 2021/08/12 → Sentinel-2 없음
# 2021/08/17 → Landsat 없음
# 2021/08/18 → Sentinel-2 없음
# 2021/08/23 → Sentinel-2 없음
# 2021/08/25 → Landsat 없음
# 2021/08/26 → Sentinel-2 없음
# 2021/08/31 → Sentinel-2 없음
# 2021/09/01 → Landsat 없음
# 2021/09/02 → Sentinel-2 없음
# 2021/09/07 → Sentinel-2 없음
# 2021/09/08 → Sentinel-2 없음
# 2021/09/09 → Landsat 없음
# 2021/09/10 → Sentinel-2 없음
# 2021/09/13 → Sentinel-2 없음
# 2021/09/15 → Sentinel-2 없음
# 2021/09/23 → Sentinel-2 없음
# 2021/09/27 → Sentinel-2 없음
# 2021/09/28 → Sentinel-2 없음
# 2021/10/05 → Sentinel-2 없음
# 2021/10/06 → Landsat 없음
# 2021/10/07 → Sentinel-2 없음
# 2021/10/08 → Sentinel-2 없음
# 2021/10/12 → Sentinel-2 없음
# 2021/10/13 → Sentinel-2 없음
# 2021/10/14 → Landsat 없음
# 2021/10/15 → Sentinel-2 없음
# 2021/10/18 → Sentinel-2 없음
# 2021/10/19 → Landsat 없음
# 2021/10/21 → Landsat 없음
# 2021/10/25 → Sentinel-2 없음
# 2021/10/26 → Sentinel-2 없음
# 2021/11/01 → Sentinel-2 없음
# 2021/11/02 → Sentinel-2 없음
# 2021/11/03 → Landsat 없음
# 2021/11/04 → Sentinel-2 없음
# 2021/11/08 → Landsat 없음
# 2021/11/09 → Sentinel-2 없음
# 2021/11/10 → Sentinel-2 없음
# 2021/11/11 → Sentinel-2 없음
# 2021/11/12 → Sentinel-2 없음
# 2021/11/15 → Landsat 없음
# 2021/11/16 → Sentinel-2 없음
# 2021/11/17 → Sentinel-2 없음
# 2021/11/19 → Sentinel-2 없음
# 2021/11/22 → Sentinel-2 없음
# 2021/11/23 → Landsat 없음
# 2021/11/24 → Sentinel-2 없음
# 2021/11/29 → Sentinel-2 없음
# 2021/11/30 → Sentinel-2 없음
# 2021/12/01 → Sentinel-2 없음
# 2021/12/02 → Sentinel-2 없음
# 2021/12/03 → Landsat 없음
# 2021/12/06 → Sentinel-2 없음
# 2021/12/07 → Sentinel-2 없음
# 2021/12/08 → Landsat 없음
# 2021/12/09 → Sentinel-2 없음
# 2021/12/10 → Sentinel-2 없음
# 2021/12/14 → Sentinel-2 없음
# 2021/12/15 → Sentinel-2 없음
# 2021/12/21 → Sentinel-2 없음
# 2021/12/27 → Sentinel-2 없음
# 2022/01/03 → Sentinel-2 없음
# 2022/01/05 → Sentinel-2 없음
# 2022/01/06 → Sentinel-2 없음
# 2022/01/07 → Landsat 없음
# 2022/01/10 → Sentinel-2 없음
# 2022/01/11 → Sentinel-2 없음
# 2022/01/12 → Landsat 없음
# 2022/01/17 → Landsat 없음
# 2022/01/18 → Sentinel-2 없음
# 2022/01/19 → Sentinel-2 없음
# 2022/01/24 → Landsat 없음
# 2022/01/25 → Sentinel-2 없음
# 2022/02/03 → Landsat 없음
# 2022/02/04 → Sentinel-2 없음
# 2022/02/07 → Sentinel-2 없음
# 2022/02/08 → Landsat 없음
# 2022/02/09 → Sentinel-2 없음
# 2022/02/10 → Sentinel-2 없음
# 2022/02/14 → Sentinel-2 없음
# 2022/02/15 → Sentinel-2 없음
# 2022/02/22 → Sentinel-2 없음
# 2022/02/24 → Sentinel-2 없음
# 2022/02/28 → Landsat 없음
# 2022/03/02 → Sentinel-2 없음
# 2022/03/03 → Landsat 없음
# 2022/03/04 → Sentinel-2 없음
# 2022/03/07 → Sentinel-2 없음
# 2022/03/08 → Landsat 없음
# 2022/03/11 → Sentinel-2 없음
# 2022/03/14 → Sentinel-2 없음
# 2022/03/15 → Landsat 없음
# 2022/03/16 → Sentinel-2 없음
# 2022/03/17 → Sentinel-2 없음
# 2022/03/21 → Sentinel-2 없음
# 2022/03/22 → Sentinel-2 없음
# 2022/03/23 → Landsat 없음
# 2022/03/28 → Landsat 없음
# 2022/03/29 → Sentinel-2 없음
# 2022/04/05 → Sentinel-2 없음
# 2022/04/06 → Sentinel-2 없음
# 2022/04/07 → Landsat 없음
# 2022/04/08 → Sentinel-2 없음
# 2022/04/11 → Sentinel-2 없음
# 2022/04/13 → Sentinel-2 없음
# 2022/04/14 → Landsat 없음
# 2022/04/18 → Sentinel-2 없음
# 2022/04/19 → Sentinel-2 없음
# 2022/04/20 → Sentinel-2 없음
# 2022/04/21 → Sentinel-2 없음
# 2022/04/25 → Sentinel-2 없음
# 2022/04/26 → Sentinel-2 없음
# 2022/05/02 → Landsat 없음
# 2022/05/03 → Sentinel-2 없음
# 2022/05/09 → Landsat 없음
# 2022/05/10 → Sentinel-2 없음
# 2022/05/11 → Sentinel-2 없음
# 2022/05/12 → Sentinel-2 없음
# 2022/05/16 → Sentinel-2 없음
# 2022/05/17 → Landsat 없음
# 2022/05/18 → Sentinel-2 없음
# 2022/05/19 → Sentinel-2 없음
# 2022/05/23 → Sentinel-2 없음
# 2022/05/24 → Sentinel-2 없음
# 2022/05/25 → Sentinel-2 없음
# 2022/05/26 → Sentinel-2 없음
# 2022/05/30 → Sentinel-2 없음
# 2022/05/31 → Sentinel-2 없음
# 2022/06/02 → Sentinel-2 없음
# 2022/06/03 → Sentinel-2 없음
# 2022/06/07 → Sentinel-2 없음
# 2022/06/08 → Landsat 없음
# 2022/06/09 → Sentinel-2 없음
# 2022/06/14 → Sentinel-2 없음
# 2022/06/15 → Sentinel-2 없음
# 2022/06/17 → Sentinel-2 없음
# 2022/06/20 → Sentinel-2 없음
# 2022/06/27 → Sentinel-2 없음
# 2022/06/28 → Sentinel-2 없음
# 2022/07/04 → Sentinel-2 없음
# 2022/07/05 → Sentinel-2 없음
# 2022/07/06 → Landsat 없음
# 2022/07/07 → Sentinel-2 없음
# 2022/07/08 → Sentinel-2 없음
# 2022/07/11 → Landsat 없음
# 2022/07/12 → Sentinel-2 없음
# 2022/07/14 → Sentinel-2 없음
# 2022/07/18 → Landsat 없음
# 2022/07/19 → Sentinel-2 없음
# 2022/07/20 → Sentinel-2 없음
# 2022/07/25 → Sentinel-2 없음
# 2022/07/26 → Landsat 없음
# 2022/08/01 → Sentinel-2 없음
# 2022/08/02 → Landsat 없음
# 2022/08/03 → Sentinel-2 없음
# 2022/08/04 → Sentinel-2 없음
# 2022/08/08 → Sentinel-2 없음
# 2022/08/09 → Sentinel-2 없음
# 2022/08/16 → Sentinel-2 없음
# 2022/08/17 → Sentinel-2 없음
# 2022/08/19 → Sentinel-2 없음
# 2022/08/22 → Landsat 없음
# 2022/08/23 → Sentinel-2 없음
# 2022/08/25 → Landsat 없음
# 2022/08/29 → Sentinel-2 없음
# 2022/08/30 → Landsat 없음
# 2022/09/02 → Sentinel-2 없음
# 2022/09/05 → Sentinel-2 없음
# 2022/09/06 → Sentinel-2 없음
# 2022/09/07 → Sentinel-2 없음
# 2022/09/13 → Sentinel-2 없음
# 2022/09/14 → Landsat 없음
# 2022/09/15 → Sentinel-2 없음
# 2022/09/19 → Landsat 없음
# 2022/09/20 → Sentinel-2 없음
# 2022/09/21 → Sentinel-2 없음
# 2022/09/22 → Sentinel-2 없음
# 2022/09/27 → Sentinel-2 없음
# 2022/10/04 → Landsat 없음
# 2022/10/05 → Sentinel-2 없음
# 2022/10/06 → Landsat 없음
# 2022/10/07 → Sentinel-2 없음
# 2022/10/12 → Sentinel-2 없음
# 2022/10/13 → Sentinel-2 없음
# 2022/10/17 → Sentinel-2 없음
# 2022/10/18 → Sentinel-2 없음
# 2022/10/20 → Sentinel-2 없음
# 2022/10/24 → Landsat 없음
# 2022/10/25 → Sentinel-2 없음
# 2022/10/31 → Landsat 없음
# 2022/11/01 → Sentinel-2 없음
# 2022/11/02 → Sentinel-2 없음
# 2022/11/03 → Landsat 없음
# 2022/11/07 → Sentinel-2 없음
# 2022/11/08 → Landsat 없음
# 2022/11/09 → Sentinel-2 없음
# 2022/11/10 → Sentinel-2 없음
# 2022/11/14 → Sentinel-2 없음
# 2022/11/15 → Landsat 없음
# 2022/11/16 → Sentinel-2 없음
# 2022/11/17 → Sentinel-2 없음
# 2022/11/21 → Sentinel-2 없음
# 2022/11/22 → Sentinel-2 없음
# 2022/11/23 → Landsat 없음
# 2022/11/29 → Sentinel-2 없음
# 2022/12/01 → Sentinel-2 없음
# 2022/12/05 → Landsat 없음
# 2022/12/06 → Sentinel-2 없음
# 2022/12/07 → Sentinel-2 없음
# 2022/12/08 → Landsat 없음
# 2022/12/12 → Sentinel-2 없음
# 2022/12/13 → Landsat 없음
# 2022/12/14 → Sentinel-2 없음
# 2022/12/19 → Sentinel-2 없음
# 2022/12/27 → Sentinel-2 없음
# 2023/01/02 → Landsat 없음
# 2023/01/03 → Sentinel-2 없음
# 2023/01/04 → Landsat 없음
# 2023/01/05 → Sentinel-2 없음
# 2023/01/06 → Sentinel-2 없음
# 2023/01/09 → Landsat 없음
# 2023/01/10 → Sentinel-2 없음
# 2023/01/11 → Sentinel-2 없음
# 2023/01/16 → Sentinel-2 없음
# 2023/01/17 → Landsat 없음
# 2023/01/18 → Sentinel-2 없음
# 2023/01/25 → Sentinel-2 없음
# 2023/01/30 → Sentinel-2 없음
# 2023/01/31 → Sentinel-2 없음
# 2023/02/02 → Sentinel-2 없음
# 2023/02/06 → Landsat 없음
# 2023/02/07 → Sentinel-2 없음
# 2023/02/08 → Sentinel-2 없음
# 2023/02/09 → Sentinel-2 없음
# 2023/02/13 → Landsat 없음
# 2023/02/14 → Sentinel-2 없음
# 2023/02/20 → Sentinel-2 없음
# 2023/02/21 → Landsat 없음
# 2023/02/23 → Sentinel-2 없음
# 2023/02/27 → Sentinel-2 없음
# 2023/02/28 → Sentinel-2 없음
# 2023/03/06 → Sentinel-2 없음
# 2023/03/07 → Sentinel-2 없음
# 2023/03/08 → Landsat 없음
# 2023/03/09 → Sentinel-2 없음
# 2023/03/14 → Sentinel-2 없음
# 2023/03/15 → Sentinel-2 없음
# 2023/03/21 → Sentinel-2 없음
# 2023/03/23 → Landsat 없음
# 2023/03/24 → Sentinel-2 없음
# 2023/03/27 → Sentinel-2 없음
# 2023/04/03 → Sentinel-2 없음
# 2023/04/04 → Landsat 없음
# 2023/04/05 → Sentinel-2 없음
# 2023/04/06 → Sentinel-2 없음
# 2023/04/07 → Landsat 없음
# 2023/04/10 → Sentinel-2 없음
# 2023/04/11 → Sentinel-2 없음
# 2023/04/12 → Landsat 없음
# 2023/04/13 → Sentinel-2 없음
# 2023/04/17 → Landsat 없음
# 2023/04/18 → Sentinel-2 없음
# 2023/04/24 → Landsat 없음
# 2023/04/25 → Sentinel-2 없음
# 2023/05/01 → Sentinel-2 없음
# 2023/05/02 → Landsat 없음
# 2023/05/03 → Sentinel-2 없음
# 2023/05/04 → Landsat 없음
# 2023/05/08 → Sentinel-2 없음
# 2023/05/10 → Sentinel-2 없음
# 2023/05/11 → Sentinel-2 없음
# 2023/05/12 → Landsat 없음
# 2023/05/15 → Sentinel-2 없음
# 2023/05/16 → Sentinel-2 없음
# 2023/05/22 → Landsat 없음
# 2023/05/23 → Sentinel-2 없음
# 2023/05/30 → Sentinel-2 없음
# 2023/05/31 → Sentinel-2 없음
# 2023/06/05 → Sentinel-2 없음
# 2023/06/07 → Sentinel-2 없음
# 2023/06/08 → Landsat 없음
# 2023/06/09 → Sentinel-2 없음
# 2023/06/12 → Sentinel-2 없음
# 2023/06/13 → Landsat 없음
# 2023/06/14 → Sentinel-2 없음
# 2023/06/15 → Sentinel-2 없음
# 2023/06/19 → Sentinel-2 없음
# 2023/06/20 → Sentinel-2 없음
# 2023/06/23 → Sentinel-2 없음
# 2023/06/26 → Landsat 없음
# 2023/06/27 → Sentinel-2 없음
# 2023/06/28 → Sentinel-2 없음
# 2023/07/04 → Sentinel-2 없음
# 2023/07/05 → Sentinel-2 없음
# 2023/07/06 → Landsat 없음
# 2023/07/10 → Sentinel-2 없음
# 2023/07/11 → Landsat 없음
# 2023/07/12 → Sentinel-2 없음
# 2023/07/13 → Landsat 없음
# 2023/07/17 → Sentinel-2 없음
# 2023/07/18 → Sentinel-2 없음
# 2023/07/20 → Sentinel-2 없음
# 2023/07/24 → Sentinel-2 없음
# 2023/07/31 → Landsat 없음
# 2023/08/01 → Sentinel-2 없음
# 2023/08/02 → Landsat 없음
# 2023/08/03 → Sentinel-2 없음
# 2023/08/04 → Sentinel-2 없음
# 2023/08/07 → Landsat 없음
# 2023/08/08 → Sentinel-2 없음
# 2023/08/09 → Sentinel-2 없음
# 2023/08/11 → Sentinel-2 없음
# 2023/08/14 → Sentinel-2 없음
# 2023/08/16 → Sentinel-2 없음
# 2023/08/17 → Sentinel-2 없음
# 2023/08/21 → Sentinel-2 없음
# 2023/08/22 → Landsat 없음
# 2023/08/28 → Sentinel-2 없음
# 2023/08/29 → Sentinel-2 없음
# 2023/08/30 → Landsat 없음
# 2023/09/05 → Sentinel-2 없음
# 2023/09/07 → Sentinel-2 없음
# 2023/09/08 → Sentinel-2 없음
# 2023/09/11 → Landsat 없음
# 2023/09/12 → Sentinel-2 없음
# 2023/09/13 → Sentinel-2 없음
# 2023/09/14 → Landsat 없음
# 2023/09/18 → Sentinel-2 없음
# 2023/09/19 → Landsat 없음
# 2023/09/25 → Sentinel-2 없음
# 2023/09/26 → Sentinel-2 없음
# 2023/10/04 → Landsat 없음
# 2023/10/05 → Sentinel-2 없음
# 2023/10/06 → Sentinel-2 없음
# 2023/10/10 → Sentinel-2 없음
# 2023/10/11 → Landsat 없음
# 2023/10/12 → Sentinel-2 없음
# 2023/10/13 → Sentinel-2 없음
# 2023/10/16 → Landsat 없음
# 2023/10/17 → Sentinel-2 없음
# 2023/10/23 → Sentinel-2 없음
# 2023/10/26 → Sentinel-2 없음
# 2023/10/30 → Sentinel-2 없음
# 2023/10/31 → Sentinel-2 없음
# 2023/11/01 → Sentinel-2 없음
# 2023/11/02 → Sentinel-2 없음
# 2023/11/06 → Sentinel-2 없음
# 2023/11/07 → Sentinel-2 없음
# 2023/11/09 → Sentinel-2 없음
# 2023/11/10 → Sentinel-2 없음
# 2023/11/13 → Landsat 없음
# 2023/11/14 → Sentinel-2 없음
# 2023/11/15 → Sentinel-2 없음
# 2023/11/16 → Sentinel-2 없음
# 2023/11/20 → Landsat 없음
# 2023/11/21 → Sentinel-2 없음
# 2023/11/22 → Sentinel-2 없음
# 2023/11/27 → Sentinel-2 없음
# 2023/11/28 → Landsat 없음
# 2023/12/01 → Sentinel-2 없음
# 2023/12/04 → Sentinel-2 없음
# 2023/12/05 → Landsat 없음
# 2023/12/06 → Sentinel-2 없음
# 2023/12/07 → Sentinel-2 없음
# 2023/12/11 → Sentinel-2 없음
# 2023/12/12 → Sentinel-2 없음
# 2023/12/13 → Landsat 없음
# 2023/12/15 → Landsat 없음
# 2023/12/19 → Sentinel-2 없음
# 2023/12/26 → Sentinel-2 없음
# 2024/01/03 → Sentinel-2 없음
# 2024/01/05 → Sentinel-2 없음
# 2024/01/08 → Sentinel-2 없음
# 2024/01/09 → Landsat 없음
# 2024/01/10 → Sentinel-2 없음
# 2024/01/11 → Sentinel-2 없음
# 2024/01/12 → Sentinel-2 없음
# 2024/01/15 → Sentinel-2 없음
# 2024/01/16 → Sentinel-2 없음
# 2024/01/17 → Landsat 없음
# 2024/01/22 → Landsat 없음
# 2024/01/23 → Sentinel-2 없음
# 2024/01/29 → Landsat 없음
# 2024/01/30 → Sentinel-2 없음
# 2024/02/01 → Landsat 없음
# 2024/02/02 → Sentinel-2 없음
# 2024/02/05 → Sentinel-2 없음
# 2024/02/06 → Landsat 없음
# 2024/02/07 → Sentinel-2 없음
# 2024/02/14 → Sentinel-2 없음
# 2024/02/15 → Sentinel-2 없음
# 2024/02/16 → Landsat 없음
# 2024/02/19 → Sentinel-2 없음
# 2024/02/20 → Sentinel-2 없음
# 2024/02/26 → Landsat 없음
# 2024/02/27 → Sentinel-2 없음
# 2024/03/04 → Landsat 없음
# 2024/03/05 → Sentinel-2 없음
# 2024/03/06 → Sentinel-2 없음
# 2024/03/11 → Sentinel-2 없음
# 2024/03/12 → Landsat 없음
# 2024/03/13 → Sentinel-2 없음
# 2024/03/14 → Sentinel-2 없음
# 2024/03/15 → Sentinel-2 없음
# 2024/03/18 → Sentinel-2 없음
# 2024/03/19 → Landsat 없음
# 2024/03/20 → Sentinel-2 없음
# 2024/03/25 → Sentinel-2 없음
# 2024/04/02 → Sentinel-2 없음
# 2024/04/03 → Landsat 없음
# 2024/04/04 → Sentinel-2 없음
# 2024/04/09 → Sentinel-2 없음
# 2024/04/11 → Landsat 없음
# 2024/04/12 → Sentinel-2 없음
# 2024/04/15 → Sentinel-2 없음
# 2024/04/18 → Sentinel-2 없음
# 2024/04/22 → Sentinel-2 없음
# 2024/04/23 → Sentinel-2 없음
# 2024/04/24 → Sentinel-2 없음
# 2024/04/29 → Sentinel-2 없음
# 2024/04/30 → Sentinel-2 없음
# 2024/05/02 → Sentinel-2 없음
# 2024/05/03 → Landsat 없음
# 2024/05/07 → Sentinel-2 없음
# 2024/05/08 → Landsat 없음
# 2024/05/09 → Sentinel-2 없음
# 2024/05/10 → Sentinel-2 없음
# 2024/05/13 → Landsat 없음
# 2024/05/14 → Sentinel-2 없음
# 2024/05/16 → Landsat 없음
# 2024/05/20 → Sentinel-2 없음
# 2024/05/21 → Landsat 없음
# 2024/05/22 → Sentinel-2 없음
# 2024/05/27 → Sentinel-2 없음
# 2024/05/28 → Landsat 없음
# 2024/06/03 → Sentinel-2 없음
# 2024/06/04 → Sentinel-2 없음
# 2024/06/05 → Landsat 없음
# 2024/06/11 → Sentinel-2 없음
# 2024/06/13 → Sentinel-2 없음
# 2024/06/17 → Landsat 없음
# 2024/06/18 → Sentinel-2 없음
# 2024/06/21 → Sentinel-2 없음
# 2024/06/24 → Sentinel-2 없음
# 2024/06/25 → Landsat 없음
# 2024/07/01 → Sentinel-2 없음
# 2024/07/02 → Sentinel-2 없음
# 2024/07/03 → Sentinel-2 없음
# 2024/07/04 → Sentinel-2 없음
# 2024/07/08 → Sentinel-2 없음
# 2024/07/09 → Sentinel-2 없음
# 2024/07/10 → Landsat 없음
# 2024/07/11 → Sentinel-2 없음
# 2024/07/15 → Landsat 없음
# 2024/07/16 → Sentinel-2 없음
# 2024/07/17 → Landsat 없음
# 2024/07/19 → Sentinel-2 없음
# 2024/07/22 → Landsat 없음
# 2024/07/23 → Sentinel-2 없음
# 2024/07/29 → Sentinel-2 없음
# 2024/07/30 → Landsat 없음
# 2024/08/01 → Landsat 없음
# 2024/08/02 → Sentinel-2 없음
# 2024/08/05 → Sentinel-2 없음
# 2024/08/07 → Sentinel-2 없음
# 2024/08/08 → Sentinel-2 없음
# 2024/08/12 → Sentinel-2 없음
# 2024/08/13 → Sentinel-2 없음
# 2024/08/19 → Landsat 없음
# 2024/08/20 → Sentinel-2 없음
# 2024/08/26 → Landsat 없음
# 2024/08/27 → Sentinel-2 없음
# 2024/09/02 → Sentinel-2 없음
# 2024/09/03 → Landsat 없음
# 2024/09/04 → Sentinel-2 없음
# 2024/09/05 → Landsat 없음
# 2024/09/06 → Sentinel-2 없음
# 2024/09/09 → Sentinel-2 없음
# 2024/09/10 → Landsat 없음
# 2024/09/11 → Sentinel-2 없음
# 2024/09/19 → Sentinel-2 없음
# 2024/10/02 → Sentinel-2 없음
# 2024/10/07 → Sentinel-2 없음
# 2024/10/11 → Sentinel-2 없음
# 2024/10/14 → Sentinel-2 없음
# 2024/10/15 → Landsat 없음
# 2024/10/16 → Sentinel-2 없음
# 2024/10/17 → Sentinel-2 없음
# 2024/10/21 → Sentinel-2 없음
# 2024/10/22 → Sentinel-2 없음
# 2024/10/28 → Landsat 없음
# 2024/10/29 → Sentinel-2 없음
# 2024/11/01 → Sentinel-2 없음
# 2024/11/04 → Landsat 없음
# 2024/11/05 → Sentinel-2 없음
# 2024/11/06 → Sentinel-2 없음
# 2024/11/07 → Landsat 없음
# 2024/11/11 → Sentinel-2 없음
# 2024/11/12 → Landsat 없음
# 2024/11/13 → Sentinel-2 없음
# 2024/11/18 → Sentinel-2 없음
# 2024/11/19 → Sentinel-2 없음
# 2024/11/25 → Sentinel-2 없음
# 2024/11/26 → Sentinel-2 없음
# 2024/12/02 → Landsat 없음
# 2024/12/03 → Sentinel-2 없음
# 2024/12/05 → Sentinel-2 없음
# 2024/12/06 → Sentinel-2 없음
# 2024/12/09 → Landsat 없음
# 2024/12/10 → Sentinel-2 없음
# 2024/12/11 → Sentinel-2 없음
# 2024/12/16 → Sentinel-2 없음
# 2024/12/17 → Landsat 없음
# 2024/12/23 → Sentinel-2 없음
# 2024/12/30 → Sentinel-2 없음
# 2025/01/02 → Sentinel-2 없음
# 2025/01/07 → Sentinel-2 없음
# 2025/01/08 → Sentinel-2 없음
# 2025/01/09 → Sentinel-2 없음
# 2025/01/14 → Sentinel-2 없음
# 2025/01/15 → Sentinel-2 없음
# 2025/01/20 → Sentinel-2 없음
# 2025/02/03 → Sentinel-2 없음
# 2025/02/04 → Sentinel-2 없음
# 2025/02/05 → Landsat 없음
# 2025/02/06 → Sentinel-2 없음
# 2025/02/10 → Landsat 없음
# 2025/02/11 → Sentinel-2 없음
# 2025/02/12 → Landsat 없음
# 2025/02/13 → Sentinel-2 없음
# 2025/02/17 → Landsat 없음
# 2025/02/18 → Sentinel-2 없음
# 2025/02/19 → Sentinel-2 없음
# 2025/02/24 → Sentinel-2 없음
# 2025/02/25 → Landsat 없음
# 2025/03/04 → Landsat 없음
# 2025/03/05 → Sentinel-2 없음
# 2025/03/06 → Sentinel-2 없음
# 2025/03/07 → Landsat 없음
# 2025/03/10 → Sentinel-2 없음
# 2025/03/11 → Sentinel-2 없음
# 2025/03/12 → Landsat 없음
# 2025/03/13 → Sentinel-2 없음
# 2025/03/18 → Sentinel-2 없음
# 2025/03/20 → Sentinel-2 없음
# 2025/03/24 → Landsat 없음
# 2025/03/31 → Sentinel-2 없음
# 2025/04/01 → Landsat 없음
# 2025/04/02 → Sentinel-2 없음
# 2025/04/04 → Sentinel-2 없음
# 2025/04/07 → Sentinel-2 없음
# 2025/04/08 → Landsat 없음
# 2025/04/09 → Sentinel-2 없음
# 2025/04/10 → Sentinel-2 없음
# 2025/04/14 → Sentinel-2 없음
# 2025/04/15 → Sentinel-2 없음
# 2025/04/16 → Landsat 없음
# 2025/04/21 → Landsat 없음
# 2025/04/28 → Landsat 없음
# 2025/05/07 → Sentinel-2 없음
# 2025/05/08 → Landsat 없음
# 2025/05/09 → Sentinel-2 없음
# 2025/05/12 → Sentinel-2 없음
# 2025/05/14 → Sentinel-2 없음
# 2025/05/15 → Sentinel-2 없음
# 2025/05/19 → Sentinel-2 없음
# 2025/05/20 → Sentinel-2 없음
# 2025/05/22 → Sentinel-2 없음
# 2025/05/26 → Landsat 없음
# 2025/06/02 → Landsat 없음
# 2025/06/04 → Sentinel-2 없음
# 2025/06/09 → Sentinel-2 없음
# 2025/06/10 → Landsat 없음
# 2025/06/11 → Sentinel-2 없음
# 2025/06/12 → Landsat 없음
# 2025/06/16 → Sentinel-2 없음
# 2025/06/17 → Landsat 없음
# 2025/06/18 → Sentinel-2 없음
# 2025/06/23 → Sentinel-2 없음
# 2025/07/01 → Sentinel-2 없음
# 2025/07/02 → Landsat 없음
# 2025/07/03 → Sentinel-2 없음
# 2025/07/08 → Sentinel-2 없음
# 2025/07/09 → Landsat 없음
# 2025/07/10 → Landsat 없음
# 2025/07/14 → Sentinel-2 없음
# 2025/07/15 → Landsat 없음
# 2025/07/21 → Sentinel-2 없음
# 2025/07/22 → Landsat 없음
# 2025/07/23 → Sentinel-2 없음
# 2025/07/24 → Sentinel-2 없음
# 2025/07/28 → Sentinel-2 없음
# 2025/08/04 → Landsat 없음
# 2025/08/05 → Sentinel-2 없음
# 2025/08/06 → Landsat 없음
# 2025/08/07 → Sentinel-2 없음
# 2025/08/11 → Landsat 없음
# 2025/08/12 → Sentinel-2 없음
# 2025/08/13 → Sentinel-2 없음
# 2025/08/14 → Landsat 없음
# 2025/08/18 → Landsat 없음
# 2025/08/20 → Sentinel-2 없음
# 2025/08/25 → Sentinel-2 없음
# 2025/08/27 → Sentinel-2 없음
# 2025/08/28 → Sentinel-2 없음
# 2025/09/01 → Sentinel-2 없음
# 2025/09/02 → Sentinel-2 없음
# 2025/09/04 → Sentinel-2 없음
# 2025/09/08 → Landsat 없음
# 2025/09/09 → Sentinel-2 없음
# 2025/09/11 → Sentinel-2 없음
# 2025/09/15 → Landsat 없음
# 2025/09/22 → Sentinel-2 없음
# 2025/09/23 → Landsat 없음
# 2025/09/25 → Sentinel-2 없음
# 2025/09/29 → Sentinel-2 없음
# 2025/10/01 → Sentinel-2 없음
# 2025/10/02 → Sentinel-2 없음
# 2025/10/10 → Landsat 없음
# 2025/10/13 → Landsat 없음
# 2025/10/14 → Sentinel-2 없음
# 2025/10/15 → Landsat 없음
# 2025/10/16 → Sentinel-2 없음
# 2025/10/20 → Landsat 없음
# 2025/10/21 → Sentinel-2 없음
# 2025/10/23 → Landsat 없음
# 2025/10/24 → Sentinel-2 없음
# 2025/10/27 → Sentinel-2 없음
# 2025/10/30 → Landsat 없음

# %%
results = []

for date, group in total_df.groupby("년/월/일"):

    obs_date = pd.to_datetime(date)
    start = obs_date.strftime("%Y-%m-%d")
    end   = (obs_date + timedelta(days=1)).strftime("%Y-%m-%d")

    # -----------------------------------
    # 관측 지점 → FeatureCollection
    # (Landsat용 buffer 적용)
    # -----------------------------------
    s2_features  = []
    lst_features = []

    for idx, row in group.iterrows():
        lon = dms_to_dd(row["경도"])
        lat = dms_to_dd(row["위도"])

        # Sentinel-2: point
        pt_s2 = ee.Geometry.Point([lon, lat])
        s2_features.append(
            ee.Feature(pt_s2, {"idx": idx})
        )

        # Landsat: buffer (60 m)
        pt_lst = ee.Geometry.Point([lon, lat]).buffer(60)
        lst_features.append(
            ee.Feature(pt_lst, {"idx": idx})
        )

    fc_s2  = ee.FeatureCollection(s2_features)
    fc_lst = ee.FeatureCollection(lst_features)

    # -----------------------------------
    # Sentinel-2
    # -----------------------------------
    s2_img = (S2
              .filterBounds(fc_s2)
              .filterDate(start, end)
              .sort("system:time_start", False)
              .first())

    if s2_img.getInfo() is None:
        print(date, "→ Sentinel-2 없음")
        continue

    s2_selected = s2_img.select([
        "SCL",
        "B1","B2","B3","B4","B5","B6","B7",
        "B8","B8A","B9","B11","B12"
    ])

    s2_reduced = s2_selected.reduceRegions(
        collection = fc_s2,
        reducer    = ee.Reducer.first(),
        scale      = 10
    )

    s2_rows = s2_reduced.getInfo()["features"]

    # -----------------------------------
    # Landsat LST
    # -----------------------------------
    lst_img = (Landsat
               .filterBounds(fc_lst)
               .filterDate(start, end)
               .sort("system:time_start", False)
               .first())

    if lst_img.getInfo() is None:
        print(date, "→ Landsat 없음")
        continue

    # ST_B10 → 섭씨
    lst_selected = (
        lst_img.select("ST_B10")
        .multiply(0.00341802)
        .add(149.0)
        .subtract(273.15)
        .rename("LST")
    )

    # buffer 영역 평균값 사용
    lst_reduced = lst_selected.reduceRegions(
        collection = fc_lst,
        reducer    = ee.Reducer.mean(),
        scale      = 30
    )

    # idx → LST 매핑
    lst_rows = {
        f["properties"]["idx"]: f["properties"]["LST"]
        for f in lst_reduced.getInfo()["features"]
        if "LST" in f["properties"] and f["properties"]["LST"] is not None
    }

    # -----------------------------------
    # Sentinel + Landsat 병합
    # -----------------------------------
    for item in s2_rows:
        props = item["properties"]
        idx   = props["idx"]

        # Sentinel-2 SCL 필터 (수체)
        scl = props.get("SCL", None)
        if scl not in [2, 6, 7]:
            continue

        # Landsat LST 없는 지점 제거
        if idx not in lst_rows:
            continue

        out = total_df.loc[idx].to_dict()

        # Sentinel-2 밴드
        out.update(props)

        # Landsat LST
        out["LST"] = lst_rows[idx]

        # 메타정보
        out["image_id_S2"]       = s2_img.get("system:index").getInfo()
        out["image_id_Landsat"]  = lst_img.get("system:index").getInfo()

        results.append(out)

df_out = pd.DataFrame(results)
# Out:
# 2018/01/02 → Sentinel-2 없음
# 2018/01/03 → Sentinel-2 없음
# 2018/01/04 → Sentinel-2 없음
# 2018/01/05 → Sentinel-2 없음
# 2018/01/08 → Sentinel-2 없음
# 2018/01/09 → Sentinel-2 없음
# 2018/01/10 → Sentinel-2 없음
# 2018/01/12 → Sentinel-2 없음
# 2018/01/15 → Sentinel-2 없음
# 2018/01/19 → Sentinel-2 없음
# 2018/01/22 → Sentinel-2 없음
# 2018/01/23 → Sentinel-2 없음
# 2018/01/29 → Sentinel-2 없음
# 2018/02/01 → Sentinel-2 없음
# 2018/02/02 → Sentinel-2 없음
# 2018/02/05 → Sentinel-2 없음
# 2018/02/06 → Sentinel-2 없음
# 2018/02/08 → Sentinel-2 없음
# 2018/02/09 → Sentinel-2 없음
# 2018/02/12 → Sentinel-2 없음
# 2018/02/14 → Sentinel-2 없음
# 2018/02/19 → Sentinel-2 없음
# 2018/02/20 → Sentinel-2 없음
# 2018/02/22 → Landsat 없음
# 2018/02/26 → Sentinel-2 없음
# 2018/02/27 → Sentinel-2 없음
# 2018/02/28 → Sentinel-2 없음
# 2018/03/02 → Sentinel-2 없음
# 2018/03/05 → Sentinel-2 없음
# 2018/03/06 → Sentinel-2 없음
# 2018/03/07 → Sentinel-2 없음
# 2018/03/08 → Sentinel-2 없음
# 2018/03/09 → Landsat 없음
# 2018/03/12 → Sentinel-2 없음
# 2018/03/13 → Sentinel-2 없음
# 2018/03/14 → Sentinel-2 없음
# 2018/03/15 → Sentinel-2 없음
# 2018/03/19 → Landsat 없음
# 2018/03/20 → Sentinel-2 없음
# 2018/03/23 → Sentinel-2 없음
# 2018/03/26 → Sentinel-2 없음
# 2018/03/27 → Sentinel-2 없음
# 2018/04/02 → Sentinel-2 없음
# 2018/04/03 → Sentinel-2 없음
# 2018/04/04 → Sentinel-2 없음
# 2018/04/05 → Sentinel-2 없음
# 2018/04/06 → Sentinel-2 없음
# 2018/04/09 → Sentinel-2 없음
# 2018/04/10 → Sentinel-2 없음
# 2018/04/11 → Sentinel-2 없음
# 2018/04/12 → Sentinel-2 없음
# 2018/04/16 → Sentinel-2 없음
# 2018/04/17 → Sentinel-2 없음
# 2018/04/19 → Sentinel-2 없음
# 2018/04/23 → Sentinel-2 없음
# 2018/04/25 → Sentinel-2 없음
# 2018/04/30 → Sentinel-2 없음
# 2018/05/01 → Sentinel-2 없음
# 2018/05/02 → Sentinel-2 없음
# 2018/05/03 → Sentinel-2 없음
# 2018/05/04 → Sentinel-2 없음
# 2018/05/07 → Sentinel-2 없음
# 2018/05/08 → Sentinel-2 없음
# 2018/05/10 → Sentinel-2 없음
# 2018/05/11 → Sentinel-2 없음
# 2018/05/14 → Sentinel-2 없음
# 2018/05/15 → Sentinel-2 없음
# 2018/05/16 → Sentinel-2 없음
# 2018/05/21 → Sentinel-2 없음
# 2018/05/23 → Sentinel-2 없음
# 2018/05/28 → Sentinel-2 없음
# 2018/05/29 → Sentinel-2 없음
# 2018/06/01 → Sentinel-2 없음
# 2018/06/04 → Sentinel-2 없음
# 2018/06/05 → Sentinel-2 없음
# 2018/06/07 → Sentinel-2 없음
# 2018/06/08 → Sentinel-2 없음
# 2018/06/11 → Sentinel-2 없음
# 2018/06/12 → Sentinel-2 없음
# 2018/06/14 → Sentinel-2 없음
# 2018/06/15 → Sentinel-2 없음
# 2018/06/18 → Sentinel-2 없음
# 2018/06/21 → Sentinel-2 없음
# 2018/06/25 → Sentinel-2 없음
# 2018/06/26 → Sentinel-2 없음
# 2018/07/02 → Sentinel-2 없음
# 2018/07/03 → Sentinel-2 없음
# 2018/07/04 → Sentinel-2 없음
# 2018/07/05 → Sentinel-2 없음
# 2018/07/09 → Sentinel-2 없음
# 2018/07/10 → Sentinel-2 없음
# 2018/07/11 → Sentinel-2 없음
# 2018/07/12 → Sentinel-2 없음
# 2018/07/13 → Sentinel-2 없음
# 2018/07/16 → Sentinel-2 없음
# 2018/07/17 → Sentinel-2 없음
# 2018/07/19 → Sentinel-2 없음
# 2018/07/23 → Sentinel-2 없음
# 2018/07/24 → Sentinel-2 없음
# 2018/07/30 → Sentinel-2 없음
# 2018/07/31 → Sentinel-2 없음
# 2018/08/01 → Sentinel-2 없음
# 2018/08/02 → Sentinel-2 없음
# 2018/08/03 → Sentinel-2 없음
# 2018/08/06 → Sentinel-2 없음
# 2018/08/07 → Sentinel-2 없음
# 2018/08/08 → Sentinel-2 없음
# 2018/08/09 → Sentinel-2 없음
# 2018/08/13 → Sentinel-2 없음
# 2018/08/14 → Sentinel-2 없음
# 2018/08/16 → Sentinel-2 없음
# 2018/08/20 → Sentinel-2 없음
# 2018/08/21 → Sentinel-2 없음
# 2018/08/27 → Sentinel-2 없음
# 2018/08/28 → Sentinel-2 없음
# 2018/09/03 → Sentinel-2 없음
# 2018/09/04 → Sentinel-2 없음
# 2018/09/05 → Sentinel-2 없음
# 2018/09/06 → Sentinel-2 없음
# 2018/09/10 → Sentinel-2 없음
# 2018/09/11 → Sentinel-2 없음
# 2018/09/12 → Sentinel-2 없음
# 2018/09/13 → Sentinel-2 없음
# 2018/09/14 → Sentinel-2 없음
# 2018/09/17 → Sentinel-2 없음
# 2018/09/18 → Sentinel-2 없음
# 2018/09/27 → Sentinel-2 없음
# 2018/10/01 → Sentinel-2 없음
# 2018/10/02 → Sentinel-2 없음
# 2018/10/04 → Sentinel-2 없음
# 2018/10/08 → Sentinel-2 없음
# 2018/10/10 → Sentinel-2 없음
# 2018/10/11 → Sentinel-2 없음
# 2018/10/12 → Sentinel-2 없음
# 2018/10/15 → Landsat 없음
# 2018/10/16 → Sentinel-2 없음
# 2018/10/17 → Sentinel-2 없음
# 2018/10/22 → Sentinel-2 없음
# 2018/10/23 → Sentinel-2 없음
# 2018/10/24 → Sentinel-2 없음
# 2018/10/29 → Sentinel-2 없음
# 2018/10/30 → Sentinel-2 없음
# 2018/11/01 → Sentinel-2 없음
# 2018/11/02 → Sentinel-2 없음
# 2018/11/05 → Sentinel-2 없음
# 2018/11/06 → Sentinel-2 없음
# 2018/11/07 → Sentinel-2 없음
# 2018/11/08 → Sentinel-2 없음
# 2018/11/09 → Sentinel-2 없음
# 2018/11/12 → Sentinel-2 없음
# 2018/11/13 → Sentinel-2 없음
# 2018/11/14 → Sentinel-2 없음
# 2018/11/19 → Sentinel-2 없음
# 2018/11/20 → Sentinel-2 없음
# 2018/11/22 → Sentinel-2 없음
# 2018/11/26 → Sentinel-2 없음
# 2018/11/27 → Sentinel-2 없음
# 2018/12/03 → Sentinel-2 없음
# 2018/12/04 → Sentinel-2 없음
# 2018/12/05 → Sentinel-2 없음
# 2018/12/06 → Sentinel-2 없음
# 2018/12/07 → Sentinel-2 없음
# 2018/12/10 → Sentinel-2 없음
# 2018/12/11 → Sentinel-2 없음
# 2018/12/12 → Sentinel-2 없음
# 2018/12/13 → Sentinel-2 없음
# 2018/12/17 → Sentinel-2 없음
# 2018/12/18 → Sentinel-2 없음
# 2018/12/24 → Landsat 없음
# 2018/12/26 → Sentinel-2 없음
# 2019/01/02 → Sentinel-2 없음
# 2019/01/03 → Landsat 없음
# 2019/01/04 → Sentinel-2 없음
# 2019/01/07 → Sentinel-2 없음
# 2019/01/08 → Landsat 없음
# 2019/01/09 → Sentinel-2 없음
# 2019/01/10 → Landsat 없음
# 2019/01/14 → Sentinel-2 없음
# 2019/01/15 → Landsat 없음
# 2019/01/21 → Sentinel-2 없음
# 2019/01/22 → Sentinel-2 없음
# 2019/01/28 → Landsat 없음
# 2019/01/29 → Sentinel-2 없음
# 2019/02/01 → Sentinel-2 없음
# 2019/02/08 → Sentinel-2 없음
# 2019/02/11 → Sentinel-2 없음
# 2019/02/12 → Landsat 없음
# 2019/02/13 → Sentinel-2 없음
# 2019/02/15 → Sentinel-2 없음
# 2019/02/18 → Sentinel-2 없음
# 2019/02/19 → Sentinel-2 없음
# 2019/02/20 → Sentinel-2 없음
# 2019/02/21 → Sentinel-2 없음
# 2019/02/25 → Sentinel-2 없음
# 2019/02/26 → Sentinel-2 없음
# 2019/03/04 → Landsat 없음
# 2019/03/05 → Sentinel-2 없음
# 2019/03/06 → Landsat 없음
# 2019/03/07 → Sentinel-2 없음
# 2019/03/12 → Sentinel-2 없음
# 2019/03/13 → Sentinel-2 없음
# 2019/03/14 → Landsat 없음
# 2019/03/18 → Sentinel-2 없음
# 2019/03/19 → Landsat 없음
# 2019/03/21 → Sentinel-2 없음
# 2019/03/25 → Sentinel-2 없음
# 2019/03/26 → Sentinel-2 없음
# 2019/04/01 → Sentinel-2 없음
# 2019/04/02 → Sentinel-2 없음
# 2019/04/04 → Sentinel-2 없음
# 2019/04/05 → Sentinel-2 없음
# 2019/04/08 → Landsat 없음
# 2019/04/09 → Sentinel-2 없음
# 2019/04/10 → Landsat 없음
# 2019/04/11 → Sentinel-2 없음
# 2019/04/15 → Landsat 없음
# 2019/04/16 → Sentinel-2 없음
# 2019/04/22 → Sentinel-2 없음
# 2019/04/23 → Landsat 없음
# 2019/04/24 → Sentinel-2 없음
# 2019/04/29 → Sentinel-2 없음
# 2019/04/30 → Sentinel-2 없음
# 2019/05/02 → Sentinel-2 없음
# 2019/05/03 → Landsat 없음
# 2019/05/07 → Sentinel-2 없음
# 2019/05/08 → Landsat 없음
# 2019/05/09 → Sentinel-2 없음
# 2019/05/13 → Landsat 없음
# 2019/05/14 → Sentinel-2 없음
# 2019/05/15 → Landsat 없음
# 2019/05/17 → Sentinel-2 없음
# 2019/05/20 → Sentinel-2 없음
# 2019/05/21 → Sentinel-2 없음
# 2019/05/22 → Sentinel-2 없음
# 2019/05/27 → Sentinel-2 없음
# 2019/05/29 → Sentinel-2 없음
# 2019/06/03 → Sentinel-2 없음
# 2019/06/04 → Landsat 없음
# 2019/06/05 → Sentinel-2 없음
# 2019/06/10 → Sentinel-2 없음
# 2019/06/11 → Sentinel-2 없음
# 2019/06/12 → Sentinel-2 없음
# 2019/06/13 → Sentinel-2 없음
# 2019/06/17 → Landsat 없음
# 2019/06/18 → Sentinel-2 없음
# 2019/06/20 → Sentinel-2 없음
# 2019/06/24 → Landsat 없음
# 2019/06/25 → Sentinel-2 없음
# 2019/06/27 → Landsat 없음
# 2019/07/01 → Sentinel-2 없음
# 2019/07/02 → Landsat 없음
# 2019/07/03 → Sentinel-2 없음
# 2019/07/04 → Sentinel-2 없음
# 2019/07/08 → Sentinel-2 없음
# 2019/07/09 → Landsat 없음
# 2019/07/11 → Sentinel-2 없음
# 2019/07/12 → Landsat 없음
# 2019/07/15 → Sentinel-2 없음
# 2019/07/16 → Sentinel-2 없음
# 2019/07/18 → Sentinel-2 없음
# 2019/07/22 → Landsat 없음
# 2019/07/23 → Sentinel-2 없음
# 2019/07/24 → Sentinel-2 없음
# 2019/07/29 → Landsat 없음
# 2019/08/01 → Landsat 없음
# 2019/08/02 → Sentinel-2 없음
# 2019/08/05 → Sentinel-2 없음
# 2019/08/06 → Landsat 없음
# 2019/08/07 → Sentinel-2 없음
# 2019/08/08 → Landsat 없음
# 2019/08/12 → Sentinel-2 없음
# 2019/08/13 → Landsat 없음
# 2019/08/19 → Sentinel-2 없음
# 2019/08/20 → Sentinel-2 없음
# 2019/08/22 → Sentinel-2 없음
# 2019/08/26 → Landsat 없음
# 2019/08/27 → Sentinel-2 없음
# 2019/09/02 → Landsat 없음
# 2019/09/03 → Sentinel-2 없음
# 2019/09/04 → Sentinel-2 없음
# 2019/09/05 → Landsat 없음
# 2019/09/09 → Sentinel-2 없음
# 2019/09/11 → Sentinel-2 없음
# 2019/09/16 → Sentinel-2 없음
# 2019/09/18 → Sentinel-2 없음
# 2019/09/19 → Sentinel-2 없음
# 2019/09/20 → Landsat 없음
# 2019/09/23 → Sentinel-2 없음
# 2019/09/24 → Sentinel-2 없음
# 2019/09/30 → Landsat 없음
# 2019/10/01 → Sentinel-2 없음
# 2019/10/02 → Sentinel-2 없음
# 2019/10/04 → Sentinel-2 없음
# 2019/10/07 → Landsat 없음
# 2019/10/08 → Sentinel-2 없음
# 2019/10/10 → Landsat 없음
# 2019/10/14 → Sentinel-2 없음
# 2019/10/15 → Landsat 없음
# 2019/10/16 → Sentinel-2 없음
# 2019/10/21 → Sentinel-2 없음
# 2019/10/22 → Sentinel-2 없음
# 2019/10/28 → Sentinel-2 없음
# 2019/10/29 → Sentinel-2 없음
# 2019/11/01 → Landsat 없음
# 2019/11/05 → Sentinel-2 없음
# 2019/11/06 → Landsat 없음
# 2019/11/07 → Sentinel-2 없음
# 2019/11/08 → Sentinel-2 없음
# 2019/11/11 → Landsat 없음
# 2019/11/12 → Sentinel-2 없음
# 2019/11/13 → Sentinel-2 없음
# 2019/11/14 → Landsat 없음
# 2019/11/15 → Sentinel-2 없음
# 2019/11/18 → Sentinel-2 없음
# 2019/11/19 → Landsat 없음
# 2019/11/21 → Sentinel-2 없음
# 2019/11/25 → Sentinel-2 없음
# 2019/11/26 → Sentinel-2 없음
# 2019/12/02 → Sentinel-2 없음
# 2019/12/03 → Sentinel-2 없음
# 2019/12/04 → Landsat 없음
# 2019/12/05 → Sentinel-2 없음
# 2019/12/06 → Sentinel-2 없음
# 2019/12/09 → Landsat 없음
# 2019/12/10 → Sentinel-2 없음
# 2019/12/11 → Sentinel-2 없음
# 2019/12/16 → Landsat 없음
# 2019/12/17 → Sentinel-2 없음
# 2019/12/23 → Sentinel-2 없음
# 2019/12/30 → Sentinel-2 없음
# 2020/01/02 → Sentinel-2 없음
# 2020/01/03 → Landsat 없음
# 2020/01/06 → Sentinel-2 없음
# 2020/01/07 → Sentinel-2 없음
# 2020/01/08 → Landsat 없음
# 2020/01/09 → Sentinel-2 없음
# 2020/01/10 → Sentinel-2 없음
# 2020/01/13 → Landsat 없음
# 2020/01/14 → Sentinel-2 없음
# 2020/01/15 → Sentinel-2 없음
# 2020/01/16 → Sentinel-2 없음
# 2020/01/20 → Landsat 없음
# 2020/01/21 → Sentinel-2 없음
# 2020/01/22 → Sentinel-2 없음
# 2020/01/28 → Landsat 없음
# 2020/02/03 → Sentinel-2 없음
# 2020/02/04 → Landsat 없음
# 2020/02/05 → Sentinel-2 없음
# 2020/02/06 → Sentinel-2 없음
# 2020/02/10 → Sentinel-2 없음
# 2020/02/11 → Sentinel-2 없음
# 2020/02/12 → Landsat 없음
# 2020/02/13 → Sentinel-2 없음
# 2020/02/14 → Sentinel-2 없음
# 2020/02/18 → Sentinel-2 없음
# 2020/02/19 → Sentinel-2 없음
# 2020/02/25 → Sentinel-2 없음
# 2020/03/02 → Sentinel-2 없음
# 2020/03/03 → Landsat 없음
# 2020/03/04 → Sentinel-2 없음
# 2020/03/05 → Landsat 없음
# 2020/03/06 → Sentinel-2 없음
# 2020/03/09 → Sentinel-2 없음
# 2020/03/10 → Landsat 없음
# 2020/03/11 → Sentinel-2 없음
# 2020/03/13 → Landsat 없음
# 2020/03/16 → Sentinel-2 없음
# 2020/03/17 → Sentinel-2 없음
# 2020/03/23 → Landsat 없음
# 2020/03/24 → Sentinel-2 없음
# 2020/03/25 → Sentinel-2 없음
# 2020/03/30 → Sentinel-2 없음
# 2020/03/31 → Sentinel-2 없음
# 2020/04/01 → Sentinel-2 없음
# 2020/04/02 → Landsat 없음
# 2020/04/03 → Sentinel-2 없음
# 2020/04/06 → Sentinel-2 없음
# 2020/04/07 → Landsat 없음
# 2020/04/08 → Sentinel-2 없음
# 2020/04/09 → Sentinel-2 없음
# 2020/04/13 → Sentinel-2 없음
# 2020/04/16 → Sentinel-2 없음
# 2020/04/20 → Sentinel-2 없음
# 2020/04/21 → Sentinel-2 없음
# 2020/04/23 → Sentinel-2 없음
# 2020/04/24 → Sentinel-2 없음
# 2020/04/27 → Landsat 없음
# 2020/04/28 → Sentinel-2 없음
# 2020/05/04 → Landsat 없음
# 2020/05/06 → Sentinel-2 없음
# 2020/05/08 → Sentinel-2 없음
# 2020/05/11 → Sentinel-2 없음
# 2020/05/12 → Landsat 없음
# 2020/05/13 → Sentinel-2 없음
# 2020/05/14 → Sentinel-2 없음
# 2020/05/18 → Sentinel-2 없음
# 2020/05/19 → Sentinel-2 없음
# 2020/05/20 → Sentinel-2 없음
# 2020/05/25 → Sentinel-2 없음
# 2020/05/26 → Sentinel-2 없음
# 2020/06/02 → Sentinel-2 없음
# 2020/06/03 → Landsat 없음
# 2020/06/04 → Sentinel-2 없음
# 2020/06/09 → Sentinel-2 없음
# 2020/06/10 → Sentinel-2 없음
# 2020/06/11 → Landsat 없음
# 2020/06/12 → Sentinel-2 없음
# 2020/06/15 → Sentinel-2 없음
# 2020/06/16 → Landsat 없음
# 2020/06/22 → Sentinel-2 없음
# 2020/06/23 → Sentinel-2 없음
# 2020/06/24 → Sentinel-2 없음
# 2020/06/29 → Sentinel-2 없음
# 2020/07/01 → Landsat 없음
# 2020/07/02 → Sentinel-2 없음
# 2020/07/06 → Landsat 없음
# 2020/07/07 → Sentinel-2 없음
# 2020/07/08 → Landsat 없음
# 2020/07/09 → Sentinel-2 없음
# 2020/07/13 → Landsat 없음
# 2020/07/14 → Sentinel-2 없음
# 2020/07/15 → Sentinel-2 없음
# 2020/07/16 → Landsat 없음
# 2020/07/17 → Sentinel-2 없음
# 2020/07/20 → Sentinel-2 없음
# 2020/07/21 → Landsat 없음
# 2020/07/22 → Sentinel-2 없음
# 2020/07/27 → Sentinel-2 없음
# 2020/07/28 → Sentinel-2 없음
# 2020/08/03 → Sentinel-2 없음
# 2020/08/04 → Sentinel-2 없음
# 2020/08/05 → Landsat 없음
# 2020/08/06 → Sentinel-2 없음
# 2020/08/10 → Landsat 없음
# 2020/08/11 → Sentinel-2 없음
# 2020/08/12 → Landsat 없음
# 2020/08/14 → Sentinel-2 없음
# 2020/08/18 → Sentinel-2 없음
# 2020/08/19 → Sentinel-2 없음
# 2020/08/21 → Sentinel-2 없음
# 2020/08/24 → Sentinel-2 없음
# 2020/08/25 → Landsat 없음
# 2020/08/27 → Sentinel-2 없음
# 2020/08/31 → Sentinel-2 없음
# 2020/09/01 → Landsat 없음
# 2020/09/02 → Sentinel-2 없음
# 2020/09/04 → Landsat 없음
# 2020/09/07 → Sentinel-2 없음
# 2020/09/08 → Sentinel-2 없음
# 2020/09/09 → Landsat 없음
# 2020/09/10 → Sentinel-2 없음
# 2020/09/14 → Landsat 없음
# 2020/09/15 → Sentinel-2 없음
# 2020/09/16 → Landsat 없음
# 2020/09/17 → Sentinel-2 없음
# 2020/09/22 → Sentinel-2 없음
# 2020/09/28 → Sentinel-2 없음
# 2020/10/05 → Sentinel-2 없음
# 2020/10/06 → Landsat 없음
# 2020/10/07 → Sentinel-2 없음
# 2020/10/08 → Sentinel-2 없음
# 2020/10/12 → Sentinel-2 없음
# 2020/10/13 → Sentinel-2 없음
# 2020/10/15 → Sentinel-2 없음
# 2020/10/19 → Landsat 없음
# 2020/10/20 → Sentinel-2 없음
# 2020/10/26 → Landsat 없음
# 2020/10/27 → Sentinel-2 없음
# 2020/11/02 → Sentinel-2 없음
# 2020/11/03 → Landsat 없음
# 2020/11/04 → Sentinel-2 없음
# 2020/11/05 → Landsat 없음
# 2020/11/06 → Sentinel-2 없음
# 2020/11/09 → Sentinel-2 없음
# 2020/11/10 → Landsat 없음
# 2020/11/11 → Sentinel-2 없음
# 2020/11/16 → Sentinel-2 없음
# 2020/11/17 → Sentinel-2 없음
# 2020/11/18 → Landsat 없음
# 2020/11/23 → Landsat 없음
# 2020/11/24 → Sentinel-2 없음
# 2020/11/30 → Landsat 없음
# 2020/12/01 → Sentinel-2 없음
# 2020/12/02 → Sentinel-2 없음
# 2020/12/03 → Landsat 없음
# 2020/12/04 → Sentinel-2 없음
# 2020/12/07 → Sentinel-2 없음
# 2020/12/09 → Sentinel-2 없음
# 2020/12/10 → Sentinel-2 없음
# 2020/12/14 → Sentinel-2 없음
# 2020/12/15 → Landsat 없음
# 2020/12/16 → Sentinel-2 없음
# 2020/12/21 → Sentinel-2 없음
# 2020/12/22 → Sentinel-2 없음
# 2020/12/28 → Landsat 없음
# 2021/01/04 → Landsat 없음
# 2021/01/05 → Sentinel-2 없음
# 2021/01/06 → Sentinel-2 없음
# 2021/01/07 → Landsat 없음
# 2021/01/11 → Sentinel-2 없음
# 2021/01/12 → Sentinel-2 없음
# 2021/01/13 → Sentinel-2 없음
# 2021/01/14 → Landsat 없음
# 2021/01/18 → Sentinel-2 없음
# 2021/01/19 → Landsat 없음
# 2021/01/20 → Sentinel-2 없음
# 2021/01/25 → Sentinel-2 없음
# 2021/01/26 → Sentinel-2 없음
# 2021/02/01 → Landsat 없음
# 2021/02/02 → Sentinel-2 없음
# 2021/02/04 → Sentinel-2 없음
# 2021/02/05 → Sentinel-2 없음
# 2021/02/08 → Landsat 없음
# 2021/02/09 → Sentinel-2 없음
# 2021/02/15 → Sentinel-2 없음
# 2021/02/16 → Landsat 없음
# 2021/02/19 → Sentinel-2 없음
# 2021/02/22 → Sentinel-2 없음
# 2021/02/23 → Sentinel-2 없음
# 2021/02/24 → Sentinel-2 없음
# 2021/03/02 → Sentinel-2 없음
# 2021/03/03 → Landsat 없음
# 2021/03/04 → Sentinel-2 없음
# 2021/03/08 → Landsat 없음
# 2021/03/09 → Sentinel-2 없음
# 2021/03/10 → Landsat 없음
# 2021/03/11 → Sentinel-2 없음
# 2021/03/15 → Landsat 없음
# 2021/03/16 → Sentinel-2 없음
# 2021/03/18 → Landsat 없음
# 2021/03/22 → Sentinel-2 없음
# 2021/03/29 → Sentinel-2 없음
# 2021/03/30 → Sentinel-2 없음
# 2021/04/01 → Sentinel-2 없음
# 2021/04/02 → Landsat 없음
# 2021/04/05 → Sentinel-2 없음
# 2021/04/06 → Sentinel-2 없음
# 2021/04/07 → Landsat 없음
# 2021/04/09 → Sentinel-2 없음
# 2021/04/12 → Landsat 없음
# 2021/04/13 → Sentinel-2 없음
# 2021/04/14 → Landsat 없음
# 2021/04/15 → Sentinel-2 없음
# 2021/04/16 → Sentinel-2 없음
# 2021/04/19 → Landsat 없음
# 2021/04/20 → Sentinel-2 없음
# 2021/04/22 → Landsat 없음
# 2021/04/26 → Sentinel-2 없음
# 2021/04/27 → Landsat 없음
# 2021/05/03 → Sentinel-2 없음
# 2021/05/04 → Landsat 없음
# 2021/05/06 → Sentinel-2 없음
# 2021/05/10 → Sentinel-2 없음
# 2021/05/11 → Sentinel-2 없음
# 2021/05/12 → Landsat 없음
# 2021/05/13 → Sentinel-2 없음
# 2021/05/18 → Sentinel-2 없음
# 2021/05/20 → Sentinel-2 없음
# 2021/05/24 → Landsat 없음
# 2021/05/25 → Sentinel-2 없음
# 2021/05/31 → Sentinel-2 없음
# 2021/06/01 → Landsat 없음
# 2021/06/02 → Sentinel-2 없음
# 2021/06/03 → Sentinel-2 없음
# 2021/06/04 → Sentinel-2 없음
# 2021/06/07 → Sentinel-2 없음
# 2021/06/08 → Landsat 없음
# 2021/06/10 → Sentinel-2 없음
# 2021/06/14 → Sentinel-2 없음
# 2021/06/15 → Sentinel-2 없음
# 2021/06/21 → Landsat 없음
# 2021/06/22 → Sentinel-2 없음
# 2021/06/28 → Landsat 없음
# 2021/06/29 → Sentinel-2 없음
# 2021/07/01 → Landsat 없음
# 2021/07/02 → Sentinel-2 없음
# 2021/07/05 → Sentinel-2 없음
# 2021/07/07 → Sentinel-2 없음
# 2021/07/08 → Sentinel-2 없음
# 2021/07/12 → Sentinel-2 없음
# 2021/07/14 → Sentinel-2 없음
# 2021/07/15 → Sentinel-2 없음
# 2021/07/19 → Sentinel-2 없음
# 2021/07/20 → Sentinel-2 없음
# 2021/07/26 → Landsat 없음
# 2021/07/27 → Sentinel-2 없음
# 2021/08/02 → Landsat 없음
# 2021/08/03 → Sentinel-2 없음
# 2021/08/04 → Sentinel-2 없음
# 2021/08/09 → Sentinel-2 없음
# 2021/08/10 → Landsat 없음
# 2021/08/11 → Sentinel-2 없음
# 2021/08/12 → Sentinel-2 없음
# 2021/08/17 → Landsat 없음
# 2021/08/18 → Sentinel-2 없음
# 2021/08/23 → Sentinel-2 없음
# 2021/08/25 → Landsat 없음
# 2021/08/26 → Sentinel-2 없음
# 2021/08/31 → Sentinel-2 없음
# 2021/09/01 → Landsat 없음
# 2021/09/02 → Sentinel-2 없음
# 2021/09/07 → Sentinel-2 없음
# 2021/09/08 → Sentinel-2 없음
# 2021/09/09 → Landsat 없음
# 2021/09/10 → Sentinel-2 없음
# 2021/09/13 → Sentinel-2 없음
# 2021/09/15 → Sentinel-2 없음
# 2021/09/23 → Sentinel-2 없음
# 2021/09/27 → Sentinel-2 없음
# 2021/09/28 → Sentinel-2 없음
# 2021/10/05 → Sentinel-2 없음
# 2021/10/06 → Landsat 없음
# 2021/10/07 → Sentinel-2 없음
# 2021/10/08 → Sentinel-2 없음
# 2021/10/12 → Sentinel-2 없음
# 2021/10/13 → Sentinel-2 없음
# 2021/10/14 → Landsat 없음
# 2021/10/15 → Sentinel-2 없음
# 2021/10/18 → Sentinel-2 없음
# 2021/10/19 → Landsat 없음
# 2021/10/21 → Landsat 없음
# 2021/10/25 → Sentinel-2 없음
# 2021/10/26 → Sentinel-2 없음
# 2021/11/01 → Sentinel-2 없음
# 2021/11/02 → Sentinel-2 없음
# 2021/11/03 → Landsat 없음
# 2021/11/04 → Sentinel-2 없음
# 2021/11/08 → Landsat 없음
# 2021/11/09 → Sentinel-2 없음
# 2021/11/10 → Sentinel-2 없음
# 2021/11/11 → Sentinel-2 없음
# 2021/11/12 → Sentinel-2 없음
# 2021/11/15 → Landsat 없음
# 2021/11/16 → Sentinel-2 없음
# 2021/11/17 → Sentinel-2 없음
# 2021/11/19 → Sentinel-2 없음
# 2021/11/22 → Sentinel-2 없음
# 2021/11/23 → Landsat 없음
# 2021/11/24 → Sentinel-2 없음
# 2021/11/29 → Sentinel-2 없음
# 2021/11/30 → Sentinel-2 없음
# 2021/12/01 → Sentinel-2 없음
# 2021/12/02 → Sentinel-2 없음
# 2021/12/03 → Landsat 없음
# 2021/12/06 → Sentinel-2 없음
# 2021/12/07 → Sentinel-2 없음
# 2021/12/08 → Landsat 없음
# 2021/12/09 → Sentinel-2 없음
# 2021/12/10 → Sentinel-2 없음
# 2021/12/14 → Sentinel-2 없음
# 2021/12/15 → Sentinel-2 없음
# 2021/12/21 → Sentinel-2 없음
# 2021/12/27 → Sentinel-2 없음
# 2022/01/03 → Sentinel-2 없음
# 2022/01/05 → Sentinel-2 없음
# 2022/01/06 → Sentinel-2 없음
# 2022/01/07 → Landsat 없음
# 2022/01/10 → Sentinel-2 없음
# 2022/01/11 → Sentinel-2 없음
# 2022/01/12 → Landsat 없음
# 2022/01/17 → Landsat 없음
# 2022/01/18 → Sentinel-2 없음
# 2022/01/19 → Sentinel-2 없음
# 2022/01/24 → Landsat 없음
# 2022/01/25 → Sentinel-2 없음
# 2022/02/03 → Landsat 없음
# 2022/02/04 → Sentinel-2 없음
# 2022/02/07 → Sentinel-2 없음
# 2022/02/08 → Landsat 없음
# 2022/02/09 → Sentinel-2 없음
# 2022/02/10 → Sentinel-2 없음
# 2022/02/14 → Sentinel-2 없음
# 2022/02/15 → Sentinel-2 없음
# 2022/02/22 → Sentinel-2 없음
# 2022/02/24 → Sentinel-2 없음
# 2022/02/28 → Landsat 없음
# 2022/03/02 → Sentinel-2 없음
# 2022/03/03 → Landsat 없음
# 2022/03/04 → Sentinel-2 없음
# 2022/03/07 → Sentinel-2 없음
# 2022/03/08 → Landsat 없음
# 2022/03/11 → Sentinel-2 없음
# 2022/03/14 → Sentinel-2 없음
# 2022/03/15 → Landsat 없음
# 2022/03/16 → Sentinel-2 없음
# 2022/03/17 → Sentinel-2 없음
# 2022/03/21 → Sentinel-2 없음
# 2022/03/22 → Sentinel-2 없음
# 2022/03/23 → Landsat 없음
# 2022/03/28 → Landsat 없음
# 2022/03/29 → Sentinel-2 없음
# 2022/04/05 → Sentinel-2 없음
# 2022/04/06 → Sentinel-2 없음
# 2022/04/07 → Landsat 없음
# 2022/04/08 → Sentinel-2 없음
# 2022/04/11 → Sentinel-2 없음
# 2022/04/13 → Sentinel-2 없음
# 2022/04/14 → Landsat 없음
# 2022/04/18 → Sentinel-2 없음
# 2022/04/19 → Sentinel-2 없음
# 2022/04/20 → Sentinel-2 없음
# 2022/04/21 → Sentinel-2 없음
# 2022/04/25 → Sentinel-2 없음
# 2022/04/26 → Sentinel-2 없음
# 2022/05/02 → Landsat 없음
# 2022/05/03 → Sentinel-2 없음
# 2022/05/09 → Landsat 없음
# 2022/05/10 → Sentinel-2 없음
# 2022/05/11 → Sentinel-2 없음
# 2022/05/12 → Sentinel-2 없음
# 2022/05/16 → Sentinel-2 없음
# 2022/05/17 → Landsat 없음
# 2022/05/18 → Sentinel-2 없음
# 2022/05/19 → Sentinel-2 없음
# 2022/05/23 → Sentinel-2 없음
# 2022/05/24 → Sentinel-2 없음
# 2022/05/25 → Sentinel-2 없음
# 2022/05/26 → Sentinel-2 없음
# 2022/05/30 → Sentinel-2 없음
# 2022/05/31 → Sentinel-2 없음
# 2022/06/02 → Sentinel-2 없음
# 2022/06/03 → Sentinel-2 없음
# 2022/06/07 → Sentinel-2 없음
# 2022/06/08 → Landsat 없음
# 2022/06/09 → Sentinel-2 없음
# 2022/06/14 → Sentinel-2 없음
# 2022/06/15 → Sentinel-2 없음
# 2022/06/17 → Sentinel-2 없음
# 2022/06/20 → Sentinel-2 없음
# 2022/06/27 → Sentinel-2 없음
# 2022/06/28 → Sentinel-2 없음
# 2022/07/04 → Sentinel-2 없음
# 2022/07/05 → Sentinel-2 없음
# 2022/07/06 → Landsat 없음
# 2022/07/07 → Sentinel-2 없음
# 2022/07/08 → Sentinel-2 없음
# 2022/07/11 → Landsat 없음
# 2022/07/12 → Sentinel-2 없음
# 2022/07/14 → Sentinel-2 없음
# 2022/07/18 → Landsat 없음
# 2022/07/19 → Sentinel-2 없음
# 2022/07/20 → Sentinel-2 없음
# 2022/07/25 → Sentinel-2 없음
# 2022/07/26 → Landsat 없음
# 2022/08/01 → Sentinel-2 없음
# 2022/08/02 → Landsat 없음
# 2022/08/03 → Sentinel-2 없음
# 2022/08/04 → Sentinel-2 없음
# 2022/08/08 → Sentinel-2 없음
# 2022/08/09 → Sentinel-2 없음
# 2022/08/16 → Sentinel-2 없음
# 2022/08/17 → Sentinel-2 없음
# 2022/08/19 → Sentinel-2 없음
# 2022/08/22 → Landsat 없음
# 2022/08/23 → Sentinel-2 없음
# 2022/08/25 → Landsat 없음
# 2022/08/29 → Sentinel-2 없음
# 2022/08/30 → Landsat 없음
# 2022/09/02 → Sentinel-2 없음
# 2022/09/05 → Sentinel-2 없음
# 2022/09/06 → Sentinel-2 없음
# 2022/09/07 → Sentinel-2 없음
# 2022/09/13 → Sentinel-2 없음
# 2022/09/14 → Landsat 없음
# 2022/09/15 → Sentinel-2 없음
# 2022/09/19 → Landsat 없음
# 2022/09/20 → Sentinel-2 없음
# 2022/09/21 → Sentinel-2 없음
# 2022/09/22 → Sentinel-2 없음
# 2022/09/27 → Sentinel-2 없음
# 2022/10/04 → Landsat 없음
# 2022/10/05 → Sentinel-2 없음
# 2022/10/06 → Landsat 없음
# 2022/10/07 → Sentinel-2 없음
# 2022/10/12 → Sentinel-2 없음
# 2022/10/13 → Sentinel-2 없음
# 2022/10/17 → Sentinel-2 없음
# 2022/10/18 → Sentinel-2 없음
# 2022/10/20 → Sentinel-2 없음
# 2022/10/24 → Landsat 없음
# 2022/10/25 → Sentinel-2 없음
# 2022/10/31 → Landsat 없음
# 2022/11/01 → Sentinel-2 없음
# 2022/11/02 → Sentinel-2 없음
# 2022/11/03 → Landsat 없음
# 2022/11/07 → Sentinel-2 없음
# 2022/11/08 → Landsat 없음
# 2022/11/09 → Sentinel-2 없음
# 2022/11/10 → Sentinel-2 없음
# 2022/11/14 → Sentinel-2 없음
# 2022/11/15 → Landsat 없음
# 2022/11/16 → Sentinel-2 없음
# 2022/11/17 → Sentinel-2 없음
# 2022/11/21 → Sentinel-2 없음
# 2022/11/22 → Sentinel-2 없음
# 2022/11/23 → Landsat 없음
# 2022/11/29 → Sentinel-2 없음
# 2022/12/01 → Sentinel-2 없음
# 2022/12/05 → Landsat 없음
# 2022/12/06 → Sentinel-2 없음
# 2022/12/07 → Sentinel-2 없음
# 2022/12/08 → Landsat 없음
# 2022/12/12 → Sentinel-2 없음
# 2022/12/13 → Landsat 없음
# 2022/12/14 → Sentinel-2 없음
# 2022/12/19 → Sentinel-2 없음
# 2022/12/27 → Sentinel-2 없음
# 2023/01/02 → Landsat 없음
# 2023/01/03 → Sentinel-2 없음
# 2023/01/04 → Landsat 없음
# 2023/01/05 → Sentinel-2 없음
# 2023/01/06 → Sentinel-2 없음
# 2023/01/09 → Landsat 없음
# 2023/01/10 → Sentinel-2 없음
# 2023/01/11 → Sentinel-2 없음
# 2023/01/16 → Sentinel-2 없음
# 2023/01/17 → Landsat 없음
# 2023/01/18 → Sentinel-2 없음
# 2023/01/25 → Sentinel-2 없음
# 2023/01/30 → Sentinel-2 없음
# 2023/01/31 → Sentinel-2 없음
# 2023/02/02 → Sentinel-2 없음
# 2023/02/06 → Landsat 없음
# 2023/02/07 → Sentinel-2 없음
# 2023/02/08 → Sentinel-2 없음
# 2023/02/09 → Sentinel-2 없음
# 2023/02/13 → Landsat 없음
# 2023/02/14 → Sentinel-2 없음
# 2023/02/20 → Sentinel-2 없음
# 2023/02/21 → Landsat 없음
# 2023/02/23 → Sentinel-2 없음
# 2023/02/27 → Sentinel-2 없음
# 2023/02/28 → Sentinel-2 없음
# 2023/03/06 → Sentinel-2 없음
# 2023/03/07 → Sentinel-2 없음
# 2023/03/08 → Landsat 없음
# 2023/03/09 → Sentinel-2 없음
# 2023/03/14 → Sentinel-2 없음
# 2023/03/15 → Sentinel-2 없음
# 2023/03/21 → Sentinel-2 없음
# 2023/03/23 → Landsat 없음
# 2023/03/24 → Sentinel-2 없음
# 2023/03/27 → Sentinel-2 없음
# 2023/04/03 → Sentinel-2 없음
# 2023/04/04 → Landsat 없음
# 2023/04/05 → Sentinel-2 없음
# 2023/04/06 → Sentinel-2 없음
# 2023/04/07 → Landsat 없음
# 2023/04/10 → Sentinel-2 없음
# 2023/04/11 → Sentinel-2 없음
# 2023/04/12 → Landsat 없음
# 2023/04/13 → Sentinel-2 없음
# 2023/04/17 → Landsat 없음
# 2023/04/18 → Sentinel-2 없음
# 2023/04/24 → Landsat 없음
# 2023/04/25 → Sentinel-2 없음
# 2023/05/01 → Sentinel-2 없음
# 2023/05/02 → Landsat 없음
# 2023/05/03 → Sentinel-2 없음
# 2023/05/04 → Landsat 없음
# 2023/05/08 → Sentinel-2 없음
# 2023/05/10 → Sentinel-2 없음
# 2023/05/11 → Sentinel-2 없음
# 2023/05/12 → Landsat 없음
# 2023/05/15 → Sentinel-2 없음
# 2023/05/16 → Sentinel-2 없음
# 2023/05/22 → Landsat 없음
# 2023/05/23 → Sentinel-2 없음
# 2023/05/30 → Sentinel-2 없음
# 2023/05/31 → Sentinel-2 없음
# 2023/06/05 → Sentinel-2 없음
# 2023/06/07 → Sentinel-2 없음
# 2023/06/08 → Landsat 없음
# 2023/06/09 → Sentinel-2 없음
# 2023/06/12 → Sentinel-2 없음
# 2023/06/13 → Landsat 없음
# 2023/06/14 → Sentinel-2 없음
# 2023/06/15 → Sentinel-2 없음
# 2023/06/19 → Sentinel-2 없음
# 2023/06/20 → Sentinel-2 없음
# 2023/06/23 → Sentinel-2 없음
# 2023/06/26 → Landsat 없음
# 2023/06/27 → Sentinel-2 없음
# 2023/06/28 → Sentinel-2 없음
# 2023/07/04 → Sentinel-2 없음
# 2023/07/05 → Sentinel-2 없음
# 2023/07/06 → Landsat 없음
# 2023/07/10 → Sentinel-2 없음
# 2023/07/11 → Landsat 없음
# 2023/07/12 → Sentinel-2 없음
# 2023/07/13 → Landsat 없음
# 2023/07/17 → Sentinel-2 없음
# 2023/07/18 → Sentinel-2 없음
# 2023/07/20 → Sentinel-2 없음
# 2023/07/24 → Sentinel-2 없음
# 2023/07/31 → Landsat 없음
# 2023/08/01 → Sentinel-2 없음
# 2023/08/02 → Landsat 없음
# 2023/08/03 → Sentinel-2 없음
# 2023/08/04 → Sentinel-2 없음
# 2023/08/07 → Landsat 없음
# 2023/08/08 → Sentinel-2 없음
# 2023/08/09 → Sentinel-2 없음
# 2023/08/11 → Sentinel-2 없음
# 2023/08/14 → Sentinel-2 없음
# 2023/08/16 → Sentinel-2 없음
# 2023/08/17 → Sentinel-2 없음
# 2023/08/21 → Sentinel-2 없음
# 2023/08/22 → Landsat 없음
# 2023/08/28 → Sentinel-2 없음
# 2023/08/29 → Sentinel-2 없음
# 2023/08/30 → Landsat 없음
# 2023/09/05 → Sentinel-2 없음
# 2023/09/07 → Sentinel-2 없음
# 2023/09/08 → Sentinel-2 없음
# 2023/09/11 → Landsat 없음
# 2023/09/12 → Sentinel-2 없음
# 2023/09/13 → Sentinel-2 없음
# 2023/09/14 → Landsat 없음
# 2023/09/18 → Sentinel-2 없음
# 2023/09/19 → Landsat 없음
# 2023/09/25 → Sentinel-2 없음
# 2023/09/26 → Sentinel-2 없음
# 2023/10/04 → Landsat 없음
# 2023/10/05 → Sentinel-2 없음
# 2023/10/06 → Sentinel-2 없음
# 2023/10/10 → Sentinel-2 없음
# 2023/10/11 → Landsat 없음
# 2023/10/12 → Sentinel-2 없음
# 2023/10/13 → Sentinel-2 없음
# 2023/10/16 → Landsat 없음
# 2023/10/17 → Sentinel-2 없음
# 2023/10/23 → Sentinel-2 없음
# 2023/10/26 → Sentinel-2 없음
# 2023/10/30 → Sentinel-2 없음
# 2023/10/31 → Sentinel-2 없음
# 2023/11/01 → Sentinel-2 없음
# 2023/11/02 → Sentinel-2 없음
# 2023/11/06 → Sentinel-2 없음
# 2023/11/07 → Sentinel-2 없음
# 2023/11/09 → Sentinel-2 없음
# 2023/11/10 → Sentinel-2 없음
# 2023/11/13 → Landsat 없음
# 2023/11/14 → Sentinel-2 없음
# 2023/11/15 → Sentinel-2 없음
# 2023/11/16 → Sentinel-2 없음
# 2023/11/20 → Landsat 없음
# 2023/11/21 → Sentinel-2 없음
# 2023/11/22 → Sentinel-2 없음
# 2023/11/27 → Sentinel-2 없음
# 2023/11/28 → Landsat 없음
# 2023/12/01 → Sentinel-2 없음
# 2023/12/04 → Sentinel-2 없음
# 2023/12/05 → Landsat 없음
# 2023/12/06 → Sentinel-2 없음
# 2023/12/07 → Sentinel-2 없음
# 2023/12/11 → Sentinel-2 없음
# 2023/12/12 → Sentinel-2 없음
# 2023/12/13 → Landsat 없음
# 2023/12/15 → Landsat 없음
# 2023/12/19 → Sentinel-2 없음
# 2023/12/26 → Sentinel-2 없음
# 2024/01/03 → Sentinel-2 없음
# 2024/01/05 → Sentinel-2 없음
# 2024/01/08 → Sentinel-2 없음
# 2024/01/09 → Landsat 없음
# 2024/01/10 → Sentinel-2 없음
# 2024/01/11 → Sentinel-2 없음
# 2024/01/12 → Sentinel-2 없음
# 2024/01/15 → Sentinel-2 없음
# 2024/01/16 → Sentinel-2 없음
# 2024/01/17 → Landsat 없음
# 2024/01/22 → Landsat 없음
# 2024/01/23 → Sentinel-2 없음
# 2024/01/29 → Landsat 없음
# 2024/01/30 → Sentinel-2 없음
# 2024/02/01 → Landsat 없음
# 2024/02/02 → Sentinel-2 없음
# 2024/02/05 → Sentinel-2 없음
# 2024/02/06 → Landsat 없음
# 2024/02/07 → Sentinel-2 없음
# 2024/02/14 → Sentinel-2 없음
# 2024/02/15 → Sentinel-2 없음
# 2024/02/16 → Landsat 없음
# 2024/02/19 → Sentinel-2 없음
# 2024/02/20 → Sentinel-2 없음
# 2024/02/26 → Landsat 없음
# 2024/02/27 → Sentinel-2 없음
# 2024/03/04 → Landsat 없음
# 2024/03/05 → Sentinel-2 없음
# 2024/03/06 → Sentinel-2 없음
# 2024/03/11 → Sentinel-2 없음
# 2024/03/12 → Landsat 없음
# 2024/03/13 → Sentinel-2 없음
# 2024/03/14 → Sentinel-2 없음
# 2024/03/15 → Sentinel-2 없음
# 2024/03/18 → Sentinel-2 없음
# 2024/03/19 → Landsat 없음
# 2024/03/20 → Sentinel-2 없음
# 2024/03/25 → Sentinel-2 없음
# 2024/04/02 → Sentinel-2 없음
# 2024/04/03 → Landsat 없음
# 2024/04/04 → Sentinel-2 없음
# 2024/04/09 → Sentinel-2 없음
# 2024/04/11 → Landsat 없음
# 2024/04/12 → Sentinel-2 없음
# 2024/04/15 → Sentinel-2 없음
# 2024/04/18 → Sentinel-2 없음
# 2024/04/22 → Sentinel-2 없음
# 2024/04/23 → Sentinel-2 없음
# 2024/04/24 → Sentinel-2 없음
# 2024/04/29 → Sentinel-2 없음
# 2024/04/30 → Sentinel-2 없음
# 2024/05/02 → Sentinel-2 없음
# 2024/05/03 → Landsat 없음
# 2024/05/07 → Sentinel-2 없음
# 2024/05/08 → Landsat 없음
# 2024/05/09 → Sentinel-2 없음
# 2024/05/10 → Sentinel-2 없음
# 2024/05/13 → Landsat 없음
# 2024/05/14 → Sentinel-2 없음
# 2024/05/16 → Landsat 없음
# 2024/05/20 → Sentinel-2 없음
# 2024/05/21 → Landsat 없음
# 2024/05/22 → Sentinel-2 없음
# 2024/05/27 → Sentinel-2 없음
# 2024/05/28 → Landsat 없음
# 2024/06/03 → Sentinel-2 없음
# 2024/06/04 → Sentinel-2 없음
# 2024/06/05 → Landsat 없음
# 2024/06/11 → Sentinel-2 없음
# 2024/06/13 → Sentinel-2 없음
# 2024/06/17 → Landsat 없음
# 2024/06/18 → Sentinel-2 없음
# 2024/06/21 → Sentinel-2 없음
# 2024/06/24 → Sentinel-2 없음
# 2024/06/25 → Landsat 없음
# 2024/07/01 → Sentinel-2 없음
# 2024/07/02 → Sentinel-2 없음
# 2024/07/03 → Sentinel-2 없음
# 2024/07/04 → Sentinel-2 없음
# 2024/07/08 → Sentinel-2 없음
# 2024/07/09 → Sentinel-2 없음
# 2024/07/10 → Landsat 없음
# 2024/07/11 → Sentinel-2 없음
# 2024/07/15 → Landsat 없음
# 2024/07/16 → Sentinel-2 없음
# 2024/07/17 → Landsat 없음
# 2024/07/19 → Sentinel-2 없음
# 2024/07/22 → Landsat 없음
# 2024/07/23 → Sentinel-2 없음
# 2024/07/29 → Sentinel-2 없음
# 2024/07/30 → Landsat 없음
# 2024/08/01 → Landsat 없음
# 2024/08/02 → Sentinel-2 없음
# 2024/08/05 → Sentinel-2 없음
# 2024/08/07 → Sentinel-2 없음
# 2024/08/08 → Sentinel-2 없음
# 2024/08/12 → Sentinel-2 없음
# 2024/08/13 → Sentinel-2 없음
# 2024/08/19 → Landsat 없음
# 2024/08/20 → Sentinel-2 없음
# 2024/08/26 → Landsat 없음
# 2024/08/27 → Sentinel-2 없음
# 2024/09/02 → Sentinel-2 없음
# 2024/09/03 → Landsat 없음
# 2024/09/04 → Sentinel-2 없음
# 2024/09/05 → Landsat 없음
# 2024/09/06 → Sentinel-2 없음
# 2024/09/09 → Sentinel-2 없음
# 2024/09/10 → Landsat 없음
# 2024/09/11 → Sentinel-2 없음
# 2024/09/19 → Sentinel-2 없음
# 2024/10/02 → Sentinel-2 없음
# 2024/10/07 → Sentinel-2 없음
# 2024/10/11 → Sentinel-2 없음
# 2024/10/14 → Sentinel-2 없음
# 2024/10/15 → Landsat 없음
# 2024/10/16 → Sentinel-2 없음
# 2024/10/17 → Sentinel-2 없음
# 2024/10/21 → Sentinel-2 없음
# 2024/10/22 → Sentinel-2 없음
# 2024/10/28 → Landsat 없음
# 2024/10/29 → Sentinel-2 없음
# 2024/11/01 → Sentinel-2 없음
# 2024/11/04 → Landsat 없음
# 2024/11/05 → Sentinel-2 없음
# 2024/11/06 → Sentinel-2 없음
# 2024/11/07 → Landsat 없음
# 2024/11/11 → Sentinel-2 없음
# 2024/11/12 → Landsat 없음
# 2024/11/13 → Sentinel-2 없음
# 2024/11/18 → Sentinel-2 없음
# 2024/11/19 → Sentinel-2 없음
# 2024/11/25 → Sentinel-2 없음
# 2024/11/26 → Sentinel-2 없음
# 2024/12/02 → Landsat 없음
# 2024/12/03 → Sentinel-2 없음
# 2024/12/05 → Sentinel-2 없음
# 2024/12/06 → Sentinel-2 없음
# 2024/12/09 → Landsat 없음
# 2024/12/10 → Sentinel-2 없음
# 2024/12/11 → Sentinel-2 없음
# 2024/12/16 → Sentinel-2 없음
# 2024/12/17 → Landsat 없음
# 2024/12/23 → Sentinel-2 없음
# 2024/12/30 → Sentinel-2 없음
# 2025/01/02 → Sentinel-2 없음
# 2025/01/07 → Sentinel-2 없음
# 2025/01/08 → Sentinel-2 없음
# 2025/01/09 → Sentinel-2 없음
# 2025/01/14 → Sentinel-2 없음
# 2025/01/15 → Sentinel-2 없음
# 2025/01/20 → Sentinel-2 없음
# 2025/02/03 → Sentinel-2 없음
# 2025/02/04 → Sentinel-2 없음
# 2025/02/05 → Landsat 없음
# 2025/02/06 → Sentinel-2 없음
# 2025/02/10 → Landsat 없음
# 2025/02/11 → Sentinel-2 없음
# 2025/02/12 → Landsat 없음
# 2025/02/13 → Sentinel-2 없음
# 2025/02/17 → Landsat 없음
# 2025/02/18 → Sentinel-2 없음
# 2025/02/19 → Sentinel-2 없음
# 2025/02/24 → Sentinel-2 없음
# 2025/02/25 → Landsat 없음
# 2025/03/04 → Landsat 없음
# 2025/03/05 → Sentinel-2 없음
# 2025/03/06 → Sentinel-2 없음
# 2025/03/07 → Landsat 없음
# 2025/03/10 → Sentinel-2 없음
# 2025/03/11 → Sentinel-2 없음
# 2025/03/12 → Landsat 없음
# 2025/03/13 → Sentinel-2 없음
# 2025/03/18 → Sentinel-2 없음
# 2025/03/20 → Sentinel-2 없음
# 2025/03/24 → Landsat 없음
# 2025/03/31 → Sentinel-2 없음
# 2025/04/01 → Landsat 없음
# 2025/04/02 → Sentinel-2 없음
# 2025/04/04 → Sentinel-2 없음
# 2025/04/07 → Sentinel-2 없음
# 2025/04/08 → Landsat 없음
# 2025/04/09 → Sentinel-2 없음
# 2025/04/10 → Sentinel-2 없음
# 2025/04/14 → Sentinel-2 없음
# 2025/04/15 → Sentinel-2 없음
# 2025/04/16 → Landsat 없음
# 2025/04/21 → Landsat 없음
# 2025/04/28 → Landsat 없음
# 2025/05/07 → Sentinel-2 없음
# 2025/05/08 → Landsat 없음
# 2025/05/09 → Sentinel-2 없음
# 2025/05/12 → Sentinel-2 없음
# 2025/05/14 → Sentinel-2 없음
# 2025/05/15 → Sentinel-2 없음
# 2025/05/19 → Sentinel-2 없음
# 2025/05/20 → Sentinel-2 없음
# 2025/05/22 → Sentinel-2 없음
# 2025/05/26 → Landsat 없음
# 2025/06/02 → Landsat 없음
# 2025/06/04 → Sentinel-2 없음
# 2025/06/09 → Sentinel-2 없음
# 2025/06/10 → Landsat 없음
# 2025/06/11 → Sentinel-2 없음
# 2025/06/12 → Landsat 없음
# 2025/06/16 → Sentinel-2 없음
# 2025/06/17 → Landsat 없음
# 2025/06/18 → Sentinel-2 없음
# 2025/06/23 → Sentinel-2 없음
# 2025/07/01 → Sentinel-2 없음
# 2025/07/02 → Landsat 없음
# 2025/07/03 → Sentinel-2 없음
# 2025/07/08 → Sentinel-2 없음
# 2025/07/09 → Landsat 없음
# 2025/07/10 → Landsat 없음
# 2025/07/14 → Sentinel-2 없음
# 2025/07/15 → Landsat 없음
# 2025/07/21 → Sentinel-2 없음
# 2025/07/22 → Landsat 없음
# 2025/07/23 → Sentinel-2 없음
# 2025/07/24 → Sentinel-2 없음
# 2025/07/28 → Sentinel-2 없음
# 2025/08/04 → Landsat 없음
# 2025/08/05 → Sentinel-2 없음
# 2025/08/06 → Landsat 없음
# 2025/08/07 → Sentinel-2 없음
# 2025/08/11 → Landsat 없음
# 2025/08/12 → Sentinel-2 없음
# 2025/08/13 → Sentinel-2 없음
# 2025/08/14 → Landsat 없음
# 2025/08/18 → Landsat 없음
# 2025/08/20 → Sentinel-2 없음
# 2025/08/25 → Sentinel-2 없음
# 2025/08/27 → Sentinel-2 없음
# 2025/08/28 → Sentinel-2 없음
# 2025/09/01 → Sentinel-2 없음
# 2025/09/02 → Sentinel-2 없음
# 2025/09/04 → Sentinel-2 없음
# 2025/09/08 → Landsat 없음
# 2025/09/09 → Sentinel-2 없음
# 2025/09/11 → Sentinel-2 없음
# 2025/09/15 → Landsat 없음
# 2025/09/22 → Sentinel-2 없음
# 2025/09/23 → Landsat 없음
# 2025/09/25 → Sentinel-2 없음
# 2025/09/29 → Sentinel-2 없음
# 2025/10/01 → Sentinel-2 없음
# 2025/10/02 → Sentinel-2 없음
# 2025/10/10 → Landsat 없음
# 2025/10/13 → Landsat 없음
# 2025/10/14 → Sentinel-2 없음
# 2025/10/15 → Landsat 없음
# 2025/10/16 → Sentinel-2 없음
# 2025/10/20 → Landsat 없음
# 2025/10/21 → Sentinel-2 없음
# 2025/10/23 → Landsat 없음
# 2025/10/24 → Sentinel-2 없음
# 2025/10/27 → Sentinel-2 없음
# 2025/10/30 → Landsat 없음

# %%
import numpy as np
from datetime import timedelta

#### 이걸로 진행
results = []

for date, group in total_df.groupby("년/월/일"):

    obs_date = pd.to_datetime(date)

    # 날짜는 당일
    start = obs_date.strftime("%Y-%m-%d")
    end   = (obs_date + timedelta(days=1)).strftime("%Y-%m-%d")

    # -----------------------------------
    # 관측 지점 → FeatureCollection
    # Sentinel-2 / Landsat 분리
    # -----------------------------------
    s2_features  = []
    lst_features = []

    for idx, row in group.iterrows():
        lon = dms_to_dd(row["경도"])
        lat = dms_to_dd(row["위도"])

        # Sentinel-2: point
        pt_s2 = ee.Geometry.Point([lon, lat])
        s2_features.append(
            ee.Feature(pt_s2, {"idx": idx})
        )

        # Landsat: buffer (60 m)
        pt_lst = ee.Geometry.Point([lon, lat]).buffer(60)
        lst_features.append(
            ee.Feature(pt_lst, {"idx": idx})
        )

    fc_s2  = ee.FeatureCollection(s2_features)
    fc_lst = ee.FeatureCollection(lst_features)

    # -----------------------------------
    # Sentinel-2
    # -----------------------------------
    s2_img = (S2
              .filterBounds(fc_s2)
              .filterDate(start, end)
              .sort("system:time_start", False)
              .first())

    if s2_img.getInfo() is None:
        print(date, "→ Sentinel-2 없음")
        continue

    s2_selected = s2_img.select([
        "SCL",
        "B1","B2","B3","B4","B5","B6","B7",
        "B8","B8A","B9","B11","B12"
    ])

    s2_reduced = s2_selected.reduceRegions(
        collection = fc_s2,
        reducer    = ee.Reducer.first(),
        scale      = 10
    )

    s2_rows = s2_reduced.getInfo()["features"]

    # -----------------------------------
    # Landsat LST
    # -----------------------------------
    lst_img = (Landsat
               .filterBounds(fc_lst)
               .filterDate(start, end)
               .sort("system:time_start", False)
               .first())

    if lst_img.getInfo() is None:
        print(date, "→ Landsat 없음")
        continue

    # ST_B10 → 섭씨
    lst_selected = (
        lst_img.select("ST_B10")
        .multiply(0.00341802)
        .add(149.0)
        .subtract(273.15)
        .rename("LST")
    )

    # buffer 평균
    lst_reduced = lst_selected.reduceRegions(
        collection = fc_lst,
        reducer    = ee.Reducer.mean(),
        scale      = 30
    )

    # idx → LST 매핑 (null 제거)
    lst_rows = {
        f["properties"]["idx"]: f["properties"]["LST"]
        for f in lst_reduced.getInfo()["features"]
        if f["properties"].get("LST") is not None
    }

    # -----------------------------------
    # Sentinel + Landsat 병합
    # -----------------------------------
    for item in s2_rows:
        props = item["properties"]
        idx   = props["idx"]

        # Sentinel-2 수체 필터
        scl = props.get("SCL", None)
        if scl not in [6, 7]:   # 필요하면 [2,6,7]
            continue

        out = total_df.loc[idx].to_dict()

        # Sentinel-2 밴드
        out.update(props)

        # Landsat LST (있으면 쓰고, 없으면 NaN)
        if idx in lst_rows:
            out["LST"] = lst_rows[idx]
            out["LST_valid"] = 1
        else:
            out["LST"] = np.nan
            out["LST_valid"] = 0

        # 메타정보
        out["image_id_S2"]      = s2_img.get("system:index").getInfo()
        out["image_id_Landsat"] = lst_img.get("system:index").getInfo()

        results.append(out)

df_out = pd.DataFrame(results)
# Out:
# 2018/01/02 → Sentinel-2 없음
# 2018/01/03 → Sentinel-2 없음
# 2018/01/04 → Sentinel-2 없음
# 2018/01/05 → Sentinel-2 없음
# 2018/01/08 → Sentinel-2 없음
# 2018/01/09 → Sentinel-2 없음
# 2018/01/10 → Sentinel-2 없음
# 2018/01/12 → Sentinel-2 없음
# 2018/01/15 → Sentinel-2 없음
# 2018/01/19 → Sentinel-2 없음
# 2018/01/22 → Sentinel-2 없음
# 2018/01/23 → Sentinel-2 없음
# 2018/01/29 → Sentinel-2 없음
# 2018/02/01 → Sentinel-2 없음
# 2018/02/02 → Sentinel-2 없음
# 2018/02/05 → Sentinel-2 없음
# 2018/02/06 → Sentinel-2 없음
# 2018/02/08 → Sentinel-2 없음
# 2018/02/09 → Sentinel-2 없음
# 2018/02/12 → Sentinel-2 없음
# 2018/02/14 → Sentinel-2 없음
# 2018/02/19 → Sentinel-2 없음
# 2018/02/20 → Sentinel-2 없음
# 2018/02/22 → Landsat 없음
# 2018/02/26 → Sentinel-2 없음
# 2018/02/27 → Sentinel-2 없음
# 2018/02/28 → Sentinel-2 없음
# 2018/03/02 → Sentinel-2 없음
# 2018/03/05 → Sentinel-2 없음
# 2018/03/06 → Sentinel-2 없음
# 2018/03/07 → Sentinel-2 없음
# 2018/03/08 → Sentinel-2 없음
# 2018/03/09 → Landsat 없음
# 2018/03/12 → Sentinel-2 없음
# 2018/03/13 → Sentinel-2 없음
# 2018/03/14 → Sentinel-2 없음
# 2018/03/15 → Sentinel-2 없음
# 2018/03/19 → Landsat 없음
# 2018/03/20 → Sentinel-2 없음
# 2018/03/23 → Sentinel-2 없음
# 2018/03/26 → Sentinel-2 없음
# 2018/03/27 → Sentinel-2 없음
# 2018/04/02 → Sentinel-2 없음
# 2018/04/03 → Sentinel-2 없음
# 2018/04/04 → Sentinel-2 없음
# 2018/04/05 → Sentinel-2 없음
# 2018/04/06 → Sentinel-2 없음
# 2018/04/09 → Sentinel-2 없음
# 2018/04/10 → Sentinel-2 없음
# 2018/04/11 → Sentinel-2 없음
# 2018/04/12 → Sentinel-2 없음
# 2018/04/16 → Sentinel-2 없음
# 2018/04/17 → Sentinel-2 없음
# 2018/04/19 → Sentinel-2 없음
# 2018/04/23 → Sentinel-2 없음
# 2018/04/25 → Sentinel-2 없음
# 2018/04/30 → Sentinel-2 없음
# 2018/05/01 → Sentinel-2 없음
# 2018/05/02 → Sentinel-2 없음
# 2018/05/03 → Sentinel-2 없음
# 2018/05/04 → Sentinel-2 없음
# 2018/05/07 → Sentinel-2 없음
# 2018/05/08 → Sentinel-2 없음
# 2018/05/10 → Sentinel-2 없음
# 2018/05/11 → Sentinel-2 없음
# 2018/05/14 → Sentinel-2 없음
# 2018/05/15 → Sentinel-2 없음
# 2018/05/16 → Sentinel-2 없음
# 2018/05/21 → Sentinel-2 없음
# 2018/05/23 → Sentinel-2 없음
# 2018/05/28 → Sentinel-2 없음
# 2018/05/29 → Sentinel-2 없음
# 2018/06/01 → Sentinel-2 없음
# 2018/06/04 → Sentinel-2 없음
# 2018/06/05 → Sentinel-2 없음
# 2018/06/07 → Sentinel-2 없음
# 2018/06/08 → Sentinel-2 없음
# 2018/06/11 → Sentinel-2 없음
# 2018/06/12 → Sentinel-2 없음
# 2018/06/14 → Sentinel-2 없음
# 2018/06/15 → Sentinel-2 없음
# 2018/06/18 → Sentinel-2 없음
# 2018/06/21 → Sentinel-2 없음
# 2018/06/25 → Sentinel-2 없음
# 2018/06/26 → Sentinel-2 없음
# 2018/07/02 → Sentinel-2 없음
# 2018/07/03 → Sentinel-2 없음
# 2018/07/04 → Sentinel-2 없음
# 2018/07/05 → Sentinel-2 없음
# 2018/07/09 → Sentinel-2 없음
# 2018/07/10 → Sentinel-2 없음
# 2018/07/11 → Sentinel-2 없음
# 2018/07/12 → Sentinel-2 없음
# 2018/07/13 → Sentinel-2 없음
# 2018/07/16 → Sentinel-2 없음
# 2018/07/17 → Sentinel-2 없음
# 2018/07/19 → Sentinel-2 없음
# 2018/07/23 → Sentinel-2 없음
# 2018/07/24 → Sentinel-2 없음
# 2018/07/30 → Sentinel-2 없음
# 2018/07/31 → Sentinel-2 없음
# 2018/08/01 → Sentinel-2 없음
# 2018/08/02 → Sentinel-2 없음
# 2018/08/03 → Sentinel-2 없음
# 2018/08/06 → Sentinel-2 없음
# 2018/08/07 → Sentinel-2 없음
# 2018/08/08 → Sentinel-2 없음
# 2018/08/09 → Sentinel-2 없음
# 2018/08/13 → Sentinel-2 없음
# 2018/08/14 → Sentinel-2 없음
# 2018/08/16 → Sentinel-2 없음
# 2018/08/20 → Sentinel-2 없음
# 2018/08/21 → Sentinel-2 없음
# 2018/08/27 → Sentinel-2 없음
# 2018/08/28 → Sentinel-2 없음
# 2018/09/03 → Sentinel-2 없음
# 2018/09/04 → Sentinel-2 없음
# 2018/09/05 → Sentinel-2 없음
# 2018/09/06 → Sentinel-2 없음
# 2018/09/10 → Sentinel-2 없음
# 2018/09/11 → Sentinel-2 없음
# 2018/09/12 → Sentinel-2 없음
# 2018/09/13 → Sentinel-2 없음
# 2018/09/14 → Sentinel-2 없음
# 2018/09/17 → Sentinel-2 없음
# 2018/09/18 → Sentinel-2 없음
# 2018/09/27 → Sentinel-2 없음
# 2018/10/01 → Sentinel-2 없음
# 2018/10/02 → Sentinel-2 없음
# 2018/10/04 → Sentinel-2 없음
# 2018/10/08 → Sentinel-2 없음
# 2018/10/10 → Sentinel-2 없음
# 2018/10/11 → Sentinel-2 없음
# 2018/10/12 → Sentinel-2 없음
# 2018/10/15 → Landsat 없음
# 2018/10/16 → Sentinel-2 없음
# 2018/10/17 → Sentinel-2 없음
# 2018/10/22 → Sentinel-2 없음
# 2018/10/23 → Sentinel-2 없음
# 2018/10/24 → Sentinel-2 없음
# 2018/10/29 → Sentinel-2 없음
# 2018/10/30 → Sentinel-2 없음
# 2018/11/01 → Sentinel-2 없음
# 2018/11/02 → Sentinel-2 없음
# 2018/11/05 → Sentinel-2 없음
# 2018/11/06 → Sentinel-2 없음
# 2018/11/07 → Sentinel-2 없음
# 2018/11/08 → Sentinel-2 없음
# 2018/11/09 → Sentinel-2 없음
# 2018/11/12 → Sentinel-2 없음
# 2018/11/13 → Sentinel-2 없음
# 2018/11/14 → Sentinel-2 없음
# 2018/11/19 → Sentinel-2 없음
# 2018/11/20 → Sentinel-2 없음
# 2018/11/22 → Sentinel-2 없음
# 2018/11/26 → Sentinel-2 없음
# 2018/11/27 → Sentinel-2 없음
# 2018/12/03 → Sentinel-2 없음
# 2018/12/04 → Sentinel-2 없음
# 2018/12/05 → Sentinel-2 없음
# 2018/12/06 → Sentinel-2 없음
# 2018/12/07 → Sentinel-2 없음
# 2018/12/10 → Sentinel-2 없음
# 2018/12/11 → Sentinel-2 없음
# 2018/12/12 → Sentinel-2 없음
# 2018/12/13 → Sentinel-2 없음
# 2018/12/17 → Sentinel-2 없음
# 2018/12/18 → Sentinel-2 없음
# 2018/12/24 → Landsat 없음
# 2018/12/26 → Sentinel-2 없음
# 2019/01/02 → Sentinel-2 없음
# 2019/01/03 → Landsat 없음
# 2019/01/04 → Sentinel-2 없음
# 2019/01/07 → Sentinel-2 없음
# 2019/01/08 → Landsat 없음
# 2019/01/09 → Sentinel-2 없음
# 2019/01/10 → Landsat 없음
# 2019/01/14 → Sentinel-2 없음
# 2019/01/15 → Landsat 없음
# 2019/01/21 → Sentinel-2 없음
# 2019/01/22 → Sentinel-2 없음
# 2019/01/28 → Landsat 없음
# 2019/01/29 → Sentinel-2 없음
# 2019/02/01 → Sentinel-2 없음
# 2019/02/08 → Sentinel-2 없음
# 2019/02/11 → Sentinel-2 없음
# 2019/02/12 → Landsat 없음
# 2019/02/13 → Sentinel-2 없음
# 2019/02/15 → Sentinel-2 없음
# 2019/02/18 → Sentinel-2 없음
# 2019/02/19 → Sentinel-2 없음
# 2019/02/20 → Sentinel-2 없음
# 2019/02/21 → Sentinel-2 없음
# 2019/02/25 → Sentinel-2 없음
# 2019/02/26 → Sentinel-2 없음
# 2019/03/04 → Landsat 없음
# 2019/03/05 → Sentinel-2 없음
# 2019/03/06 → Landsat 없음
# 2019/03/07 → Sentinel-2 없음
# 2019/03/12 → Sentinel-2 없음
# 2019/03/13 → Sentinel-2 없음
# 2019/03/14 → Landsat 없음
# 2019/03/18 → Sentinel-2 없음
# 2019/03/19 → Landsat 없음
# 2019/03/21 → Sentinel-2 없음
# 2019/03/25 → Sentinel-2 없음
# 2019/03/26 → Sentinel-2 없음
# 2019/04/01 → Sentinel-2 없음
# 2019/04/02 → Sentinel-2 없음
# 2019/04/04 → Sentinel-2 없음
# 2019/04/05 → Sentinel-2 없음
# 2019/04/08 → Landsat 없음
# 2019/04/09 → Sentinel-2 없음
# 2019/04/10 → Landsat 없음
# 2019/04/11 → Sentinel-2 없음
# 2019/04/15 → Landsat 없음
# 2019/04/16 → Sentinel-2 없음
# 2019/04/22 → Sentinel-2 없음
# 2019/04/23 → Landsat 없음
# 2019/04/24 → Sentinel-2 없음
# 2019/04/29 → Sentinel-2 없음
# 2019/04/30 → Sentinel-2 없음
# 2019/05/02 → Sentinel-2 없음
# 2019/05/03 → Landsat 없음
# 2019/05/07 → Sentinel-2 없음
# 2019/05/08 → Landsat 없음
# 2019/05/09 → Sentinel-2 없음
# 2019/05/13 → Landsat 없음
# 2019/05/14 → Sentinel-2 없음
# 2019/05/15 → Landsat 없음
# 2019/05/17 → Sentinel-2 없음
# 2019/05/20 → Sentinel-2 없음
# 2019/05/21 → Sentinel-2 없음
# 2019/05/22 → Sentinel-2 없음
# 2019/05/27 → Sentinel-2 없음
# 2019/05/29 → Sentinel-2 없음
# 2019/06/03 → Sentinel-2 없음
# 2019/06/04 → Landsat 없음
# 2019/06/05 → Sentinel-2 없음
# 2019/06/10 → Sentinel-2 없음
# 2019/06/11 → Sentinel-2 없음
# 2019/06/12 → Sentinel-2 없음
# 2019/06/13 → Sentinel-2 없음
# 2019/06/17 → Landsat 없음
# 2019/06/18 → Sentinel-2 없음
# 2019/06/20 → Sentinel-2 없음
# 2019/06/24 → Landsat 없음
# 2019/06/25 → Sentinel-2 없음
# 2019/06/27 → Landsat 없음
# 2019/07/01 → Sentinel-2 없음
# 2019/07/02 → Landsat 없음
# 2019/07/03 → Sentinel-2 없음
# 2019/07/04 → Sentinel-2 없음
# 2019/07/08 → Sentinel-2 없음
# 2019/07/09 → Landsat 없음
# 2019/07/11 → Sentinel-2 없음
# 2019/07/12 → Landsat 없음
# 2019/07/15 → Sentinel-2 없음
# 2019/07/16 → Sentinel-2 없음
# 2019/07/18 → Sentinel-2 없음
# 2019/07/22 → Landsat 없음
# 2019/07/23 → Sentinel-2 없음
# 2019/07/24 → Sentinel-2 없음
# 2019/07/29 → Landsat 없음
# 2019/08/01 → Landsat 없음
# 2019/08/02 → Sentinel-2 없음
# 2019/08/05 → Sentinel-2 없음
# 2019/08/06 → Landsat 없음
# 2019/08/07 → Sentinel-2 없음
# 2019/08/08 → Landsat 없음
# 2019/08/12 → Sentinel-2 없음
# 2019/08/13 → Landsat 없음
# 2019/08/19 → Sentinel-2 없음
# 2019/08/20 → Sentinel-2 없음
# 2019/08/22 → Sentinel-2 없음
# 2019/08/26 → Landsat 없음
# 2019/08/27 → Sentinel-2 없음
# 2019/09/02 → Landsat 없음
# 2019/09/03 → Sentinel-2 없음
# 2019/09/04 → Sentinel-2 없음
# 2019/09/05 → Landsat 없음
# 2019/09/09 → Sentinel-2 없음
# 2019/09/11 → Sentinel-2 없음
# 2019/09/16 → Sentinel-2 없음
# 2019/09/18 → Sentinel-2 없음
# 2019/09/19 → Sentinel-2 없음
# 2019/09/20 → Landsat 없음
# 2019/09/23 → Sentinel-2 없음
# 2019/09/24 → Sentinel-2 없음
# 2019/09/30 → Landsat 없음
# 2019/10/01 → Sentinel-2 없음
# 2019/10/02 → Sentinel-2 없음
# 2019/10/04 → Sentinel-2 없음
# 2019/10/07 → Landsat 없음
# 2019/10/08 → Sentinel-2 없음
# 2019/10/10 → Landsat 없음
# 2019/10/14 → Sentinel-2 없음
# 2019/10/15 → Landsat 없음
# 2019/10/16 → Sentinel-2 없음
# 2019/10/21 → Sentinel-2 없음
# 2019/10/22 → Sentinel-2 없음
# 2019/10/28 → Sentinel-2 없음
# 2019/10/29 → Sentinel-2 없음
# 2019/11/01 → Landsat 없음
# 2019/11/05 → Sentinel-2 없음
# 2019/11/06 → Landsat 없음
# 2019/11/07 → Sentinel-2 없음
# 2019/11/08 → Sentinel-2 없음
# 2019/11/11 → Landsat 없음
# 2019/11/12 → Sentinel-2 없음
# 2019/11/13 → Sentinel-2 없음
# 2019/11/14 → Landsat 없음
# 2019/11/15 → Sentinel-2 없음
# 2019/11/18 → Sentinel-2 없음
# 2019/11/19 → Landsat 없음
# 2019/11/21 → Sentinel-2 없음
# 2019/11/25 → Sentinel-2 없음
# 2019/11/26 → Sentinel-2 없음
# 2019/12/02 → Sentinel-2 없음
# 2019/12/03 → Sentinel-2 없음
# 2019/12/04 → Landsat 없음
# 2019/12/05 → Sentinel-2 없음
# 2019/12/06 → Sentinel-2 없음
# 2019/12/09 → Landsat 없음
# 2019/12/10 → Sentinel-2 없음
# 2019/12/11 → Sentinel-2 없음
# 2019/12/16 → Landsat 없음
# 2019/12/17 → Sentinel-2 없음
# 2019/12/23 → Sentinel-2 없음
# 2019/12/30 → Sentinel-2 없음
# 2020/01/02 → Sentinel-2 없음
# 2020/01/03 → Landsat 없음
# 2020/01/06 → Sentinel-2 없음
# 2020/01/07 → Sentinel-2 없음
# 2020/01/08 → Landsat 없음
# 2020/01/09 → Sentinel-2 없음
# 2020/01/10 → Sentinel-2 없음
# 2020/01/13 → Landsat 없음
# 2020/01/14 → Sentinel-2 없음
# 2020/01/15 → Sentinel-2 없음
# 2020/01/16 → Sentinel-2 없음
# 2020/01/20 → Landsat 없음
# 2020/01/21 → Sentinel-2 없음
# 2020/01/22 → Sentinel-2 없음
# 2020/01/28 → Landsat 없음
# 2020/02/03 → Sentinel-2 없음
# 2020/02/04 → Landsat 없음
# 2020/02/05 → Sentinel-2 없음
# 2020/02/06 → Sentinel-2 없음
# 2020/02/10 → Sentinel-2 없음
# 2020/02/11 → Sentinel-2 없음
# 2020/02/12 → Landsat 없음
# 2020/02/13 → Sentinel-2 없음
# 2020/02/14 → Sentinel-2 없음
# 2020/02/18 → Sentinel-2 없음
# 2020/02/19 → Sentinel-2 없음
# 2020/02/25 → Sentinel-2 없음
# 2020/03/02 → Sentinel-2 없음
# 2020/03/03 → Landsat 없음
# 2020/03/04 → Sentinel-2 없음
# 2020/03/05 → Landsat 없음
# 2020/03/06 → Sentinel-2 없음
# 2020/03/09 → Sentinel-2 없음
# 2020/03/10 → Landsat 없음
# 2020/03/11 → Sentinel-2 없음
# 2020/03/13 → Landsat 없음
# 2020/03/16 → Sentinel-2 없음
# 2020/03/17 → Sentinel-2 없음
# 2020/03/23 → Landsat 없음
# 2020/03/24 → Sentinel-2 없음
# 2020/03/25 → Sentinel-2 없음
# 2020/03/30 → Sentinel-2 없음
# 2020/03/31 → Sentinel-2 없음
# 2020/04/01 → Sentinel-2 없음
# 2020/04/02 → Landsat 없음
# 2020/04/03 → Sentinel-2 없음
# 2020/04/06 → Sentinel-2 없음
# 2020/04/07 → Landsat 없음
# 2020/04/08 → Sentinel-2 없음
# 2020/04/09 → Sentinel-2 없음
# 2020/04/13 → Sentinel-2 없음
# 2020/04/16 → Sentinel-2 없음
# 2020/04/20 → Sentinel-2 없음
# 2020/04/21 → Sentinel-2 없음
# 2020/04/23 → Sentinel-2 없음
# 2020/04/24 → Sentinel-2 없음
# 2020/04/27 → Landsat 없음
# 2020/04/28 → Sentinel-2 없음
# 2020/05/04 → Landsat 없음
# 2020/05/06 → Sentinel-2 없음
# 2020/05/08 → Sentinel-2 없음
# 2020/05/11 → Sentinel-2 없음
# 2020/05/12 → Landsat 없음
# 2020/05/13 → Sentinel-2 없음
# 2020/05/14 → Sentinel-2 없음
# 2020/05/18 → Sentinel-2 없음
# 2020/05/19 → Sentinel-2 없음
# 2020/05/20 → Sentinel-2 없음
# 2020/05/25 → Sentinel-2 없음
# 2020/05/26 → Sentinel-2 없음
# 2020/06/02 → Sentinel-2 없음
# 2020/06/03 → Landsat 없음
# 2020/06/04 → Sentinel-2 없음
# 2020/06/09 → Sentinel-2 없음
# 2020/06/10 → Sentinel-2 없음
# 2020/06/11 → Landsat 없음
# 2020/06/12 → Sentinel-2 없음
# 2020/06/15 → Sentinel-2 없음
# 2020/06/16 → Landsat 없음
# 2020/06/22 → Sentinel-2 없음
# 2020/06/23 → Sentinel-2 없음
# 2020/06/24 → Sentinel-2 없음
# 2020/06/29 → Sentinel-2 없음
# 2020/07/01 → Landsat 없음
# 2020/07/02 → Sentinel-2 없음
# 2020/07/06 → Landsat 없음
# 2020/07/07 → Sentinel-2 없음
# 2020/07/08 → Landsat 없음
# 2020/07/09 → Sentinel-2 없음
# 2020/07/13 → Landsat 없음
# 2020/07/14 → Sentinel-2 없음
# 2020/07/15 → Sentinel-2 없음
# 2020/07/16 → Landsat 없음
# 2020/07/17 → Sentinel-2 없음
# 2020/07/20 → Sentinel-2 없음
# 2020/07/21 → Landsat 없음
# 2020/07/22 → Sentinel-2 없음
# 2020/07/27 → Sentinel-2 없음
# 2020/07/28 → Sentinel-2 없음
# 2020/08/03 → Sentinel-2 없음
# 2020/08/04 → Sentinel-2 없음
# 2020/08/05 → Landsat 없음
# 2020/08/06 → Sentinel-2 없음
# 2020/08/10 → Landsat 없음
# 2020/08/11 → Sentinel-2 없음
# 2020/08/12 → Landsat 없음
# 2020/08/14 → Sentinel-2 없음
# 2020/08/18 → Sentinel-2 없음
# 2020/08/19 → Sentinel-2 없음
# 2020/08/21 → Sentinel-2 없음
# 2020/08/24 → Sentinel-2 없음
# 2020/08/25 → Landsat 없음
# 2020/08/27 → Sentinel-2 없음
# 2020/08/31 → Sentinel-2 없음
# 2020/09/01 → Landsat 없음
# 2020/09/02 → Sentinel-2 없음
# 2020/09/04 → Landsat 없음
# 2020/09/07 → Sentinel-2 없음
# 2020/09/08 → Sentinel-2 없음
# 2020/09/09 → Landsat 없음
# 2020/09/10 → Sentinel-2 없음
# 2020/09/14 → Landsat 없음
# 2020/09/15 → Sentinel-2 없음
# 2020/09/16 → Landsat 없음
# 2020/09/17 → Sentinel-2 없음
# 2020/09/22 → Sentinel-2 없음
# 2020/09/28 → Sentinel-2 없음
# 2020/10/05 → Sentinel-2 없음
# 2020/10/06 → Landsat 없음
# 2020/10/07 → Sentinel-2 없음
# 2020/10/08 → Sentinel-2 없음
# 2020/10/12 → Sentinel-2 없음
# 2020/10/13 → Sentinel-2 없음
# 2020/10/15 → Sentinel-2 없음
# 2020/10/19 → Landsat 없음
# 2020/10/20 → Sentinel-2 없음
# 2020/10/26 → Landsat 없음
# 2020/10/27 → Sentinel-2 없음
# 2020/11/02 → Sentinel-2 없음
# 2020/11/03 → Landsat 없음
# 2020/11/04 → Sentinel-2 없음
# 2020/11/05 → Landsat 없음
# 2020/11/06 → Sentinel-2 없음
# 2020/11/09 → Sentinel-2 없음
# 2020/11/10 → Landsat 없음
# 2020/11/11 → Sentinel-2 없음
# 2020/11/16 → Sentinel-2 없음
# 2020/11/17 → Sentinel-2 없음
# 2020/11/18 → Landsat 없음
# 2020/11/23 → Landsat 없음
# 2020/11/24 → Sentinel-2 없음
# 2020/11/30 → Landsat 없음
# 2020/12/01 → Sentinel-2 없음
# 2020/12/02 → Sentinel-2 없음
# 2020/12/03 → Landsat 없음
# 2020/12/04 → Sentinel-2 없음
# 2020/12/07 → Sentinel-2 없음
# 2020/12/09 → Sentinel-2 없음
# 2020/12/10 → Sentinel-2 없음
# 2020/12/14 → Sentinel-2 없음
# 2020/12/15 → Landsat 없음
# 2020/12/16 → Sentinel-2 없음
# 2020/12/21 → Sentinel-2 없음
# 2020/12/22 → Sentinel-2 없음
# 2020/12/28 → Landsat 없음
# 2021/01/04 → Landsat 없음
# 2021/01/05 → Sentinel-2 없음
# 2021/01/06 → Sentinel-2 없음
# 2021/01/07 → Landsat 없음
# 2021/01/11 → Sentinel-2 없음
# 2021/01/12 → Sentinel-2 없음
# 2021/01/13 → Sentinel-2 없음
# 2021/01/14 → Landsat 없음
# 2021/01/18 → Sentinel-2 없음
# 2021/01/19 → Landsat 없음
# 2021/01/20 → Sentinel-2 없음
# 2021/01/25 → Sentinel-2 없음
# 2021/01/26 → Sentinel-2 없음
# 2021/02/01 → Landsat 없음
# 2021/02/02 → Sentinel-2 없음
# 2021/02/04 → Sentinel-2 없음
# 2021/02/05 → Sentinel-2 없음
# 2021/02/08 → Landsat 없음
# 2021/02/09 → Sentinel-2 없음
# 2021/02/15 → Sentinel-2 없음
# 2021/02/16 → Landsat 없음
# 2021/02/19 → Sentinel-2 없음
# 2021/02/22 → Sentinel-2 없음
# 2021/02/23 → Sentinel-2 없음
# 2021/02/24 → Sentinel-2 없음
# 2021/03/02 → Sentinel-2 없음
# 2021/03/03 → Landsat 없음
# 2021/03/04 → Sentinel-2 없음
# 2021/03/08 → Landsat 없음
# 2021/03/09 → Sentinel-2 없음
# 2021/03/10 → Landsat 없음
# 2021/03/11 → Sentinel-2 없음
# 2021/03/15 → Landsat 없음
# 2021/03/16 → Sentinel-2 없음
# 2021/03/18 → Landsat 없음
# 2021/03/22 → Sentinel-2 없음
# 2021/03/29 → Sentinel-2 없음
# 2021/03/30 → Sentinel-2 없음
# 2021/04/01 → Sentinel-2 없음
# 2021/04/02 → Landsat 없음
# 2021/04/05 → Sentinel-2 없음
# 2021/04/06 → Sentinel-2 없음
# 2021/04/07 → Landsat 없음
# 2021/04/09 → Sentinel-2 없음
# 2021/04/12 → Landsat 없음
# 2021/04/13 → Sentinel-2 없음
# 2021/04/14 → Landsat 없음
# 2021/04/15 → Sentinel-2 없음
# 2021/04/16 → Sentinel-2 없음
# 2021/04/19 → Landsat 없음
# 2021/04/20 → Sentinel-2 없음
# 2021/04/22 → Landsat 없음
# 2021/04/26 → Sentinel-2 없음
# 2021/04/27 → Landsat 없음
# 2021/05/03 → Sentinel-2 없음
# 2021/05/04 → Landsat 없음
# 2021/05/06 → Sentinel-2 없음
# 2021/05/10 → Sentinel-2 없음
# 2021/05/11 → Sentinel-2 없음
# 2021/05/12 → Landsat 없음
# 2021/05/13 → Sentinel-2 없음
# 2021/05/18 → Sentinel-2 없음
# 2021/05/20 → Sentinel-2 없음
# 2021/05/24 → Landsat 없음
# 2021/05/25 → Sentinel-2 없음
# 2021/05/31 → Sentinel-2 없음
# 2021/06/01 → Landsat 없음
# 2021/06/02 → Sentinel-2 없음
# 2021/06/03 → Sentinel-2 없음
# 2021/06/04 → Sentinel-2 없음
# 2021/06/07 → Sentinel-2 없음
# 2021/06/08 → Landsat 없음
# 2021/06/10 → Sentinel-2 없음
# 2021/06/14 → Sentinel-2 없음
# 2021/06/15 → Sentinel-2 없음
# 2021/06/21 → Landsat 없음
# 2021/06/22 → Sentinel-2 없음
# 2021/06/28 → Landsat 없음
# 2021/06/29 → Sentinel-2 없음
# 2021/07/01 → Landsat 없음
# 2021/07/02 → Sentinel-2 없음
# 2021/07/05 → Sentinel-2 없음
# 2021/07/07 → Sentinel-2 없음
# 2021/07/08 → Sentinel-2 없음
# 2021/07/12 → Sentinel-2 없음
# 2021/07/14 → Sentinel-2 없음
# 2021/07/15 → Sentinel-2 없음
# 2021/07/19 → Sentinel-2 없음
# 2021/07/20 → Sentinel-2 없음
# 2021/07/26 → Landsat 없음
# 2021/07/27 → Sentinel-2 없음
# 2021/08/02 → Landsat 없음
# 2021/08/03 → Sentinel-2 없음
# 2021/08/04 → Sentinel-2 없음
# 2021/08/09 → Sentinel-2 없음
# 2021/08/10 → Landsat 없음
# 2021/08/11 → Sentinel-2 없음
# 2021/08/12 → Sentinel-2 없음
# 2021/08/17 → Landsat 없음
# 2021/08/18 → Sentinel-2 없음
# 2021/08/23 → Sentinel-2 없음
# 2021/08/25 → Landsat 없음
# 2021/08/26 → Sentinel-2 없음
# 2021/08/31 → Sentinel-2 없음
# 2021/09/01 → Landsat 없음
# 2021/09/02 → Sentinel-2 없음
# 2021/09/07 → Sentinel-2 없음
# 2021/09/08 → Sentinel-2 없음
# 2021/09/09 → Landsat 없음
# 2021/09/10 → Sentinel-2 없음
# 2021/09/13 → Sentinel-2 없음
# 2021/09/15 → Sentinel-2 없음
# 2021/09/23 → Sentinel-2 없음
# 2021/09/27 → Sentinel-2 없음
# 2021/09/28 → Sentinel-2 없음
# 2021/10/05 → Sentinel-2 없음
# 2021/10/06 → Landsat 없음
# 2021/10/07 → Sentinel-2 없음
# 2021/10/08 → Sentinel-2 없음
# 2021/10/12 → Sentinel-2 없음
# 2021/10/13 → Sentinel-2 없음
# 2021/10/14 → Landsat 없음
# 2021/10/15 → Sentinel-2 없음
# 2021/10/18 → Sentinel-2 없음
# 2021/10/19 → Landsat 없음
# 2021/10/21 → Landsat 없음
# 2021/10/25 → Sentinel-2 없음
# 2021/10/26 → Sentinel-2 없음
# 2021/11/01 → Sentinel-2 없음
# 2021/11/02 → Sentinel-2 없음
# 2021/11/03 → Landsat 없음
# 2021/11/04 → Sentinel-2 없음
# 2021/11/08 → Landsat 없음
# 2021/11/09 → Sentinel-2 없음
# 2021/11/10 → Sentinel-2 없음
# 2021/11/11 → Sentinel-2 없음
# 2021/11/12 → Sentinel-2 없음
# 2021/11/15 → Landsat 없음
# 2021/11/16 → Sentinel-2 없음
# 2021/11/17 → Sentinel-2 없음
# 2021/11/19 → Sentinel-2 없음
# 2021/11/22 → Sentinel-2 없음
# 2021/11/23 → Landsat 없음
# 2021/11/24 → Sentinel-2 없음
# 2021/11/29 → Sentinel-2 없음
# 2021/11/30 → Sentinel-2 없음
# 2021/12/01 → Sentinel-2 없음
# 2021/12/02 → Sentinel-2 없음
# 2021/12/03 → Landsat 없음
# 2021/12/06 → Sentinel-2 없음
# 2021/12/07 → Sentinel-2 없음
# 2021/12/08 → Landsat 없음
# 2021/12/09 → Sentinel-2 없음
# 2021/12/10 → Sentinel-2 없음
# 2021/12/14 → Sentinel-2 없음
# 2021/12/15 → Sentinel-2 없음
# 2021/12/21 → Sentinel-2 없음
# 2021/12/27 → Sentinel-2 없음
# 2022/01/03 → Sentinel-2 없음
# 2022/01/05 → Sentinel-2 없음
# 2022/01/06 → Sentinel-2 없음
# 2022/01/07 → Landsat 없음
# 2022/01/10 → Sentinel-2 없음
# 2022/01/11 → Sentinel-2 없음
# 2022/01/12 → Landsat 없음
# 2022/01/17 → Landsat 없음
# 2022/01/18 → Sentinel-2 없음
# 2022/01/19 → Sentinel-2 없음
# 2022/01/24 → Landsat 없음
# 2022/01/25 → Sentinel-2 없음
# 2022/02/03 → Landsat 없음
# 2022/02/04 → Sentinel-2 없음
# 2022/02/07 → Sentinel-2 없음
# 2022/02/08 → Landsat 없음
# 2022/02/09 → Sentinel-2 없음
# 2022/02/10 → Sentinel-2 없음
# 2022/02/14 → Sentinel-2 없음
# 2022/02/15 → Sentinel-2 없음
# 2022/02/22 → Sentinel-2 없음
# 2022/02/24 → Sentinel-2 없음
# 2022/02/28 → Landsat 없음
# 2022/03/02 → Sentinel-2 없음
# 2022/03/03 → Landsat 없음
# 2022/03/04 → Sentinel-2 없음
# 2022/03/07 → Sentinel-2 없음
# 2022/03/08 → Landsat 없음
# 2022/03/11 → Sentinel-2 없음
# 2022/03/14 → Sentinel-2 없음
# 2022/03/15 → Landsat 없음
# 2022/03/16 → Sentinel-2 없음
# 2022/03/17 → Sentinel-2 없음
# 2022/03/21 → Sentinel-2 없음
# 2022/03/22 → Sentinel-2 없음
# 2022/03/23 → Landsat 없음
# 2022/03/28 → Landsat 없음
# 2022/03/29 → Sentinel-2 없음
# 2022/04/05 → Sentinel-2 없음
# 2022/04/06 → Sentinel-2 없음
# 2022/04/07 → Landsat 없음
# 2022/04/08 → Sentinel-2 없음
# 2022/04/11 → Sentinel-2 없음
# 2022/04/13 → Sentinel-2 없음
# 2022/04/14 → Landsat 없음
# 2022/04/18 → Sentinel-2 없음
# 2022/04/19 → Sentinel-2 없음
# 2022/04/20 → Sentinel-2 없음
# 2022/04/21 → Sentinel-2 없음
# 2022/04/25 → Sentinel-2 없음
# 2022/04/26 → Sentinel-2 없음
# 2022/05/02 → Landsat 없음
# 2022/05/03 → Sentinel-2 없음
# 2022/05/09 → Landsat 없음
# 2022/05/10 → Sentinel-2 없음
# 2022/05/11 → Sentinel-2 없음
# 2022/05/12 → Sentinel-2 없음
# 2022/05/16 → Sentinel-2 없음
# 2022/05/17 → Landsat 없음
# 2022/05/18 → Sentinel-2 없음
# 2022/05/19 → Sentinel-2 없음
# 2022/05/23 → Sentinel-2 없음
# 2022/05/24 → Sentinel-2 없음
# 2022/05/25 → Sentinel-2 없음
# 2022/05/26 → Sentinel-2 없음
# 2022/05/30 → Sentinel-2 없음
# 2022/05/31 → Sentinel-2 없음
# 2022/06/02 → Sentinel-2 없음
# 2022/06/03 → Sentinel-2 없음
# 2022/06/07 → Sentinel-2 없음
# 2022/06/08 → Landsat 없음
# 2022/06/09 → Sentinel-2 없음
# 2022/06/14 → Sentinel-2 없음
# 2022/06/15 → Sentinel-2 없음
# 2022/06/17 → Sentinel-2 없음
# 2022/06/20 → Sentinel-2 없음
# 2022/06/27 → Sentinel-2 없음
# 2022/06/28 → Sentinel-2 없음
# 2022/07/04 → Sentinel-2 없음
# 2022/07/05 → Sentinel-2 없음
# 2022/07/06 → Landsat 없음
# 2022/07/07 → Sentinel-2 없음
# 2022/07/08 → Sentinel-2 없음
# 2022/07/11 → Landsat 없음
# 2022/07/12 → Sentinel-2 없음
# 2022/07/14 → Sentinel-2 없음
# 2022/07/18 → Landsat 없음
# 2022/07/19 → Sentinel-2 없음
# 2022/07/20 → Sentinel-2 없음
# 2022/07/25 → Sentinel-2 없음
# 2022/07/26 → Landsat 없음
# 2022/08/01 → Sentinel-2 없음
# 2022/08/02 → Landsat 없음
# 2022/08/03 → Sentinel-2 없음
# 2022/08/04 → Sentinel-2 없음
# 2022/08/08 → Sentinel-2 없음
# 2022/08/09 → Sentinel-2 없음
# 2022/08/16 → Sentinel-2 없음
# 2022/08/17 → Sentinel-2 없음
# 2022/08/19 → Sentinel-2 없음
# 2022/08/22 → Landsat 없음
# 2022/08/23 → Sentinel-2 없음
# 2022/08/25 → Landsat 없음
# 2022/08/29 → Sentinel-2 없음
# 2022/08/30 → Landsat 없음
# 2022/09/02 → Sentinel-2 없음
# 2022/09/05 → Sentinel-2 없음
# 2022/09/06 → Sentinel-2 없음
# 2022/09/07 → Sentinel-2 없음
# 2022/09/13 → Sentinel-2 없음
# 2022/09/14 → Landsat 없음
# 2022/09/15 → Sentinel-2 없음
# 2022/09/19 → Landsat 없음
# 2022/09/20 → Sentinel-2 없음
# 2022/09/21 → Sentinel-2 없음
# 2022/09/22 → Sentinel-2 없음
# 2022/09/27 → Sentinel-2 없음
# 2022/10/04 → Landsat 없음
# 2022/10/05 → Sentinel-2 없음
# 2022/10/06 → Landsat 없음
# 2022/10/07 → Sentinel-2 없음
# 2022/10/12 → Sentinel-2 없음
# 2022/10/13 → Sentinel-2 없음
# 2022/10/17 → Sentinel-2 없음
# 2022/10/18 → Sentinel-2 없음
# 2022/10/20 → Sentinel-2 없음
# 2022/10/24 → Landsat 없음
# 2022/10/25 → Sentinel-2 없음
# 2022/10/31 → Landsat 없음
# 2022/11/01 → Sentinel-2 없음
# 2022/11/02 → Sentinel-2 없음
# 2022/11/03 → Landsat 없음
# 2022/11/07 → Sentinel-2 없음
# 2022/11/08 → Landsat 없음
# 2022/11/09 → Sentinel-2 없음
# 2022/11/10 → Sentinel-2 없음
# 2022/11/14 → Sentinel-2 없음
# 2022/11/15 → Landsat 없음
# 2022/11/16 → Sentinel-2 없음
# 2022/11/17 → Sentinel-2 없음
# 2022/11/21 → Sentinel-2 없음
# 2022/11/22 → Sentinel-2 없음
# 2022/11/23 → Landsat 없음
# 2022/11/29 → Sentinel-2 없음
# 2022/12/01 → Sentinel-2 없음
# 2022/12/05 → Landsat 없음
# 2022/12/06 → Sentinel-2 없음
# 2022/12/07 → Sentinel-2 없음
# 2022/12/08 → Landsat 없음
# 2022/12/12 → Sentinel-2 없음
# 2022/12/13 → Landsat 없음
# 2022/12/14 → Sentinel-2 없음
# 2022/12/19 → Sentinel-2 없음
# 2022/12/27 → Sentinel-2 없음
# 2023/01/02 → Landsat 없음
# 2023/01/03 → Sentinel-2 없음
# 2023/01/04 → Landsat 없음
# 2023/01/05 → Sentinel-2 없음
# 2023/01/06 → Sentinel-2 없음
# 2023/01/09 → Landsat 없음
# 2023/01/10 → Sentinel-2 없음
# 2023/01/11 → Sentinel-2 없음
# 2023/01/16 → Sentinel-2 없음
# 2023/01/17 → Landsat 없음
# 2023/01/18 → Sentinel-2 없음
# 2023/01/25 → Sentinel-2 없음
# 2023/01/30 → Sentinel-2 없음
# 2023/01/31 → Sentinel-2 없음
# 2023/02/02 → Sentinel-2 없음
# 2023/02/06 → Landsat 없음
# 2023/02/07 → Sentinel-2 없음
# 2023/02/08 → Sentinel-2 없음
# 2023/02/09 → Sentinel-2 없음
# 2023/02/13 → Landsat 없음
# 2023/02/14 → Sentinel-2 없음
# 2023/02/20 → Sentinel-2 없음
# 2023/02/21 → Landsat 없음
# 2023/02/23 → Sentinel-2 없음
# 2023/02/27 → Sentinel-2 없음
# 2023/02/28 → Sentinel-2 없음
# 2023/03/06 → Sentinel-2 없음
# 2023/03/07 → Sentinel-2 없음
# 2023/03/08 → Landsat 없음
# 2023/03/09 → Sentinel-2 없음
# 2023/03/14 → Sentinel-2 없음
# 2023/03/15 → Sentinel-2 없음
# 2023/03/21 → Sentinel-2 없음
# 2023/03/23 → Landsat 없음
# 2023/03/24 → Sentinel-2 없음
# 2023/03/27 → Sentinel-2 없음
# 2023/04/03 → Sentinel-2 없음
# 2023/04/04 → Landsat 없음
# 2023/04/05 → Sentinel-2 없음
# 2023/04/06 → Sentinel-2 없음
# 2023/04/07 → Landsat 없음
# 2023/04/10 → Sentinel-2 없음
# 2023/04/11 → Sentinel-2 없음
# 2023/04/12 → Landsat 없음
# 2023/04/13 → Sentinel-2 없음
# 2023/04/17 → Landsat 없음
# 2023/04/18 → Sentinel-2 없음
# 2023/04/24 → Landsat 없음
# 2023/04/25 → Sentinel-2 없음
# 2023/05/01 → Sentinel-2 없음
# 2023/05/02 → Landsat 없음
# 2023/05/03 → Sentinel-2 없음
# 2023/05/04 → Landsat 없음
# 2023/05/08 → Sentinel-2 없음
# 2023/05/10 → Sentinel-2 없음
# 2023/05/11 → Sentinel-2 없음
# 2023/05/12 → Landsat 없음
# 2023/05/15 → Sentinel-2 없음
# 2023/05/16 → Sentinel-2 없음
# 2023/05/22 → Landsat 없음
# 2023/05/23 → Sentinel-2 없음
# 2023/05/30 → Sentinel-2 없음
# 2023/05/31 → Sentinel-2 없음
# 2023/06/05 → Sentinel-2 없음
# 2023/06/07 → Sentinel-2 없음
# 2023/06/08 → Landsat 없음
# 2023/06/09 → Sentinel-2 없음
# 2023/06/12 → Sentinel-2 없음
# 2023/06/13 → Landsat 없음
# 2023/06/14 → Sentinel-2 없음
# 2023/06/15 → Sentinel-2 없음
# 2023/06/19 → Sentinel-2 없음
# 2023/06/20 → Sentinel-2 없음
# 2023/06/23 → Sentinel-2 없음
# 2023/06/26 → Landsat 없음
# 2023/06/27 → Sentinel-2 없음
# 2023/06/28 → Sentinel-2 없음
# 2023/07/04 → Sentinel-2 없음
# 2023/07/05 → Sentinel-2 없음
# 2023/07/06 → Landsat 없음
# 2023/07/10 → Sentinel-2 없음
# 2023/07/11 → Landsat 없음
# 2023/07/12 → Sentinel-2 없음
# 2023/07/13 → Landsat 없음
# 2023/07/17 → Sentinel-2 없음
# 2023/07/18 → Sentinel-2 없음
# 2023/07/20 → Sentinel-2 없음
# 2023/07/24 → Sentinel-2 없음
# 2023/07/31 → Landsat 없음
# 2023/08/01 → Sentinel-2 없음
# 2023/08/02 → Landsat 없음
# 2023/08/03 → Sentinel-2 없음
# 2023/08/04 → Sentinel-2 없음
# 2023/08/07 → Landsat 없음
# 2023/08/08 → Sentinel-2 없음
# 2023/08/09 → Sentinel-2 없음
# 2023/08/11 → Sentinel-2 없음
# 2023/08/14 → Sentinel-2 없음
# 2023/08/16 → Sentinel-2 없음
# 2023/08/17 → Sentinel-2 없음
# 2023/08/21 → Sentinel-2 없음
# 2023/08/22 → Landsat 없음
# 2023/08/28 → Sentinel-2 없음
# 2023/08/29 → Sentinel-2 없음
# 2023/08/30 → Landsat 없음
# 2023/09/05 → Sentinel-2 없음
# 2023/09/07 → Sentinel-2 없음
# 2023/09/08 → Sentinel-2 없음
# 2023/09/11 → Landsat 없음
# 2023/09/12 → Sentinel-2 없음
# 2023/09/13 → Sentinel-2 없음
# 2023/09/14 → Landsat 없음
# 2023/09/18 → Sentinel-2 없음
# 2023/09/19 → Landsat 없음
# 2023/09/25 → Sentinel-2 없음
# 2023/09/26 → Sentinel-2 없음
# 2023/10/04 → Landsat 없음
# 2023/10/05 → Sentinel-2 없음
# 2023/10/06 → Sentinel-2 없음
# 2023/10/10 → Sentinel-2 없음
# 2023/10/11 → Landsat 없음
# 2023/10/12 → Sentinel-2 없음
# 2023/10/13 → Sentinel-2 없음
# 2023/10/16 → Landsat 없음
# 2023/10/17 → Sentinel-2 없음
# 2023/10/23 → Sentinel-2 없음
# 2023/10/26 → Sentinel-2 없음
# 2023/10/30 → Sentinel-2 없음
# 2023/10/31 → Sentinel-2 없음
# 2023/11/01 → Sentinel-2 없음
# 2023/11/02 → Sentinel-2 없음
# 2023/11/06 → Sentinel-2 없음
# 2023/11/07 → Sentinel-2 없음
# 2023/11/09 → Sentinel-2 없음
# 2023/11/10 → Sentinel-2 없음
# 2023/11/13 → Landsat 없음
# 2023/11/14 → Sentinel-2 없음
# 2023/11/15 → Sentinel-2 없음
# 2023/11/16 → Sentinel-2 없음
# 2023/11/20 → Landsat 없음
# 2023/11/21 → Sentinel-2 없음
# 2023/11/22 → Sentinel-2 없음
# 2023/11/27 → Sentinel-2 없음
# 2023/11/28 → Landsat 없음
# 2023/12/01 → Sentinel-2 없음
# 2023/12/04 → Sentinel-2 없음
# 2023/12/05 → Landsat 없음
# 2023/12/06 → Sentinel-2 없음
# 2023/12/07 → Sentinel-2 없음
# 2023/12/11 → Sentinel-2 없음
# 2023/12/12 → Sentinel-2 없음
# 2023/12/13 → Landsat 없음
# 2023/12/15 → Landsat 없음
# 2023/12/19 → Sentinel-2 없음
# 2023/12/26 → Sentinel-2 없음
# 2024/01/03 → Sentinel-2 없음
# 2024/01/05 → Sentinel-2 없음
# 2024/01/08 → Sentinel-2 없음
# 2024/01/09 → Landsat 없음
# 2024/01/10 → Sentinel-2 없음
# 2024/01/11 → Sentinel-2 없음
# 2024/01/12 → Sentinel-2 없음
# 2024/01/15 → Sentinel-2 없음
# 2024/01/16 → Sentinel-2 없음
# 2024/01/17 → Landsat 없음
# 2024/01/22 → Landsat 없음
# 2024/01/23 → Sentinel-2 없음
# 2024/01/29 → Landsat 없음
# 2024/01/30 → Sentinel-2 없음
# 2024/02/01 → Landsat 없음
# 2024/02/02 → Sentinel-2 없음
# 2024/02/05 → Sentinel-2 없음
# 2024/02/06 → Landsat 없음
# 2024/02/07 → Sentinel-2 없음
# 2024/02/14 → Sentinel-2 없음
# 2024/02/15 → Sentinel-2 없음
# 2024/02/16 → Landsat 없음
# 2024/02/19 → Sentinel-2 없음
# 2024/02/20 → Sentinel-2 없음
# 2024/02/26 → Landsat 없음
# 2024/02/27 → Sentinel-2 없음
# 2024/03/04 → Landsat 없음
# 2024/03/05 → Sentinel-2 없음
# 2024/03/06 → Sentinel-2 없음
# 2024/03/11 → Sentinel-2 없음
# 2024/03/12 → Landsat 없음
# 2024/03/13 → Sentinel-2 없음
# 2024/03/14 → Sentinel-2 없음
# 2024/03/15 → Sentinel-2 없음
# 2024/03/18 → Sentinel-2 없음
# 2024/03/19 → Landsat 없음
# 2024/03/20 → Sentinel-2 없음
# 2024/03/25 → Sentinel-2 없음
# 2024/04/02 → Sentinel-2 없음
# 2024/04/03 → Landsat 없음
# 2024/04/04 → Sentinel-2 없음
# 2024/04/09 → Sentinel-2 없음
# 2024/04/11 → Landsat 없음
# 2024/04/12 → Sentinel-2 없음
# 2024/04/15 → Sentinel-2 없음
# 2024/04/18 → Sentinel-2 없음
# 2024/04/22 → Sentinel-2 없음
# 2024/04/23 → Sentinel-2 없음
# 2024/04/24 → Sentinel-2 없음
# 2024/04/29 → Sentinel-2 없음
# 2024/04/30 → Sentinel-2 없음
# 2024/05/02 → Sentinel-2 없음
# 2024/05/03 → Landsat 없음
# 2024/05/07 → Sentinel-2 없음
# 2024/05/08 → Landsat 없음
# 2024/05/09 → Sentinel-2 없음
# 2024/05/10 → Sentinel-2 없음
# 2024/05/13 → Landsat 없음
# 2024/05/14 → Sentinel-2 없음
# 2024/05/16 → Landsat 없음
# 2024/05/20 → Sentinel-2 없음
# 2024/05/21 → Landsat 없음
# 2024/05/22 → Sentinel-2 없음
# 2024/05/27 → Sentinel-2 없음
# 2024/05/28 → Landsat 없음
# 2024/06/03 → Sentinel-2 없음
# 2024/06/04 → Sentinel-2 없음
# 2024/06/05 → Landsat 없음
# 2024/06/11 → Sentinel-2 없음
# 2024/06/13 → Sentinel-2 없음
# 2024/06/17 → Landsat 없음
# 2024/06/18 → Sentinel-2 없음
# 2024/06/21 → Sentinel-2 없음
# 2024/06/24 → Sentinel-2 없음
# 2024/06/25 → Landsat 없음
# 2024/07/01 → Sentinel-2 없음
# 2024/07/02 → Sentinel-2 없음
# 2024/07/03 → Sentinel-2 없음
# 2024/07/04 → Sentinel-2 없음
# 2024/07/08 → Sentinel-2 없음
# 2024/07/09 → Sentinel-2 없음
# 2024/07/10 → Landsat 없음
# 2024/07/11 → Sentinel-2 없음
# 2024/07/15 → Landsat 없음
# 2024/07/16 → Sentinel-2 없음
# 2024/07/17 → Landsat 없음
# 2024/07/19 → Sentinel-2 없음
# 2024/07/22 → Landsat 없음
# 2024/07/23 → Sentinel-2 없음
# 2024/07/29 → Sentinel-2 없음
# 2024/07/30 → Landsat 없음
# 2024/08/01 → Landsat 없음
# 2024/08/02 → Sentinel-2 없음
# 2024/08/05 → Sentinel-2 없음
# 2024/08/07 → Sentinel-2 없음
# 2024/08/08 → Sentinel-2 없음
# 2024/08/12 → Sentinel-2 없음
# 2024/08/13 → Sentinel-2 없음
# 2024/08/19 → Landsat 없음
# 2024/08/20 → Sentinel-2 없음
# 2024/08/26 → Landsat 없음
# 2024/08/27 → Sentinel-2 없음
# 2024/09/02 → Sentinel-2 없음
# 2024/09/03 → Landsat 없음
# 2024/09/04 → Sentinel-2 없음
# 2024/09/05 → Landsat 없음
# 2024/09/06 → Sentinel-2 없음
# 2024/09/09 → Sentinel-2 없음
# 2024/09/10 → Landsat 없음
# 2024/09/11 → Sentinel-2 없음
# 2024/09/19 → Sentinel-2 없음
# 2024/10/02 → Sentinel-2 없음
# 2024/10/07 → Sentinel-2 없음
# 2024/10/11 → Sentinel-2 없음
# 2024/10/14 → Sentinel-2 없음
# 2024/10/15 → Landsat 없음
# 2024/10/16 → Sentinel-2 없음
# 2024/10/17 → Sentinel-2 없음
# 2024/10/21 → Sentinel-2 없음
# 2024/10/22 → Sentinel-2 없음
# 2024/10/28 → Landsat 없음
# 2024/10/29 → Sentinel-2 없음
# 2024/11/01 → Sentinel-2 없음
# 2024/11/04 → Landsat 없음
# 2024/11/05 → Sentinel-2 없음
# 2024/11/06 → Sentinel-2 없음
# 2024/11/07 → Landsat 없음
# 2024/11/11 → Sentinel-2 없음
# 2024/11/12 → Landsat 없음
# 2024/11/13 → Sentinel-2 없음
# 2024/11/18 → Sentinel-2 없음
# 2024/11/19 → Sentinel-2 없음
# 2024/11/25 → Sentinel-2 없음
# 2024/11/26 → Sentinel-2 없음
# 2024/12/02 → Landsat 없음
# 2024/12/03 → Sentinel-2 없음
# 2024/12/05 → Sentinel-2 없음
# 2024/12/06 → Sentinel-2 없음
# 2024/12/09 → Landsat 없음
# 2024/12/10 → Sentinel-2 없음
# 2024/12/11 → Sentinel-2 없음
# 2024/12/16 → Sentinel-2 없음
# 2024/12/17 → Landsat 없음
# 2024/12/23 → Sentinel-2 없음
# 2024/12/30 → Sentinel-2 없음
# 2025/01/02 → Sentinel-2 없음
# 2025/01/07 → Sentinel-2 없음
# 2025/01/08 → Sentinel-2 없음
# 2025/01/09 → Sentinel-2 없음
# 2025/01/14 → Sentinel-2 없음
# 2025/01/15 → Sentinel-2 없음
# 2025/01/20 → Sentinel-2 없음
# 2025/02/03 → Sentinel-2 없음
# 2025/02/04 → Sentinel-2 없음
# 2025/02/05 → Landsat 없음
# 2025/02/06 → Sentinel-2 없음
# 2025/02/10 → Landsat 없음
# 2025/02/11 → Sentinel-2 없음
# 2025/02/12 → Landsat 없음
# 2025/02/13 → Sentinel-2 없음
# 2025/02/17 → Landsat 없음
# 2025/02/18 → Sentinel-2 없음
# 2025/02/19 → Sentinel-2 없음
# 2025/02/24 → Sentinel-2 없음
# 2025/02/25 → Landsat 없음
# 2025/03/04 → Landsat 없음
# 2025/03/05 → Sentinel-2 없음
# 2025/03/06 → Sentinel-2 없음
# 2025/03/07 → Landsat 없음
# 2025/03/10 → Sentinel-2 없음
# 2025/03/11 → Sentinel-2 없음
# 2025/03/12 → Landsat 없음
# 2025/03/13 → Sentinel-2 없음
# 2025/03/18 → Sentinel-2 없음
# 2025/03/20 → Sentinel-2 없음
# 2025/03/24 → Landsat 없음
# 2025/03/31 → Sentinel-2 없음
# 2025/04/01 → Landsat 없음
# 2025/04/02 → Sentinel-2 없음
# 2025/04/04 → Sentinel-2 없음
# 2025/04/07 → Sentinel-2 없음
# 2025/04/08 → Landsat 없음
# 2025/04/09 → Sentinel-2 없음
# 2025/04/10 → Sentinel-2 없음
# 2025/04/14 → Sentinel-2 없음
# 2025/04/15 → Sentinel-2 없음
# 2025/04/16 → Landsat 없음
# 2025/04/21 → Landsat 없음
# 2025/04/28 → Landsat 없음
# 2025/05/07 → Sentinel-2 없음
# 2025/05/08 → Landsat 없음
# 2025/05/09 → Sentinel-2 없음
# 2025/05/12 → Sentinel-2 없음
# 2025/05/14 → Sentinel-2 없음
# 2025/05/15 → Sentinel-2 없음
# 2025/05/19 → Sentinel-2 없음
# 2025/05/20 → Sentinel-2 없음
# 2025/05/22 → Sentinel-2 없음
# 2025/05/26 → Landsat 없음
# 2025/06/02 → Landsat 없음
# 2025/06/04 → Sentinel-2 없음
# 2025/06/09 → Sentinel-2 없음
# 2025/06/10 → Landsat 없음
# 2025/06/11 → Sentinel-2 없음
# 2025/06/12 → Landsat 없음
# 2025/06/16 → Sentinel-2 없음
# 2025/06/17 → Landsat 없음
# 2025/06/18 → Sentinel-2 없음
# 2025/06/23 → Sentinel-2 없음
# 2025/07/01 → Sentinel-2 없음
# 2025/07/02 → Landsat 없음
# 2025/07/03 → Sentinel-2 없음
# 2025/07/08 → Sentinel-2 없음
# 2025/07/09 → Landsat 없음
# 2025/07/10 → Landsat 없음
# 2025/07/14 → Sentinel-2 없음
# 2025/07/15 → Landsat 없음
# 2025/07/21 → Sentinel-2 없음
# 2025/07/22 → Landsat 없음
# 2025/07/23 → Sentinel-2 없음
# 2025/07/24 → Sentinel-2 없음
# 2025/07/28 → Sentinel-2 없음
# 2025/08/04 → Landsat 없음
# 2025/08/05 → Sentinel-2 없음
# 2025/08/06 → Landsat 없음
# 2025/08/07 → Sentinel-2 없음
# 2025/08/11 → Landsat 없음
# 2025/08/12 → Sentinel-2 없음
# 2025/08/13 → Sentinel-2 없음
# 2025/08/14 → Landsat 없음
# 2025/08/18 → Landsat 없음
# 2025/08/20 → Sentinel-2 없음
# 2025/08/25 → Sentinel-2 없음
# 2025/08/27 → Sentinel-2 없음
# 2025/08/28 → Sentinel-2 없음
# 2025/09/01 → Sentinel-2 없음
# 2025/09/02 → Sentinel-2 없음
# 2025/09/04 → Sentinel-2 없음
# 2025/09/08 → Landsat 없음
# 2025/09/09 → Sentinel-2 없음
# 2025/09/11 → Sentinel-2 없음
# 2025/09/15 → Landsat 없음
# 2025/09/22 → Sentinel-2 없음
# 2025/09/23 → Landsat 없음
# 2025/09/25 → Sentinel-2 없음
# 2025/09/29 → Sentinel-2 없음
# 2025/10/01 → Sentinel-2 없음
# 2025/10/02 → Sentinel-2 없음
# 2025/10/10 → Landsat 없음
# 2025/10/13 → Landsat 없음
# 2025/10/14 → Sentinel-2 없음
# 2025/10/15 → Landsat 없음
# 2025/10/16 → Sentinel-2 없음
# 2025/10/20 → Landsat 없음
# 2025/10/21 → Sentinel-2 없음
# 2025/10/23 → Landsat 없음
# 2025/10/24 → Sentinel-2 없음
# 2025/10/27 → Sentinel-2 없음
# 2025/10/30 → Landsat 없음

# %%
print(df_out.head())
print(len(df_out))
print(df_out.columns)
# Out:
#       분류번호       측정소명       년/월/일       회차            경도            위도   채수시각  \
# 0  1010B50       춘천댐1  2018/12/19      1회차   127°39'.28"  37°58'44.33"  12:43
# 1  2018B10  남강댐3(진양호)  2019/03/11  1회차 상층부  127°58'38.4"   35°12'24.1"  10:30
# 2  2018B10  남강댐3(진양호)  2019/03/11  1회차 중층부  127°58'38.4"   35°12'24.1"  10:30
# 3  2018B10  남강댐3(진양호)  2019/03/11  1회차 하층부  127°58'38.4"   35°12'24.1"  10:30
# 4  5101B10       장흥댐1  2019/04/03  1회차 상층부    126°52'57"    34°45'4.2"  10:00
#
#    클로로필 a(㎎/㎥)   댐명 호소유형  ...     B7   B8  B8A     B9  SCL    idx  LST  \
# 0          4.5  춘천댐  dam  ...  230.0  280  227  407.0    6  44900  NaN
# 1          5.2  남강댐  dam  ...  120.0  136  126  116.0    6   7948  NaN
# 2          5.6  남강댐  dam  ...  120.0  136  126  116.0    6   7953  NaN
# 3          5.1  남강댐  dam  ...  120.0  136  126  116.0    6   7958  NaN
# 4          9.2  장흥댐  dam  ...   70.0   66   68  101.0    6   8298  NaN
#
#    LST_valid                             image_id_S2        image_id_Landsat
# 0          0  20181219T022109_20181219T022640_T52SCH  1_LC08_116034_20181219
# 1          0  20190311T020651_20190311T020648_T52SCD  1_LC08_114036_20190311
# 2          0  20190311T020651_20190311T020648_T52SCD  1_LC08_114036_20190311
# 3          0  20190311T020651_20190311T020648_T52SCD  1_LC08_114036_20190311
# 4          0  20190403T021651_20190403T021647_T52SBD  1_LC08_115036_20190403
#
# [5 rows x 28 columns]
# 193
# Index(['분류번호', '측정소명', '년/월/일', '회차', '경도', '위도', '채수시각', '클로로필 a(㎎/㎥)', '댐명',
#        '호소유형', 'B1', 'B11', 'B12', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8',
#        'B8A', 'B9', 'SCL', 'idx', 'LST', 'LST_valid', 'image_id_S2',
#        'image_id_Landsat'],
#       dtype='object')

# %%
df_out
# Out:
#         분류번호       측정소명       년/월/일       회차             경도            위도  \
# 0    1010B50       춘천댐1  2018/12/19      1회차    127°39'.28"  37°58'44.33"
# 1    2018B10  남강댐3(진양호)  2019/03/11  1회차 상층부   127°58'38.4"   35°12'24.1"
# 2    2018B10  남강댐3(진양호)  2019/03/11  1회차 중층부   127°58'38.4"   35°12'24.1"
# 3    2018B10  남강댐3(진양호)  2019/03/11  1회차 하층부   127°58'38.4"   35°12'24.1"
# 4    5101B10       장흥댐1  2019/04/03  1회차 상층부     126°52'57"    34°45'4.2"
# ..       ...        ...         ...      ...            ...           ...
# 188  4007B10      보성강댐1  2025/10/28  1회차 상층부   127°8'41.64"  34°48'21.53"
# 189  4007B20      보성강댐2  2025/10/28  1회차 상층부   127°7'38.64"  34°48'39.02"
# 190  4007B70       주암댐1  2025/10/28  3회차 상층부  127°14'26.74"   35°3'23.78"
# 191  4007B70       주암댐1  2025/10/28  3회차 중층부  127°14'26.74"   35°3'23.78"
# 192  4007B70       주암댐1  2025/10/28  3회차 하층부  127°14'26.74"   35°3'23.78"
#
#       채수시각  클로로필 a(㎎/㎥)    댐명 호소유형  ...     B7   B8  B8A     B9  SCL    idx  \
# 0    12:43          4.5   춘천댐  dam  ...  230.0  280  227  407.0    6  44900
# 1    10:30          5.2   남강댐  dam  ...  120.0  136  126  116.0    6   7948
# 2    10:30          5.6   남강댐  dam  ...  120.0  136  126  116.0    6   7953
# 3    10:30          5.1   남강댐  dam  ...  120.0  136  126  116.0    6   7958
# 4    10:00          9.2   장흥댐  dam  ...   70.0   66   68  101.0    6   8298
# ..     ...          ...   ...  ...  ...    ...  ...  ...    ...  ...    ...
# 188  11:25         11.8  보성강댐  dam  ...   97.0   81   40  385.0    6  18575
# 189  11:00          5.8  보성강댐  dam  ...  120.0   97  111  637.0    6  18576
# 190  10:10          6.0   주암댐  dam  ...   52.0   49   62   69.0    6  18577
# 191  10:10          5.8   주암댐  dam  ...   52.0   49   62   69.0    6  18578
# 192  10:10          0.4   주암댐  dam  ...   52.0   49   62   69.0    6  18579
#
#      LST  LST_valid                             image_id_S2  \
# 0    NaN          0  20181219T022109_20181219T022640_T52SCH
# 1    NaN          0  20190311T020651_20190311T020648_T52SCD
# 2    NaN          0  20190311T020651_20190311T020648_T52SCD
# 3    NaN          0  20190311T020651_20190311T020648_T52SCD
# 4    NaN          0  20190403T021651_20190403T021647_T52SBD
# ..   ...        ...                                     ...
# 188  NaN          0  20251028T021821_20251028T022504_T52SCD
# 189  NaN          0  20251028T021821_20251028T022504_T52SCD
# 190  NaN          0  20251028T021821_20251028T022504_T52SCD
# 191  NaN          0  20251028T021821_20251028T022504_T52SCD
# 192  NaN          0  20251028T021821_20251028T022504_T52SCD
#
#            image_id_Landsat
# 0    1_LC08_116034_20181219
# 1    1_LC08_114036_20190311
# 2    1_LC08_114036_20190311
# 3    1_LC08_114036_20190311
# 4    1_LC08_115036_20190403
# ..                      ...
# 188  1_LC08_115036_20251028
# 189  1_LC08_115036_20251028
# 190  1_LC08_115036_20251028
# 191  1_LC08_115036_20251028
# 192  1_LC08_115036_20251028
#
# [193 rows x 28 columns]

# %%
# DataFrame을 pickle로 저장
df_out.to_csv("/home/khs/data/csv/hoso_reservoir_fast.csv")

# %%
df = pd.read_csv("/home/khs/data/csv/hoso_reservoir_fast.csv")
df
# Out:
#      Unnamed: 0     분류번호       측정소명       년/월/일       회차            경도  \
# 0             0  1010B50       춘천댐1  2018/12/19      1회차   127°39'.28"
# 1             1  2018B10  남강댐3(진양호)  2019/03/11  1회차 상층부  127°58'38.4"
# 2             2  2018B10  남강댐3(진양호)  2019/03/11  1회차 중층부  127°58'38.4"
# 3             3  2018B10  남강댐3(진양호)  2019/03/11  1회차 하층부  127°58'38.4"
# 4             4  5101B10       장흥댐1  2019/04/03  1회차 상층부    126°52'57"
# ..          ...      ...        ...         ...      ...           ...
# 147         147  2015B20       합천댐2  2024/06/10  1회차 중층부   128°2'22.4"
# 148         148  2015B10       합천댐3  2024/06/10  1회차 중층부   128°1'58.8"
# 149         149  2015B30       합천댐1  2024/06/10  1회차 하층부   128°1'35.4"
# 150         150  2015B20       합천댐2  2024/06/10  1회차 하층부   128°2'22.4"
# 151         151  2015B10       합천댐3  2024/06/10  1회차 하층부   128°1'58.8"
#
#                위도   채수시각  클로로필 a(㎎/㎥)   댐명  ...   B6     B7   B8  B8A     B9  \
# 0    37°58'44.33"  12:43          4.5  춘천댐  ...  250  230.0  280  227  407.0
# 1     35°12'24.1"  10:30          5.2  남강댐  ...  117  120.0  136  126  116.0
# 2     35°12'24.1"  10:30          5.6  남강댐  ...  117  120.0  136  126  116.0
# 3     35°12'24.1"  10:30          5.1  남강댐  ...  117  120.0  136  126  116.0
# 4      34°45'4.2"  10:00          9.2  장흥댐  ...   76   70.0   66   68  101.0
# ..            ...    ...          ...  ...  ...  ...    ...  ...  ...    ...
# 147     35°33'42"  10:30          0.9  합천댐  ...    0    0.0    0    0    0.0
# 148    35°36'4.6"  10:00          0.9  합천댐  ...  444  414.0  328  356  209.0
# 149    35°32'2.2"  11:00          0.9  합천댐  ...    0    0.0    0    0    0.0
# 150     35°33'42"  10:30          0.9  합천댐  ...    0    0.0    0    0    0.0
# 151    35°36'4.6"  10:00          0.9  합천댐  ...  444  414.0  328  356  209.0
#
#      SCL    idx  LST                             image_id_S2  \
# 0      6  44900  NaN  20181219T022109_20181219T022640_T52SCH
# 1      6   7948  NaN  20190311T020651_20190311T020648_T52SCD
# 2      6   7953  NaN  20190311T020651_20190311T020648_T52SCD
# 3      6   7958  NaN  20190311T020651_20190311T020648_T52SCD
# 4      6   8298  NaN  20190403T021651_20190403T021647_T52SBD
# ..   ...    ...  ...                                     ...
# 147    6  48023  NaN  20240610T021539_20240610T021535_T52SDE
# 148    6  48024  NaN  20240610T021539_20240610T021535_T52SDE
# 149    6  48041  NaN  20240610T021539_20240610T021535_T52SDE
# 150    6  48042  NaN  20240610T021539_20240610T021535_T52SDE
# 151    6  48043  NaN  20240610T021539_20240610T021535_T52SDE
#
#            image_id_Landsat
# 0    1_LC08_116034_20181219
# 1    1_LC08_114036_20190311
# 2    1_LC08_114036_20190311
# 3    1_LC08_114036_20190311
# 4    1_LC08_115036_20190403
# ..                      ...
# 147  1_LC08_116034_20240610
# 148  1_LC08_116034_20240610
# 149  1_LC08_116034_20240610
# 150  1_LC08_116034_20240610
# 151  1_LC08_116034_20240610
#
# [152 rows x 28 columns]

# %% [markdown]
# 임시 매칭

# %%
import pandas as pd
import numpy as np
import ee
from datetime import timedelta

# Earth Engine 초기화 (이미 했으면 생략)
ee.Initialize()

# --------------------------------------------------
# 1. CSV 불러오기
# --------------------------------------------------
df = pd.read_csv("/home/khs/data/csv/hoso_reservoir_fast.csv")

# 날짜 컬럼 datetime 변환
df["년/월/일"] = pd.to_datetime(df["년/월/일"])

# 결과 저장용 리스트
results = []

# --------------------------------------------------
# 2. Landsat Collection (예시: Landsat 8/9 C2 L2)
# --------------------------------------------------
Landsat = (
    ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")
    .merge(ee.ImageCollection("LANDSAT/LC09/C02/T1_L2"))
)

# --------------------------------------------------
# 3. 날짜별 그룹 처리
# --------------------------------------------------
for date, group in df.groupby("년/월/일"):

    start = date.strftime("%Y-%m-%d")
    end   = (date + timedelta(days=1)).strftime("%Y-%m-%d")

    # ----------------------------------------------
    # 3-1. FeatureCollection 생성 (buffer 적용)
    # ----------------------------------------------
    features = []

    for idx, row in group.iterrows():
        lon = dms_to_dd(row["경도"])
        lat = dms_to_dd(row["위도"])

        geom = ee.Geometry.Point([lon, lat]).buffer(60)
        feat = ee.Feature(geom, {"idx": idx})
        features.append(feat)

    fc = ee.FeatureCollection(features)

    # ----------------------------------------------
    # 3-2. Landsat 영상 선택 (당일 only)
    # ----------------------------------------------
    lst_img = (
        Landsat
        .filterBounds(fc)
        .filterDate(start, end)
        .sort("system:time_start", False)
        .first()
    )

    if lst_img.getInfo() is None:
        print(date.date(), "→ Landsat 없음")
        # 날짜에 해당하는 행 전부 NaN 처리
        for idx in group.index:
            out = df.loc[idx].to_dict()
            out["LST"] = np.nan
            out["LST_valid"] = 0
            out["image_id_Landsat"] = None
            results.append(out)
        continue

    # ----------------------------------------------
    # 3-3. ST_B10 → 섭씨 변환
    # ----------------------------------------------
    lst_img = (
        lst_img.select("ST_B10")
        .multiply(0.00341802)
        .add(149.0)
        .subtract(273.15)
        .rename("LST")
    )

    # ----------------------------------------------
    # 3-4. reduceRegions (buffer 평균)
    # ----------------------------------------------
    reduced = lst_img.reduceRegions(
        collection=fc,
        reducer=ee.Reducer.mean(),
        scale=30
    ).getInfo()["features"]

    # idx → LST 매핑
    lst_map = {
        f["properties"]["idx"]: f["properties"].get("LST")
        for f in reduced
    }

    # ----------------------------------------------
    # 3-5. 결과 병합
    # ----------------------------------------------
    for idx in group.index:
        out = df.loc[idx].to_dict()

        lst_val = lst_map.get(idx)

        if lst_val is not None:
            out["LST"] = lst_val
            out["LST_valid"] = 1
        else:
            out["LST"] = np.nan
            out["LST_valid"] = 0

        out["image_id_Landsat"] = lst_img.get("system:index").getInfo()

        results.append(out)

# --------------------------------------------------
# 4. DataFrame 생성
# --------------------------------------------------
df_out = pd.DataFrame(results)
# Out:
# 2019-03-11 → Landsat 없음
# 2019-09-17 → Landsat 없음
# 2019-11-04 → Landsat 없음
# 2020-06-08 → Landsat 없음
# 2021-12-13 → Landsat 없음
# 2022-02-21 → Landsat 없음
# 2022-04-12 → Landsat 없음
# 2022-05-04 → Landsat 없음
# 2022-06-21 → Landsat 없음
# 2022-07-01 → Landsat 없음
# 2022-10-11 → Landsat 없음
# 2023-03-13 → Landsat 없음
# 2023-03-20 → Landsat 없음
# 2023-07-26 → Landsat 없음
# 2024-01-04 → Landsat 없음
# 2024-04-01 → Landsat 없음
# 2024-06-10 → Landsat 없음

# %%
df_out
# Out:
#      Unnamed: 0     분류번호       측정소명      년/월/일       회차            경도  \
# 0             0  1010B50       춘천댐1 2018-12-19      1회차   127°39'.28"
# 1             1  2018B10  남강댐3(진양호) 2019-03-11  1회차 상층부  127°58'38.4"
# 2             2  2018B10  남강댐3(진양호) 2019-03-11  1회차 중층부  127°58'38.4"
# 3             3  2018B10  남강댐3(진양호) 2019-03-11  1회차 하층부  127°58'38.4"
# 4             4  5101B10       장흥댐1 2019-04-03  1회차 상층부    126°52'57"
# ..          ...      ...        ...        ...      ...           ...
# 147         147  2015B20       합천댐2 2024-06-10  1회차 중층부   128°2'22.4"
# 148         148  2015B10       합천댐3 2024-06-10  1회차 중층부   128°1'58.8"
# 149         149  2015B30       합천댐1 2024-06-10  1회차 하층부   128°1'35.4"
# 150         150  2015B20       합천댐2 2024-06-10  1회차 하층부   128°2'22.4"
# 151         151  2015B10       합천댐3 2024-06-10  1회차 하층부   128°1'58.8"
#
#                위도   채수시각  클로로필 a(㎎/㎥)   댐명  ...     B7   B8  B8A     B9  SCL  \
# 0    37°58'44.33"  12:43          4.5  춘천댐  ...  230.0  280  227  407.0    6
# 1     35°12'24.1"  10:30          5.2  남강댐  ...  120.0  136  126  116.0    6
# 2     35°12'24.1"  10:30          5.6  남강댐  ...  120.0  136  126  116.0    6
# 3     35°12'24.1"  10:30          5.1  남강댐  ...  120.0  136  126  116.0    6
# 4      34°45'4.2"  10:00          9.2  장흥댐  ...   70.0   66   68  101.0    6
# ..            ...    ...          ...  ...  ...    ...  ...  ...    ...  ...
# 147     35°33'42"  10:30          0.9  합천댐  ...    0.0    0    0    0.0    6
# 148    35°36'4.6"  10:00          0.9  합천댐  ...  414.0  328  356  209.0    6
# 149    35°32'2.2"  11:00          0.9  합천댐  ...    0.0    0    0    0.0    6
# 150     35°33'42"  10:30          0.9  합천댐  ...    0.0    0    0    0.0    6
# 151    35°36'4.6"  10:00          0.9  합천댐  ...  414.0  328  356  209.0    6
#
#        idx  LST                             image_id_S2  image_id_Landsat  \
# 0    44900  NaN  20181219T022109_20181219T022640_T52SCH              None
# 1     7948  NaN  20190311T020651_20190311T020648_T52SCD              None
# 2     7953  NaN  20190311T020651_20190311T020648_T52SCD              None
# 3     7958  NaN  20190311T020651_20190311T020648_T52SCD              None
# 4     8298  NaN  20190403T021651_20190403T021647_T52SBD              None
# ..     ...  ...                                     ...               ...
# 147  48023  NaN  20240610T021539_20240610T021535_T52SDE              None
# 148  48024  NaN  20240610T021539_20240610T021535_T52SDE              None
# 149  48041  NaN  20240610T021539_20240610T021535_T52SDE              None
# 150  48042  NaN  20240610T021539_20240610T021535_T52SDE              None
# 151  48043  NaN  20240610T021539_20240610T021535_T52SDE              None
#
#      LST_valid
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 147          0
# 148          0
# 149          0
# 150          0
# 151          0
#
# [152 rows x 29 columns]
